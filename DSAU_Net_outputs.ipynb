# %%
from matplotlib.pyplot import figure
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

def plot_data(input_names, output_type, output_axis, second_out, legend_names, title, max_epochs = 50):
    
    colour1 = "#1E88E5"
    colour2 = "#FFC107"
    
    loss_0 = []
    loss_Nan_0 = []
    figure(figsize=(14, 6), dpi=80)
    for c in range(len(output_type)):
        for i in range(max_epochs):

            loss_0 = np.genfromtxt(input_names + "/" + second_out[c] + "/epoch_" + str(i) + "_" + output_type[c] + ".csv",
                                   delimiter=',')
            loss_Nan_0 = np.append(loss_Nan_0, np.mean(loss_0[np.logical_not(np.isnan(loss_0))]))

        plt.plot(range(len(loss_Nan_0)),loss_Nan_0)
        loss_0 = []
        loss_Nan_0 = []

    plt.title(title,fontsize=20)
    plt.legend(legend_names, fontsize=16)
    plt.xlabel("Epoch",fontsize=18)
    plt.ylabel(ylabel=output_axis[c],fontsize=18)
    plt.grid()
    plt.show()

# %%
from matplotlib.pyplot import figure
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

sns.set(font_scale = 1.35)
sns.set_style("white",{"grid.color": ".5", "grid.linestyle": ":"})

input_names = "Checkpoints/UNet_DCSAU_Net_CT/Regression/"

output_type = ["jaccard_index","jaccard_index"]
output_axis = ["Jaccard Score","Jaccard Score"]
second_out = ["Training_Jaccard/","Validation_Jaccard/"]

legend_names = ["Training",
                "Validation"]

title = "Mean training and validation Jaccard index score per Epoch"

plot_data(input_names, output_type, output_axis, second_out, legend_names, title)

# CT data regression using DCSAU-Net

# %%
from matplotlib.pyplot import figure
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

colour1 = "#1E88E5"
colour2 = "#FFC107"

sns.set(font_scale = 1.35)
sns.set_style("white",{"grid.color": ".5", "grid.linestyle": ":"})

input_names = "Checkpoints/UNet_DCSAU_Net_CT/Regression/"

output_type = ["loss","loss"]
output_axis = ["MSE + cosine","MSE + cosine"]
second_out = ["Training_loss/","Validation_loss/"]

legend_names = ["Training",
                "Validation"]

title = "Mean training and validation loss per Epoch"

plot_data(input_names, output_type, output_axis, second_out, legend_names, title)

#CT data regression loss
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-21-c03fc1e27e39> in <module>
#      22 title = "Mean training and validation loss per Epoch"
#      23
# ---> 24 plot_data(input_names, output_type, output_axis, second_out, legend_names, title)
#      25
#      26 #CT data regression loss
#
# <ipython-input-2-a0765fb869c6> in plot_data(input_names, output_type, output_axis, second_out, legend_names, title, max_epochs)
#      17
#      18             loss_0 = np.genfromtxt(input_names + "/" + second_out[c] + "/epoch_" + str(i) + "_" + output_type[c] + ".csv",
# ---> 19                                    delimiter=',')
#      20             loss_Nan_0 = np.append(loss_Nan_0, np.mean(loss_0[np.logical_not(np.isnan(loss_0))]))
#      21
#
# ...

# %%
from matplotlib.pyplot import figure
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

colour1 = "#1E88E5"
colour2 = "#FFC107"

sns.set(font_scale = 1.35)
sns.set_style("white",{"grid.color": ".5", "grid.linestyle": ":"})

input_names = "Checkpoints/UNet_DCSAU_Net_CT/Regression/"

output_type = ["loss_cosine","loss_cosine"]
output_axis = ["cosine?","cosine?"]
second_out = ["Training_loss_cosine/","Validation_loss_cosine/"]

legend_names = ["Training",
                "Validation"]

title = "Mean training and validation cosine loss per Epoch"

plot_data(input_names, output_type, output_axis, second_out, legend_names, title)

# %%
from matplotlib.pyplot import figure
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

colour1 = "#1E88E5"
colour2 = "#FFC107"

sns.set(font_scale = 1.35)
sns.set_style("white",{"grid.color": ".5", "grid.linestyle": ":"})

input_names = "Checkpoints/UNet_DCSAU_Net_CT/Regression/"

output_type = ["loss_mse","loss_mse"]
output_axis = ["mse?","mse?"]
second_out = ["Training_loss_mse/","Validation_loss_mse/"]

legend_names = ["Training",
                "Validation"]

title = "Mean training and validation mse loss per Epoch"

plot_data(input_names, output_type, output_axis, second_out, legend_names, title)

#CT data regression loss

# %%
from matplotlib.pyplot import figure
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

colour1 = "#1E88E5"
colour2 = "#FFC107"

sns.set(font_scale = 1.35)
sns.set_style("white",{"grid.color": ".5", "grid.linestyle": ":"})

input_names = "Checkpoints/UNet_DCSAU_Net_CT/Segmentation_baseline/"

output_type = ["loss","loss"]
output_axis = ["MSE?","MSE?"]
second_out = ["Training_loss/","Validation_loss/"]

legend_names = ["Training",
                "Validation"]

title = "Mean training and validation loss per Epoch"

plot_data(input_names, output_type, output_axis, second_out, legend_names, title)

# CT DCSAU-Net segmentation loss baseline

# %%
from matplotlib.pyplot import figure
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

colour1 = "#1E88E5"
colour2 = "#FFC107"

sns.set(font_scale = 1.35)
sns.set_style("white",{"grid.color": ".5", "grid.linestyle": ":"})

input_names = "Checkpoints/UNet_DCSAU_Net_CT/Segmentation/"

output_type = ["loss","loss"]
output_axis = ["MSE?","MSE?"]
second_out = ["Training_loss/","Validation_loss/"]

legend_names = ["Training",
                "Validation"]

title = "Mean training and validation dice per Epoch"

plot_data(input_names, output_type, output_axis, second_out, legend_names, title, max_epochs = 8)

output_type = ["dice_score"]
output_axis = ["MSE?","MSE?"]
second_out = ["Training_Dice/","Validation_Dice/"]

legend_names = ["Training",
                "Validation"]

title = "Mean training and validation dice per Epoch"

plot_data(input_names, output_type, output_axis, second_out, legend_names, title, max_epochs = 8)

# %%
from matplotlib.pyplot import figure
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

from matplotlib.pyplot import figure
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

def plot_data_nomean(input_names, output_type, output_axis, second_out, legend_names, title):
    epoch = 0
    colour1 = "#1E88E5"
    colour2 = "#FFC107"
    
    loss_0 = []
    loss_Nan_0 = []
    figure(figsize=(14, 6), dpi=80)

    loss_0 = np.genfromtxt(input_names + "/" + second_out[0] + "/epoch_" + str(epoch) + "_" + output_type[0] + ".csv",delimiter=',')
    loss_1 = np.mean(loss_0[:(len(loss_0)//16)*16].reshape(-1,16), axis=1)
    plt.plot(range(len(loss_1)),loss_1)
    loss_0 = []
    loss_Nan_0 = []

    plt.title(title,fontsize=20)
    plt.legend(legend_names, fontsize=16)
    plt.xlabel("Epoch",fontsize=18)
    plt.ylabel(ylabel=output_axis[0],fontsize=18)
    plt.grid()
    plt.show()  

colour1 = "#1E88E5"
colour2 = "#FFC107"

sns.set(font_scale = 1.35)
sns.set_style("white",{"grid.color": ".5", "grid.linestyle": ":"})

input_names = "Checkpoints/UNet_DCSAU_Net_CT/Segmentation/"

output_type = ["loss"]
output_axis = ["dice loss"]
second_out = ["Training_loss/"]
legend_names = ["Training"]

title = "Training loss Epoch 0 - Segmentation model"

plot_data_nomean(input_names, output_type, output_axis, second_out, legend_names, title)

output_type = ["dice_score"]
output_axis = ["Dice"]
second_out = ["Training_Dice/"]

title = "Training dice Epoch 0 - Segmentation model"

plot_data_nomean(input_names, output_type, output_axis, second_out, legend_names, title)

output_type = ["loss"]
output_axis = ["dice loss"]
second_out = ["Validation_loss/"]
legend_names = ["Validation"]

title = "Training loss Epoch 0 - Segmentation model"

plot_data_nomean(input_names, output_type, output_axis, second_out, legend_names, title)

output_type = ["dice_score"]
output_axis = ["Dice"]
second_out = ["Validation_Dice/"]

title = "Training dice Epoch 0 - Segmentation model"

plot_data_nomean(input_names, output_type, output_axis, second_out, legend_names, title)

# %%
from matplotlib.pyplot import figure
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

from matplotlib.pyplot import figure
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

colour1 = "#1E88E5"
colour2 = "#FFC107"

sns.set(font_scale = 1.35)
sns.set_style("white",{"grid.color": ".5", "grid.linestyle": ":"})

input_names = "Checkpoints/UNet_DCSAU_Net_CT/Segmentation/"

output_type = ["loss"]
output_axis = ["dice loss"]
second_out = ["Training_loss/"]
legend_names = ["Training"]

title = "Training loss Epoch 0 - Segmentation model"

plot_data(input_names, output_type, output_axis, second_out, legend_names, title)

output_type = ["dice_score"]
output_axis = ["Dice"]
second_out = ["Training_Dice/"]

title = "Training dice Epoch 0 - Segmentation model"

plot_data(input_names, output_type, output_axis, second_out, legend_names, title)

output_type = ["loss"]
output_axis = ["dice loss"]
second_out = ["Validation_loss/"]
legend_names = ["Validation"]

title = "Training loss Epoch 0 - Segmentation model"

plot_data(input_names, output_type, output_axis, second_out, legend_names, title)

output_type = ["dice_score"]
output_axis = ["Dice"]
second_out = ["Validation_Dice/"]

title = "Training dice Epoch 0 - Segmentation model"

plot_data(input_names, output_type, output_axis, second_out, legend_names, title)

# %%
from matplotlib.pyplot import figure
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

sns.set(font_scale = 1.35)
sns.set_style("white",{"grid.color": ".5", "grid.linestyle": ":"})

input_names = "Checkpoints/UNet_DCSAU_Net_CT_8/Regression/"

output_type = ["jaccard_index","jaccard_index"]
output_axis = ["Jaccard Score","Jaccard Score"]
second_out = ["Training_Jaccard/","Validation_Jaccard/"]

legend_names = ["Training",
                "Validation"]

title = "Mean training and validation Jaccard index score per Epoch"

plot_data(input_names, output_type, output_axis, second_out, legend_names, title, max_epochs = 65)

# %%
from matplotlib.pyplot import figure
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

colour1 = "#1E88E5"
colour2 = "#FFC107"

sns.set(font_scale = 1.35)
sns.set_style("white",{"grid.color": ".5", "grid.linestyle": ":"})

input_names = "Checkpoints/UNet_DCSAU_Net_CT/Segmentation/"

output_type = ["loss","loss"]
output_axis = ["Dice loss","Dice loss"]
second_out = ["Training_loss/","Validation_loss/"]

legend_names = ["Training",
                "Validation"]

title = "Mean training and validation loss per Epoch"

plot_data(input_names, output_type, output_axis, second_out, legend_names, title, 100)

output_type = ["dice_score", "dice_score"]
output_axis = ["MSE?","MSE?"]
second_out = ["Training_Dice/","Validation_Dice/"]

legend_names = ["Training",
                "Validation"]

title = "Mean training and validation dice per Epoch"

plot_data(input_names, output_type, output_axis, second_out, legend_names, title, max_epochs = 100)

# %%
from matplotlib.pyplot import figure
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

colour1 = "#1E88E5"
colour2 = "#FFC107"

sns.set(font_scale = 1.35)
sns.set_style("white",{"grid.color": ".5", "grid.linestyle": ":"})

input_names = "Checkpoints/UNet_DCSAU_Net_CT_8/Regression/"

output_type = ["loss_mse","loss_mse"]
output_axis = ["mse?","mse?"]
second_out = ["Training_loss_mse/","Validation_loss_mse/"]

legend_names = ["Training",
                "Validation"]

title = "Mean training and validation mse loss per Epoch"

plot_data(input_names, output_type, output_axis, second_out, legend_names, title,100)

# %%
from matplotlib.pyplot import figure
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

sns.set(font_scale = 1.35)
sns.set_style("white",{"grid.color": ".5", "grid.linestyle": ":"})

input_names = "Checkpoints/UNet_DCSAU_Net_CT_8/Regression/"

output_type = ["jaccard_index","jaccard_index"]
output_axis = ["Jaccard Score","Jaccard Score"]
second_out = ["Training_Jaccard/","Validation_Jaccard/"]

legend_names = ["Training",
                "Validation"]

title = "Mean training and validation Jaccard index score per Epoch"

plot_data(input_names, output_type, output_axis, second_out, legend_names, title,100)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-25-494d025288a5> in <module>
#      19 title = "Mean training and validation Jaccard index score per Epoch"
#      20
# ---> 21 plot_data(input_names, output_type, output_axis, second_out, legend_names, title,100)
#
# <ipython-input-22-a0765fb869c6> in plot_data(input_names, output_type, output_axis, second_out, legend_names, title, max_epochs)
#      17
#      18             loss_0 = np.genfromtxt(input_names + "/" + second_out[c] + "/epoch_" + str(i) + "_" + output_type[c] + ".csv",
# ---> 19                                    delimiter=',')
#      20             loss_Nan_0 = np.append(loss_Nan_0, np.mean(loss_0[np.logical_not(np.isnan(loss_0))]))
#      21
#
# ...

# %%
from matplotlib.pyplot import figure
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

sns.set(font_scale = 1.35)
sns.set_style("white",{"grid.color": ".5", "grid.linestyle": ":"})

input_names = "Checkpoints/UNet_brats/Regression/"

output_type = ["jaccard_index","jaccard_index"]
output_axis = ["Jaccard Score","Jaccard Score"]
second_out = ["Training_Jaccard/","Validation_Jaccard/"]

legend_names = ["Training",
                "Validation"]

title = "Mean training and validation Jaccard index score per Epoch"

plot_data(input_names, output_type, output_axis, second_out, legend_names, title,37)

# brats data old model regression jaccard score - FLAIR channel only

# %%
from matplotlib.pyplot import figure
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

colour1 = "#1E88E5"
colour2 = "#FFC107"

sns.set(font_scale = 1.35)
sns.set_style("white",{"grid.color": ".5", "grid.linestyle": ":"})

input_names = "Checkpoints/UNet_brats/Segmentation/"

output_type = ["loss","loss"]
output_axis = ["Dice loss","Dice loss"]
second_out = ["Training_loss/","Validation_loss/"]

legend_names = ["Training",
                "Validation"]

title = "Mean training and validation loss per Epoch"

plot_data(input_names, output_type, output_axis, second_out, legend_names, title, 49)

output_type = ["dice_score", "dice_score"]
output_axis = ["MSE?","MSE?"]
second_out = ["Training_Dice/","Validation_Dice/"]

legend_names = ["Training",
                "Validation"]

title = "Mean training and validation dice per Epoch"

plot_data(input_names, output_type, output_axis, second_out, legend_names, title, max_epochs = 100)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-8-76fe955241b2> in <module>
#      22 title = "Mean training and validation loss per Epoch"
#      23
# ---> 24 plot_data(input_names, output_type, output_axis, second_out, legend_names, title, 49)
#      25
#      26 output_type = ["dice_score", "dice_score"]
#
# <ipython-input-2-a0765fb869c6> in plot_data(input_names, output_type, output_axis, second_out, legend_names, title, max_epochs)
#      17
#      18             loss_0 = np.genfromtxt(input_names + "/" + second_out[c] + "/epoch_" + str(i) + "_" + output_type[c] + ".csv",
# ---> 19                                    delimiter=',')
#      20             loss_Nan_0 = np.append(loss_Nan_0, np.mean(loss_0[np.logical_not(np.isnan(loss_0))]))
#      21
#
# ...

# %%
# from matplotlib.pyplot import figure
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

colour1 = "#1E88E5"
colour2 = "#FFC107"

sns.set(font_scale = 1.35)
sns.set_style("white",{"grid.color": ".5", "grid.linestyle": ":"})

input_names = "Checkpoints/UNet_5/Regression/"

output_type = ["loss","loss"]
output_axis = ["MSE + cosine","MSE + cosine"]
second_out = ["Training_loss/","Validation_loss/"]

legend_names = ["Training",
                "Validation"]

title = "Mean training and validation mse loss per Epoch"

plot_data(input_names, output_type, output_axis, second_out, legend_names, title,100)


output_type = ["jaccard_index","jaccard_index"]
output_axis = ["Jaccard Score","Jaccard Score"]
second_out = ["Training_Jaccard/","Validation_Jaccard/"]

legend_names = ["Training",
                "Validation"]

title = "Mean training and validation Jaccard index score per Epoch"

plot_data(input_names, output_type, output_axis, second_out, legend_names, title,100)

# %%
from matplotlib.pyplot import figure
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

colour1 = "#1E88E5"
colour2 = "#FFC107"

sns.set(font_scale = 1.35)
sns.set_style("white",{"grid.color": ".5", "grid.linestyle": ":"})

input_names = "Checkpoints/UNet_4/Segmentation/"

output_type = ["loss","loss"]
output_axis = ["Dice loss","Dice loss"]
second_out = ["Training_loss/","Validation_loss/"]

legend_names = ["Training",
                "Validation"]

title = "Mean training and validation loss per Epoch"

plot_data(input_names, output_type, output_axis, second_out, legend_names, title, 100)

output_type = ["dice_score", "dice_score"]
output_axis = ["MSE?","MSE?"]
second_out = ["Training_Dice/","Validation_Dice/"]

legend_names = ["Training",
                "Validation"]

title = "Mean training and validation dice per Epoch"

plot_data(input_names, output_type, output_axis, second_out, legend_names, title, max_epochs = 100)
