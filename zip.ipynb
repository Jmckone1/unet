# %%
import shutil
shutil.make_archive("model_5_offical_val_all_data_baseline", 'zip', "Predictions/model_5_offical_val_all_data_baseline_official_main")
# Out:
# '/data/model_5_offical_val_all_data_baseline.zip'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

x_array = np.array([])

for j in range(6):
    x = np.nanmean(np.genfromtxt("Checkpoints/Full_model_MK5_H16_unfrozen_5_epochs/epoch_"+str(j)+"validation_loss.csv", delimiter=','))
    x_array = np.append(x_array, x)
    
plt.plot(range(len(x_array)),x_array)
plt.title("Validation loss")
print("mean validation: ", np.nanmean(x))
plt.legend(["un-frozen pretrained"])
plt.show()
# Out:
# mean validation:  0.00040269602222886455

# %%
# x0 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_unfrozen_5_epochs/epoch_0training_loss.csv", delimiter=',')
# x1 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_unfrozen_5_epochs/epoch_1training_loss.csv", delimiter=',')
# x2 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_unfrozen_5_epochs/epoch_2training_loss.csv", delimiter=',')
# x3 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_unfrozen_5_epochs/epoch_3training_loss.csv", delimiter=',')
# x4 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_unfrozen_5_epochs/epoch_4training_loss.csv", delimiter=',')
# x5 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_unfrozen_5_epochs/epoch_5training_loss.csv", delimiter=',')

# x = np.concatenate((x0,x1,x2,x3,x4,x5))
# plt.plot(range(len(x)),x)
# plt.title("Mean Training Loss for the first 150 batches of 3 models")
# plt.xlabel("Mean values per batch")
# plt.ylabel("Mean loss - BCEWithLogitsLoss")
# plt.legend(["Base", "Frozen", "Unfrozen", "Unfr_all_data"])
# plt.show()

########################################################################################################################    

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

x_array = np.array([])

for j in range(6):
    x = np.nanmean(np.genfromtxt("Checkpoints/Full_model_MK5_H16_unfrozen_5_epochs/epoch_"+str(j)+"training_loss.csv", delimiter=','))
    x_array = np.append(x_array, x)
    
plt.plot(range(len(x_array)),x_array)
plt.title("Training loss")
print("mean validation: ", np.nanmean(x))
plt.legend(["un-frozen pretrained"])
plt.show()

x_array = np.array([])

for j in range(6):
    x = np.nanmean(np.genfromtxt("Checkpoints/Full_model_MK5_H16_unfrozen_5_epochs/epoch_"+str(j)+"validation_loss.csv", delimiter=','))
    x_array = np.append(x_array, x)
    
plt.plot(range(len(x_array)),x_array)
plt.title("Validation loss")
print("mean validation: ", np.nanmean(x))
plt.legend(["un-frozen pretrained"])
plt.show()

x_array = np.array([])

for j in range(6):
    x = np.nanmean(np.genfromtxt("Checkpoints/Full_model_MK5_H16_unfrozen_5_epochs/epoch_"+str(j)+"validation_dice.csv", delimiter=','))
    x_array = np.append(x_array, x)

plt.plot(range(len(x_array)),x_array)
plt.title("Validation dice")
print("mean validation: ", np.nanmean(x))
plt.legend(["un-frozen pretrained"])
plt.show()

x_array = np.array([])

for j in range(6):
    x = np.nanmean(np.genfromtxt("Checkpoints/Full_model_MK5_H16_unfrozen_5_epochs/epoch_"+str(j)+"training_dice.csv", delimiter=','))
    x_array = np.append(x_array, x)
    
plt.plot(range(len(x_array)),x_array)
plt.title("training dice")
print("mean validation: ", np.nanmean(x))
plt.legend(["un-frozen pretrained"])
plt.show()

# keep in mind that validation here is false and not worth looking into, you just wasted a bunch of time!!!!!!!
# validation includes data that is in the full dataset and can safely be ignored!
# look at the offical validation data model for this (will include having to request submission of the data a number
# of times using predictions from the various chdckpoints)
# FUCK ~
# retrain on the split dataset
# Out:
# mean validation:  3.869082650991292e-05
# mean validation:  0.00040269602222886455
# mean validation:  0.8931002284115992
# mean validation:  0.8845800864922755
