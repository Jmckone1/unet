# %%
import shutil
shutil.make_archive("model_5_offical_val_all_data_baseline", 'zip', "Predictions/model_5_offical_val_all_data_baseline_official_main")
# Out:
# '/data/model_5_offical_val_all_data_baseline.zip'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

x_array = np.array([])

for j in range(6):
    x = np.nanmean(np.genfromtxt("Checkpoints/Full_model_MK5_H16_unfrozen_5_epochs_BCELoss_2/epoch_"+str(j)+"training_loss.csv", delimiter=','))
    x_array = np.append(x_array, x)
    
plt.plot(range(len(x_array)),x_array)
plt.title("Validation loss")
print("mean validation: ", np.nanmean(x))
plt.legend(["un-frozen pretrained"])
plt.show()
# Out:
# mean validation:  5.509165765840837e-05

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

input_1 = "/Full_model_MK5_H16_unfrozen_5_epochs_BCELoss_2"
input_2 = "/Full_model_MK5_H16_unfrozen_5_epochs_DiceLoss_2"
inputs = [input_1,input_2]
output_type = ["training_loss","validation_loss","training_dice","validation_dice"]

for f in range(len(output_type)):
    for i in range(len(inputs)):
        x_array = np.array([])
        y_array = np.array([])
        for j in range(6):
            x = np.nanmean(np.genfromtxt("Checkpoints/"+inputs[i]+"/epoch_"+str(j)+output_type[f]+".csv", delimiter=','))
            x_array = np.append(x_array, x)
        plt.plot(range(len(x_array)),x_array)
        
    plt.title(output_type[f])
    plt.legend(["BCE","Dice"])
    plt.show()

# Dice and BCE loss are not directly coparible in themselves
    
# keep in mind that validation here is false and not worth looking into, you just wasted a bunch of time!!!!!!!
# validation includes data that is in the full dataset and can safely be ignored!
# look at the offical validation data model for this (will include having to request submission of the data a number
# of times using predictions from the various chdckpoints)
# FUCK ~
# retrain on the split dataset

# fixed it :D

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

input_1 = "/Full_model_MK5_H16_unfrozen_6_epochs_BCELoss_2_10"
input_2 = "/Full_model_MK5_H16_unfrozen_6_epochs_BCELoss_2_20"
input_3 = "/Full_model_MK5_H16_unfrozen_6_epochs_BCELoss_2_30"
input_4 = "/Full_model_MK5_H16_unfrozen_6_epochs_BCELoss_2_40"
input_5 = "/Full_model_MK5_H16_unfrozen_6_epochs_BCELoss_2_50"
input_0 = "/Full_model_MK5_H16_unfrozen_5_epochs_BCELoss_2"

inputs = [input_1,input_2,input_3,input_4,input_5,input_0]
output_type = ["training_loss","validation_loss","training_dice","validation_dice"]

for f in range(len(output_type)):
    for i in range(len(inputs)):
        x_array = np.array([])
        for j in range(6):
            x = np.nanmean(np.genfromtxt("Checkpoints/"+inputs[i]+"/epoch_"+str(j)+output_type[f]+".csv", delimiter=','))
            x_array = np.append(x_array, x)
        ax = plt.subplot()
        ax.plot(range(len(x_array)),x_array)
    if f > 1:
        plt.ylim([0.5,1])
    plt.title("Unfrozen Pretrained model "+output_type[f])
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])

    # Put a legend to the right of the current axis

    ax.legend(["10","20","30","40","50","100"],loc='center left', bbox_to_anchor=(1, 0.5))
    
    plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

input_1 = "/Full_model_MK5_H16_baseline_6_epochs_BCELoss_2_10"
input_2 = "/Full_model_MK5_H16_baseline_6_epochs_BCELoss_2_20"
input_3 = "/Full_model_MK5_H16_baseline_6_epochs_BCELoss_2_30"
input_4 = "/Full_model_MK5_H16_baseline_6_epochs_BCELoss_2_40"
input_5 = "/Full_model_MK5_H16_baseline_6_epochs_BCELoss_2_50"
input_0 = "/Full_model_MK5_H16_unfrozen_5_epochs_BCELoss_2"

inputs = [input_1,input_2,input_3,input_4,input_5,input_0]
output_type = ["training_loss","validation_loss","training_dice","validation_dice"]
for f in range(len(output_type)):
    for i in range(len(inputs)):
        x_array = np.array([])
        for j in range(6):
            x = np.nanmean(np.genfromtxt("Checkpoints/"+inputs[i]+"/epoch_"+str(j)+output_type[f]+".csv", delimiter=','))
            x_array = np.append(x_array, x)
        ax = plt.subplot()
        ax.plot(range(len(x_array)),x_array)
    if f > 1:
        plt.ylim([0.5,1])
    plt.title("Baseline model "+output_type[f])
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])

    # Put a legend to the right of the current axis

    ax.legend(["10","20","30","40","50","100"],loc='center left', bbox_to_anchor=(1, 0.5))
    plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# ...

# %%
import seaborn as sns
import numpy as np
import pandas as pd
sns.set_theme(style="whitegrid")
import matplotlib.pyplot as plt

input_1 = "/Full_model_MK5_H16_baseline_6_epochs_BCELoss_2_10"
input_2 = "/Full_model_MK5_H16_baseline_6_epochs_BCELoss_2_20"
input_3 = "/Full_model_MK5_H16_baseline_6_epochs_BCELoss_2_30"
input_4 = "/Full_model_MK5_H16_baseline_6_epochs_BCELoss_2_40"
input_5 = "/Full_model_MK5_H16_baseline_6_epochs_BCELoss_2_50"

input_11 = "/Full_model_MK5_H16_unfrozen_6_epochs_BCELoss_2_10"
input_12 = "/Full_model_MK5_H16_unfrozen_6_epochs_BCELoss_2_20"
input_13 = "/Full_model_MK5_H16_unfrozen_6_epochs_BCELoss_2_30"
input_14 = "/Full_model_MK5_H16_unfrozen_6_epochs_BCELoss_2_40"
input_15 = "/Full_model_MK5_H16_unfrozen_6_epochs_BCELoss_2_50"

display_epoch = 5
data_amount = [10,20,30,40,50]
inputs = [input_1,input_2,input_3,input_4,input_5]
inputs2 = [input_11,input_12,input_13,input_14,input_15]
x_array = np.array([])
y_array = np.array([])
a_array = np.array([])

#for j in range(6):
a = np.genfromtxt("Checkpoints/Full_model_MK5_H16_unfrozen_5_epochs_BCELoss_2/epoch_"+str(display_epoch)+"validation_dice.csv", delimiter=',')
a_array = np.append(a_array, a)
data_a = pd.DataFrame(data=a_array,columns=range(1)).assign(Data="Unfrozen_100%")

for i in range(len(inputs)):
    #for j in range(6):
    x = np.genfromtxt("Checkpoints/"+inputs[i]+"/epoch_"+str(display_epoch)+"validation_dice.csv", delimiter=',')
    x_array = np.append(x_array, x)
    y = np.genfromtxt("Checkpoints/"+inputs2[i]+"/epoch_"+str(display_epoch)+"validation_dice.csv", delimiter=',')
    y_array = np.append(y_array, y)

    data_x = pd.DataFrame(data=x_array,columns=range(1)).assign(Data="Baseline_"+str(data_amount[i])+"%")
    data_y = pd.DataFrame(data=y_array,columns=range(1)).assign(Data="Unfrozen_"+str(data_amount[i])+"%")
    train_data = pd.concat([data_x,data_y,data_a])
    train_data_2 = pd.melt(train_data, id_vars=['Data'])

    ax = sns.boxplot(x="Data", y="value", data=train_data_2)
    plt.title("validation dice score boxPlot for " +str(data_amount[i])+"% data used \n for epoch " + str(display_epoch))
    plt.ylabel("Mean dice score")
    plt.xlabel("")
    plt.show()

for i in range(len(inputs)):
    #for j in range(6):
    x = np.genfromtxt("Checkpoints/"+inputs[i]+"/epoch_"+str(display_epoch)+"validation_dice.csv", delimiter=',')
    x_array = np.append(x_array, x)
    y = np.genfromtxt("Checkpoints/"+inputs2[i]+"/epoch_"+str(display_epoch)+"validation_dice.csv", delimiter=',')
    y_array = np.append(y_array, y)

    data_x = pd.DataFrame(data=x_array,columns=range(1)).assign(Data="Baseline_"+str(data_amount[i])+"%")
    data_y = pd.DataFrame(data=y_array,columns=range(1)).assign(Data="Unfrozen_"+str(data_amount[i])+"%")
    train_data = pd.concat([data_x,data_y,data_a])
    train_data_2 = pd.melt(train_data, id_vars=['Data'])

    ax = sns.violinplot(x="Data", y="value", data=train_data_2)
    plt.title("validation dice score violinPlot for " +str(data_amount[i])+"% data used \n for epoch " + str(display_epoch))
    plt.ylabel("Mean dice score")
    plt.xlabel("")
    plt.show()

# %%
import torch
from torch import nn
from tqdm.auto import tqdm
from torchvision.utils import make_grid
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import torch.nn.functional as F
import numpy as np

np.random.seed(0)
torch.manual_seed(0)

#from Code_UNet.Unet_modules.Full_model_dataloader_all_data import BraTs_Dataset
from Code_UNet.Unet_modules.Full_dataloader_Rand import BraTs_Dataset

size = 1
batch_size = 16
train_split = 0.7
validation_split = 0.1
test_split = 0.2

dataset = BraTs_Dataset("Brats_2018_data_all/All_data", path_ext = ["/HGG","/LGG"], size=size, apply_transform=True)
data_size = len(dataset)
patients_number = data_size / 155

# train_length = int(155*(np.ceil(patients_number * train_split)))
# validation_length = int(155*(np.floor(patients_number * validation_split)))
# test_length = int(155*(np.floor(patients_number * test_split)))

# train = list(range(0,train_length))
# val = list(range(train_length,train_length+validation_length))
# test = list(range(train_length+validation_length,train_length+validation_length+test_length))

# train_data = torch.utils.data.Subset(dataset, train_length)
# validation_data = torch.utils.data.Subset(dataset, val)
# test_data = torch.utils.data.Subset(dataset, test)

# # train = dataset[0:train_length]
# # val = dataset[train_length+1:train_length+validation_length]
# # test = dataset[train_length+validation_length+1:train_length+validation_length+test_length]

# print(data_size,len(train_data),len(validation_data),len(test_data))
# print(train_data)
# print(dataset)
# # v = len(dataset) / 155
# # print(v)
# print(len(train_data)/155)
# print(len(train_data)+len(validation_data)+len(test_data))
# # x = torch.utils.data.BatchSampler(dataset, 155, drop_last=False)

# %%
import random

train_length = int(155*(np.ceil(patients_number * train_split)))
validation_length = int(155*(np.floor(patients_number * validation_split)))
test_length = int(155*(np.floor(patients_number * test_split)))

train = range(0,train_length)
print(list(train))
val = range(train_length,train_length+validation_length)
test = range(train_length+validation_length,train_length+validation_length+test_length)

print("")

train_data_m = torch.utils.data.SubsetRandomSampler(dataset,train)
validation_data_m = torch.utils.data.SubsetRandomSampler(dataset,val)
test_data_m = torch.utils.data.SubsetRandomSampler(dataset,test)
# https://medium.com/jun-devpblog/pytorch-5-pytorch-visualization-splitting-dataset-sve-and-load-a-model-501e0a664a67
print("Training: ", len(train_data_m))
print("validation: ", len(validation_data_m))

Train_data = DataLoader(
    dataset=dataset,
    batch_size=batch_size,
    sampler=train_data_m)

Val_data = DataLoader(
    dataset=dataset,
    batch_size=batch_size,
    drop_last=True,sampler=validation_data_m)

# %%
import numpy as np
a = np.floor(285*0.7)
b = np.ceil(285*0.2)
c = np.ceil(285*0.1)

print(a,b,c)

print(a+b+c)
# Out:
# 199.0 57.0 29.0
# 285.0
