# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import nibabel as nib

def calculate_dice(pred_seg, gt_lbl):
    union_correct = pred_seg * gt_lbl
    tp_num = np.sum(union_correct)
    gt_pos_num = np.sum(gt_lbl)
    dice = (2.0 * tp_num) / (np.sum(pred_seg) + gt_pos_num) if gt_pos_num != 0 else -1
    return dice

# Brats18_CBICA_ALX_1_whimg_norm_154

predictions = ["Brats18_2013_0_1_whimg_norm_154.nii.gz",
"Brats18_TCIA09_141_1_whimg_norm_154.nii.gz",
"Brats18_TCIA10_282_1_whimg_norm_154.nii.gz",
"Brats18_2013_1_1_whimg_norm_154.nii.gz",
"Brats18_TCIA10_346_1_whimg_norm_154.nii.gz",
"Brats18_TCIA13_642_1_whimg_norm_154.nii.gz",
"Brats18_TCIA10_310_1_whimg_norm_154.nii.gz",
"Brats18_TCIA10_307_1_whimg_norm_154.nii.gz",
"Brats18_TCIA10_175_1_whimg_norm_154.nii.gz",
"Brats18_TCIA10_628_1_whimg_norm_154.nii.gz",
"Brats18_2013_9_1_whimg_norm_154.nii.gz",
"Brats18_2013_6_1_whimg_norm_154.nii.gz",
"Brats18_TCIA10_490_1_whimg_norm_154.nii.gz",
"Brats18_TCIA10_644_1_whimg_norm_154.nii.gz",
"Brats18_TCIA13_630_1_whimg_norm_154.nii.gz",
"Brats18_TCIA10_109_1_whimg_norm_154.nii.gz",
"Brats18_TCIA13_650_1_whimg_norm_154.nii.gz",
"Brats18_TCIA10_103_1_whimg_norm_154.nii.gz",
"Brats18_TCIA09_141_1_whimg_norm_154.nii.gz",
"Brats18_TCIA10_241_1_whimg_norm_154.nii.gz",
"Brats18_TCIA10_130_1_whimg_norm_154.nii.gz",
"Brats18_2013_16_1_whimg_norm_154.nii.gz",
"Brats18_TCIA10_325_1_whimg_norm_154.nii.gz",
"Brats18_TCIA13_615_1_whimg_norm_154.nii.gz",
"Brats18_TCIA10_351_1_whimg_norm_154.nii.gz",
"Brats18_2013_15_1_whimg_norm_154.nii.gz",
"Brats18_TCIA09_462_1_whimg_norm_154.nii.gz",
"Brats18_TCIA09_255_1_whimg_norm_154.nii.gz"]

ground_truth = [
        "Brats18_2013_0_1_whseg_norm_",
     "Brats18_TCIA09_141_1_whseg_norm_",
    "Brats18_TCIA10_282_1_whseg_norm_",
        "Brats18_2013_1_1_whseg_norm_",
    "Brats18_TCIA10_346_1_whseg_norm_",
    "Brats18_TCIA13_642_1_whseg_norm_",
    "Brats18_TCIA10_310_1_whseg_norm_",
    "Brats18_TCIA10_307_1_whseg_norm_",
    "Brats18_TCIA10_175_1_whseg_norm_",
    "Brats18_TCIA10_628_1_whseg_norm_",
        "Brats18_2013_9_1_whseg_norm_",
        "Brats18_2013_6_1_whseg_norm_",
    "Brats18_TCIA10_490_1_whseg_norm_",
    "Brats18_TCIA10_644_1_whseg_norm_",
    "Brats18_TCIA13_630_1_whseg_norm_",
    "Brats18_TCIA10_109_1_whseg_norm_",
    "Brats18_TCIA13_650_1_whseg_norm_",
    "Brats18_TCIA10_103_1_whseg_norm_",
    "Brats18_TCIA09_141_1_whseg_norm_",
    "Brats18_TCIA10_241_1_whseg_norm_",
    "Brats18_TCIA10_130_1_whseg_norm_",
       "Brats18_2013_16_1_whseg_norm_",
    "Brats18_TCIA10_325_1_whseg_norm_",
    "Brats18_TCIA13_615_1_whseg_norm_",
    "Brats18_TCIA10_351_1_whseg_norm_",
       "Brats18_2013_15_1_whseg_norm_",
    "Brats18_TCIA09_462_1_whseg_norm_",
    "Brats18_TCIA09_255_1_whseg_norm_",
]

epoch = 4
for file_name in range(len(predictions)):
    print("")
    print(ground_truth[file_name])
    print(predictions[file_name])
    for epochs in range(5):
        image_path = os.path.join("Test_outputs/Prano_pretrain_1_C100_Output_test/Epoch_" + str(epochs) + "/" + predictions[file_name])
        # image_path2 = os.path.join("Test_outputs/Prano_pretrain_1_C100_Output_test/Epoch_" + str(epoch) + "/Brats18_TCIA04_361_1_whimg_norm_154.nii.gz")

        img = nib.load(image_path).get_fdata()
    #     print(np.shape(img))

        # img2 = nib.load(image_path2).get_fdata()
        # print(np.shape(img2))

        # Function to define the dice score of a volume - taken and adapted from the deepmind project code by recommendation of project supervisor.

        mask_all = np.zeros((240,240,155))

        for i in range(155):
            mask_path = os.getcwd() + "/Brats_2018_4/labelsTr/"+ ground_truth[file_name] + str(i) + ".nii.gz"

            mask = nib.load(mask_path).get_fdata()
            mask_all[:,:,i] = mask

        print("Epoch", epochs, ":", calculate_dice(img,mask_all))
        # input("")

        # for i in range(155):
        #     print(i)
        #     mask_path = os.getcwd() + "/Brats_2018_4/labelsTr/Brats18_2013_15_1_whseg_norm_" + str(i) + ".nii.gz"

        #     mask = nib.load(mask_path).get_fdata()

        #     fig, ax = plt.subplots(1,2)

        #     ax[0].imshow((img[:,:,i]), cmap='gray')
        # #     ax[1].imshow((img2[:,:,i]), cmap='gray')
        #     ax[1].imshow(mask[:,:],cmap='gray', alpha=1)
        #     plt.show()
# Out:
# Brats18_2013_0_1_whseg_norm_
# Brats18_2013_0_1_whimg_norm_154.nii.gz
# Epoch 0 : 0.7430901954370758
# Epoch 1 : 0.7347881371779049
# Epoch 2 : 0.7368017664555923
# Epoch 3 : 0.734683596264542
# Epoch 4 : 0.7372946244891558
#
# Brats18_TCIA09_141_1_whseg_norm_
# Brats18_TCIA09_141_1_whimg_norm_154.nii.gz
# Epoch 0 : 0.7161901579079288
# Epoch 1 : 0.6927208604707726
# Epoch 2 : 0.7132688580291037
# Epoch 3 : 0.7074135665048413
# Epoch 4 : 0.7026677358274428
#
# Brats18_TCIA10_282_1_whseg_norm_
# Brats18_TCIA10_282_1_whimg_norm_154.nii.gz
# Epoch 0 : 0.7843121093481695
# Epoch 1 : 0.7691086004464666
# Epoch 2 : 0.7557479584326064
# Epoch 3 : 0.7468761706701398
# Epoch 4 : 0.768941444254764
#
# Brats18_2013_1_1_whseg_norm_
# Brats18_2013_1_1_whimg_norm_154.nii.gz
# Epoch 0 : 0.6789827876277986
# Epoch 1 : 0.696640611014977
# Epoch 2 : 0.6911425228472947
# Epoch 3 : 0.4808093054976698
# Epoch 4 : 0.6439037415306565
#
# Brats18_TCIA10_346_1_whseg_norm_
# ...
