# %%
import numpy as np
import matplotlib.pyplot as plt

x ,y ,v ,b  = [],[],[],[]
x2,y2,v2,b2 = [],[],[],[]
c ,c1,z ,z1 = [],[],[],[]
u ,u1,o ,o1 = [],[],[],[]

for i in range(50):
    x = np.append(x, np.genfromtxt("Checkpoints_RANO/Unet8_data/epoch_"+str(i)+"training_loss",delimiter=','))
    v = np.append(v, np.mean(x[np.logical_not(np.isnan(x))]))
    
    y = np.append(y, np.genfromtxt("Checkpoints_RANO/Unet8_data/epoch_"+str(i)+"validation_loss",delimiter=','))
    b = np.append(b, np.mean(y[np.logical_not(np.isnan(y))]))
    
    x2 = np.append(x2, np.genfromtxt("Checkpoints_RANO/resnet_data/epoch_"+str(i)+"training_loss",delimiter=','))
    v2 = np.append(v2, np.mean(x2[np.logical_not(np.isnan(x2))]))
    
    y2 = np.append(y2, np.genfromtxt("Checkpoints_RANO/resnet_data/epoch_"+str(i)+"validation_loss",delimiter=','))
    b2 = np.append(b2, np.mean(y2[np.logical_not(np.isnan(y2))]))
    
    c = np.append(c, np.genfromtxt("Checkpoints_RANO/resnet_data/epoch_"+str(i)+"jaccard_index",delimiter=','))
    c1 = np.append(c1, np.mean(c[np.logical_not(np.isnan(c))]))
    
    z = np.append(z, np.genfromtxt("Checkpoints_RANO/Unet8_data/epoch_"+str(i)+"jaccard_index",delimiter=','))
    z1 = np.append(z1, np.mean(z[np.logical_not(np.isnan(z))]))
    
    u = np.append(u, np.genfromtxt("Checkpoints_RANO/resnet_data/epoch_"+str(i)+"validation_jaccard_index",delimiter=','))
    u1 = np.append(u1, np.mean(u[np.logical_not(np.isnan(u))]))
    
    o = np.append(o, np.genfromtxt("Checkpoints_RANO/Unet8_data/epoch_"+str(i)+"validation_jaccard_index",delimiter=','))
    o1 = np.append(o1, np.mean(o[np.logical_not(np.isnan(o))]))
    
ax = plt.subplot()

ax.plot(range(len(b)),b)
ax.plot(range(len(b2)),b2)

ax.legend(["val 1","val 2"])
plt.show()

plt.plot(range(len(v)),v)
plt.plot(range(len(v2)),v2)

plt.plot(range(len(b)),b)
plt.plot(range(len(b2)),b2)

plt.show()

ax = plt.subplot()
ax.plot(range(len(c1)),c1)
ax.plot(range(len(z1)),z1)

ax.legend(["val 1","val 2"])
#plt.plot(range(len(y6)),y6)
plt.show()

ax = plt.subplot()
ax.plot(range(len(u1)),u1)
ax.plot(range(len(o1)),o1)

ax.legend(["val 1","val 2"])
#plt.plot(range(len(y6)),y6)
plt.show()

import seaborn as sns
sns.set_theme()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

Train = np.genfromtxt("Checkpoints_RANO/Unet8_data/epoch_"+str(50-1)+"validation_jaccard_index",delimiter=',')
train2 = pd.DataFrame(data=Train, columns=range(1)).assign(Data="Train")

mdf = pd.melt(train2, id_vars=['Data'])

ax = sns.boxplot(x="Data", y="value", data=mdf)  # RUN PLOT 
plt.title("Unet_8 boxplot")  
plt.show()
ax = sns.violinplot(x="Data", y="value", data=mdf)  # RUN PLOT   
plt.title("Unet_8 violinplot")
plt.show()

Train0 = np.genfromtxt("Checkpoints_RANO/resnet_data/epoch_"+str(50-1)+"validation_jaccard_index",delimiter=',')
train3 = pd.DataFrame(data=Train0, columns=range(1)).assign(Data="Train")

mdf2 = pd.melt(train3, id_vars=['Data'])

ax = sns.boxplot(x="Data", y="value", data=mdf2)  # RUN PLOT  
plt.title("Resnet boxplot") 
plt.show()
ax = sns.violinplot(x="Data", y="value", data=mdf2)  # RUN PLOT   
plt.title("Resnet violinplot")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x ,y ,v ,b  = [],[],[],[]
x2,y2,v2,b2 = [],[],[],[]
c ,c1,z ,z1 = [],[],[],[]
u ,u1,o ,o1 = [],[],[],[]

for i in range(50):
    x = np.append(x, np.genfromtxt("Checkpoints_RANO/Unet8_data/epoch_"+str(i)+"training_loss",delimiter=','))
    v = np.append(v, np.mean(x[np.logical_not(np.isnan(x))]))
    
    y = np.append(y, np.genfromtxt("Checkpoints_RANO/Unet8_data/epoch_"+str(i)+"validation_loss",delimiter=','))
    b = np.append(b, np.mean(y[np.logical_not(np.isnan(y))]))
    
    x2 = np.append(x2, np.genfromtxt("Checkpoints_RANO/Unet_8_2_data/epoch_"+str(i)+"training_loss",delimiter=','))
    v2 = np.append(v2, np.mean(x2[np.logical_not(np.isnan(x2))]))
    
    y2 = np.append(y2, np.genfromtxt("Checkpoints_RANO/Unet_8_2_data/epoch_"+str(i)+"validation_loss",delimiter=','))
    b2 = np.append(b2, np.mean(y2[np.logical_not(np.isnan(y2))]))
    
    c = np.append(c, np.genfromtxt("Checkpoints_RANO/Unet_8_2_data/epoch_"+str(i)+"jaccard_index",delimiter=','))
    c1 = np.append(c1, np.mean(c[np.logical_not(np.isnan(c))]))
    
    z = np.append(z, np.genfromtxt("Checkpoints_RANO/Unet8_data/epoch_"+str(i)+"jaccard_index",delimiter=','))
    z1 = np.append(z1, np.mean(z[np.logical_not(np.isnan(z))]))
    
    u = np.append(u, np.genfromtxt("Checkpoints_RANO/Unet_8_2_data/epoch_"+str(i)+"validation_jaccard_index",delimiter=','))
    u1 = np.append(u1, np.mean(u[np.logical_not(np.isnan(u))]))
    
    o = np.append(o, np.genfromtxt("Checkpoints_RANO/Unet8_data/epoch_"+str(i)+"validation_jaccard_index",delimiter=','))
    o1 = np.append(o1, np.mean(o[np.logical_not(np.isnan(o))]))
    
    
ax = plt.subplot()

ax.plot(range(len(b)),b)
ax.plot(range(len(b2)),b2)

ax.legend(["net_1","net_2"])
plt.show()

plt.plot(range(len(v)),v)
plt.plot(range(len(v2)),v2)

plt.plot(range(len(b)),b)
plt.plot(range(len(b2)),b2)

plt.show()

ax = plt.subplot()
ax.plot(range(len(c1)),c1)
ax.plot(range(len(z1)),z1)

ax.legend(["net_2","net_1"])
#plt.plot(range(len(y6)),y6)
plt.show()

ax = plt.subplot()
ax.plot(range(len(u1)),u1)
ax.plot(range(len(o1)),o1)

ax.legend(["net_2","net_1"])
#plt.plot(range(len(y6)),y6)
plt.show()

import seaborn as sns
sns.set_theme()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

Train = np.genfromtxt("Checkpoints_RANO/Unet8_data/epoch_"+str(50-1)+"validation_jaccard_index",delimiter=',')
train2 = pd.DataFrame(data=Train, columns=range(1)).assign(Data="Train")

mdf = pd.melt(train2, id_vars=['Data'])

ax = sns.boxplot(x="Data", y="value", data=mdf)  # RUN PLOT 
plt.title("net_1 boxplot")  
plt.show()
ax = sns.violinplot(x="Data", y="value", data=mdf)  # RUN PLOT   
plt.title("net_1 violinplot")
plt.show()

Train0 = np.genfromtxt("Checkpoints_RANO/Unet_8_2_data/epoch_"+str(50-1)+"validation_jaccard_index",delimiter=',')
train3 = pd.DataFrame(data=Train0, columns=range(1)).assign(Data="Train")

mdf2 = pd.melt(train3, id_vars=['Data'])

ax = sns.boxplot(x="Data", y="value", data=mdf2)  # RUN PLOT  
plt.title("net_2 boxplot") 
plt.show()
ax = sns.violinplot(x="Data", y="value", data=mdf2)  # RUN PLOT   
plt.title("net_2 violinplot")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x ,y ,v ,b  = [],[],[],[]
x2,y2,v2,b2 = [],[],[],[]
c ,c1,z ,z1 = [],[],[],[]
u ,u1,o ,o1 = [],[],[],[]
x3,v3,y3,b3,c2,c3,u2,u3 = [],[],[],[],[],[],[],[]

for i in range(50):
    x = np.genfromtxt("Checkpoints_RANO/Unet_8_2_data/epoch_"+str(i)+"training_loss",delimiter=',')
    v = np.append(v, np.mean(x[np.logical_not(np.isnan(x))]))
    
    x2 = np.genfromtxt("Checkpoints_RANO/Unet_8_4_data/epoch_"+str(i)+"training_loss",delimiter=',')
    v2 = np.append(v2, np.mean(x2[np.logical_not(np.isnan(x2))]))
    
    x3 = np.genfromtxt("Checkpoints_RANO/Unet8_data/epoch_"+str(i)+"training_loss",delimiter=',')
    v3 = np.append(v3, np.mean(x3[np.logical_not(np.isnan(x3))]))
    
    y = np.genfromtxt("Checkpoints_RANO/Unet_8_2_data/epoch_"+str(i)+"validation_loss",delimiter=',')
    b = np.append(b, np.mean(y[np.logical_not(np.isnan(y))]))
    
    y2 = np.genfromtxt("Checkpoints_RANO/Unet_8_4_data/epoch_"+str(i)+"validation_loss",delimiter=',')
    b2 = np.append(b2, np.mean(y2[np.logical_not(np.isnan(y2))]))
    
    y3 = np.genfromtxt("Checkpoints_RANO/Unet8_data/epoch_"+str(i)+"validation_loss",delimiter=',')
    b3 = np.append(b3, np.mean(y3[np.logical_not(np.isnan(y3))]))
    
    z = np.genfromtxt("Checkpoints_RANO/Unet_8_2_data/epoch_"+str(i)+"jaccard_index",delimiter=',')
    z1 = np.append(z1, np.mean(z[np.logical_not(np.isnan(z))]))
    
    c = np.genfromtxt("Checkpoints_RANO/Unet_8_4_data/epoch_"+str(i)+"jaccard_index",delimiter=',')
    c1 = np.append(c1, np.mean(c[np.logical_not(np.isnan(c))]))
    
    c2 = np.genfromtxt("Checkpoints_RANO/Unet8_data/epoch_"+str(i)+"jaccard_index",delimiter=',')
    c3 = np.append(c3, np.mean(c2[np.logical_not(np.isnan(c2))]))
    
    o = np.genfromtxt("Checkpoints_RANO/Unet_8_2_data/epoch_"+str(i)+"validation_jaccard_index",delimiter=',')
    o1 = np.append(o1, np.mean(o[np.logical_not(np.isnan(o))]))
    
    u = np.genfromtxt("Checkpoints_RANO/Unet_8_4_data/epoch_"+str(i)+"validation_jaccard_index",delimiter=',')
    u1 = np.append(u1, np.mean(u[np.logical_not(np.isnan(u))]))
    
    u2 = np.genfromtxt("Checkpoints_RANO/Unet8_data/epoch_"+str(i)+"validation_jaccard_index",delimiter=',')
    u3 = np.append(u3, np.mean(u2[np.logical_not(np.isnan(u2))]))
    
ax = plt.subplot()

ax.plot(range(len(b3)),b3)
ax.plot(range(len(b)),b)
ax.plot(range(len(b2)),b2)

ax.legend(["No penalty","orthog","orthog+area"])
ax.set(xlabel = "Epoch", ylabel='MSE loss + penalty')
plt.title("Mean Validation Penalty Losses")
plt.show()

ax = plt.subplot()

ax.plot(range(len(b3)),b3)
ax.plot(range(len(b)),b)
ax.plot(range(len(b2)),b2)

ax.legend(["No penalty","orthog","orthog+area"])
ax.set(xlabel = "Epoch", ylabel='MSE loss + penalty')
plt.title("Mean Validation Penalty Losses")
plt.show()

ax = plt.subplot()
ax.plot(range(len(v3)),v3)
ax.plot(range(len(v)),v)
ax.plot(range(len(v2)),v2)

ax.plot(range(len(b3)),b3)
ax.plot(range(len(b)),b)
ax.plot(range(len(b2)),b2)

ax.legend(["train no penalty","train orthog","train orthog+area", "val no penalty", "val orthog", "val orthog+area"])
ax.set(xlabel = "Epoch", ylabel='MSE loss + penalty')
plt.title("Mean Training Penalty Losses")

plt.show()

ax = plt.subplot()
ax.plot(range(len(c3)),c3)
ax.plot(range(len(z1)),z1)
ax.plot(range(len(c1)),c1)

ax.legend(["no penalty","orthog","orthog+area"])
ax.set(xlabel = "Epoch", ylabel='Jaccard index score')
plt.title("Mean training penalty Jaccard score")
plt.show()

ax = plt.subplot()
ax.plot(range(len(u3)),u3)
ax.plot(range(len(o1)),o1)
ax.plot(range(len(u1)),u1)

ax.legend(["no penalty","orthog","orthog+area"])
ax.set(xlabel = "Epoch", ylabel='Jaccard index score')
plt.title("Mean validation penalty Jaccard score")
plt.show()

import seaborn as sns
sns.set_theme()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# basic model with no penalties
Val0 = np.genfromtxt("Checkpoints_RANO/Unet8_data/epoch_"+str(50-1)+"validation_jaccard_index",delimiter=',')
Val01 = np.genfromtxt("Checkpoints_RANO/Unet8_data/epoch_"+str(50-1)+"jaccard_index",delimiter=',')
val1 = pd.DataFrame(data=Val0, columns=range(1)).assign(Data="No penalty")
net_1 = pd.melt(val1, id_vars=['Data'])

# model introducing orthogonality penalty v1
Val2 = np.genfromtxt("Checkpoints_RANO/Unet_8_2_data/epoch_"+str(50-1)+"validation_jaccard_index",delimiter=',')
Val21 = np.genfromtxt("Checkpoints_RANO/Unet_8_2_data/epoch_"+str(50-1)+"jaccard_index",delimiter=',')
val3 = pd.DataFrame(data=Val2, columns=range(1)).assign(Data="Orthog penalty")
net_2 = pd.melt(val3, id_vars=['Data'])

# model introducing area penalty in additon to orthogonality penalty
Val4 = np.genfromtxt("Checkpoints_RANO/Unet_8_4_data/epoch_"+str(50-1)+"validation_jaccard_index",delimiter=',')
Val41 = np.genfromtxt("Checkpoints_RANO/Unet_8_4_data/epoch_"+str(50-1)+"jaccard_index",delimiter=',')
val5 = pd.DataFrame(data=Val4, columns=range(1)).assign(Data="Orthog + area penalty")
net_3 = pd.melt(val5, id_vars=['Data'])

validation_concat = pd.concat([val1, val3, val5])
validation_plots = pd.melt(validation_concat, id_vars=['Data'])

######################################

ax = sns.boxplot(x="Data", y="value", data=net_1)  # RUN PLOT  
ax.set(xlabel = "Distribution", ylabel='Jaccard Index Score')
plt.title("No Penalty model boxplot for output of 50th epoch") 
plt.show()
print("Full penalty mean training jaccard for epoch 50: ", np.mean(Val01[np.logical_not(np.isnan(Val01))]))
print("Full penalty mean validation jaccard for epoch 50: ", np.mean(Val0[np.logical_not(np.isnan(Val0))]))

##########

ax = sns.boxplot(x="Data", y="value", data=net_2)  # RUN PLOT 
ax.set(xlabel = "Distribution", ylabel='Jaccard Index Score')
plt.title("Orthogonality Penalty model boxplot for output of 50th epoch") 
plt.show()
print("Full penalty mean training jaccard for epoch 50: ", np.mean(Val21[np.logical_not(np.isnan(Val21))]))
print("Full penalty mean validation jaccard for epoch 50: ", np.mean(Val2[np.logical_not(np.isnan(Val2))]))

##########

ax = sns.boxplot(x="Data", y="value", data=net_3)  # RUN PLOT  
ax.set(xlabel = "Distribution", ylabel='Jaccard Index Score')
plt.title("Area and Orthogonality Penalty model boxplot for output of 50th epoch") 
plt.show()
print("Full penalty mean training jaccard for epoch 50: ", np.mean(Val41[np.logical_not(np.isnan(Val41))]))
print("Full penalty mean validation jaccard for epoch 50: ", np.mean(Val4[np.logical_not(np.isnan(Val4))]))

##########


######################################

ax = sns.violinplot(x="Data", y="value", data=net_1)  # RUN PLOT   
ax.set(xlabel = "Distribution", ylabel='Jaccard Index Score')
plt.title("No Penalty model violin plot for output of 50th epoch") 
plt.show()

ax = sns.violinplot(x="Data", y="value", data=net_2)  # RUN PLOT   
ax.set(xlabel = "Distribution", ylabel='Jaccard Index Score')
plt.title("Orthogonality Penalty model violin plot for output of 50th epoch") 
plt.show()

ax = sns.violinplot(x="Data", y="value", data=net_3)  # RUN PLOT   
ax.set(xlabel = "Distribution", ylabel='Jaccard Index Score')
plt.title("Area and Orthogonality Penalty model violin plot for output of 50th epoch") 
plt.show()


######################################

ax = sns.boxplot(x="Data", y="value", data=validation_plots)  # RUN PLOT  
plt.title("Comparison boxplots 50th epoch, No penalty, orthog, orthog + area") 
ax.set(xlabel = "Distribution", ylabel='Jaccard Index Score')
plt.show()

ax = sns.violinplot(x="Data", y="value", data=validation_plots)  # RUN PLOT   
plt.title("Comparison violin plot 50th epoch, No penalty, orthog, orthog + area") 
ax.set(xlabel = "Distribution", ylabel='Jaccard Index Score')
plt.show()

# they end up at a similar quantitative output for the jaccard scroe but it isthe distribution that differs
# Out:
# Full penalty mean training jaccard for epoch 50:  0.45224319735194796
# Full penalty mean validation jaccard for epoch 50:  0.2866850002887229
# Full penalty mean training jaccard for epoch 50:  0.49002414914477627
# Full penalty mean validation jaccard for epoch 50:  0.29520842538167585
# Full penalty mean training jaccard for epoch 50:  0.30025202905244175
# Full penalty mean validation jaccard for epoch 50:  0.30025202905244175

# %%
# import numpy as np
# import matplotlib.pyplot as plt

# x ,y ,v ,b  = [],[],[],[]
# x2,y2,v2,b2 = [],[],[],[]
# c ,c1,z ,z1 = [],[],[],[]
# u ,u1,o ,o1 = [],[],[],[]

# for i in range(50):
#     x = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8_O0A0/epoch_"+str(i)+"training_loss",delimiter=',')
#     v = np.append(v, np.mean(x[np.logical_not(np.isnan(x))]))
    
#     y = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8_O0A0/epoch_"+str(i)+"validation_loss",delimiter=',')
#     b = np.append(b, np.mean(y[np.logical_not(np.isnan(y))]))
    
#     x2 = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8/epoch_"+str(i)+"training_loss",delimiter=',')
#     v2 = np.append(v2, np.mean(x2[np.logical_not(np.isnan(x2))]))
    
#     y2 = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8/epoch_"+str(i)+"validation_loss",delimiter=',')
#     b2 = np.append(b2, np.mean(y2[np.logical_not(np.isnan(y2))]))
    
#     c = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8/epoch_"+str(i)+"jaccard_index",delimiter=',')
#     c1 = np.append(c1, np.mean(c[np.logical_not(np.isnan(c))]))
    
#     z = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8_O0A0/epoch_"+str(i)+"jaccard_index",delimiter=',')
#     z1 = np.append(z1, np.mean(z[np.logical_not(np.isnan(z))]))
    
#     u = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8/epoch_"+str(i)+"validation_jaccard_index",delimiter=',')
#     u1 = np.append(u1, np.mean(u[np.logical_not(np.isnan(u))]))
    
#     o = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8_O0A0/epoch_"+str(i)+"validation_jaccard_index",delimiter=',')
#     o1 = np.append(o1, np.mean(o[np.logical_not(np.isnan(o))]))
    
    
# ax = plt.subplot()

# ax.plot(range(len(b)),b)
# ax.plot(range(len(b2)),b2)

# ax.legend(["net_1","net_2"])
# plt.show()

# plt.plot(range(len(v)),v)
# plt.plot(range(len(v2)),v2)

# plt.plot(range(len(b)),b)
# plt.plot(range(len(b2)),b2)

# plt.show()

# ax = plt.subplot()
# ax.plot(range(len(c1)),c1)
# ax.plot(range(len(z1)),z1)

# ax.legend(["net_2","net_1"])
# #plt.plot(range(len(y6)),y6)
# plt.show()

# ax = plt.subplot()
# ax.plot(range(len(u1)),u1)
# ax.plot(range(len(o1)),o1)

# ax.legend(["net_2","net_1"])
# #plt.plot(range(len(y6)),y6)
# plt.show()

# import seaborn as sns
# sns.set_theme()
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt

# Train = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8_O0A0/epoch_"+str(50-1)+"validation_jaccard_index",delimiter=',')
# train2 = pd.DataFrame(data=Train, columns=range(1)).assign(Data="Train")

# mdf = pd.melt(train2, id_vars=['Data'])

# ax = sns.boxplot(x="Data", y="value", data=mdf)  # RUN PLOT 
# plt.title("net_1 boxplot")  
# plt.show()
# ax = sns.violinplot(x="Data", y="value", data=mdf)  # RUN PLOT   
# plt.title("net_1 violinplot")
# plt.show()

# Train0 = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8/epoch_"+str(50-1)+"validation_jaccard_index",delimiter=',')
# train3 = pd.DataFrame(data=Train0, columns=range(1)).assign(Data="Train")

# mdf2 = pd.melt(train3, id_vars=['Data'])

# ax = sns.boxplot(x="Data", y="value", data=mdf2)  # RUN PLOT  
# plt.title("net_2 boxplot") 
# plt.show()
# ax = sns.violinplot(x="Data", y="value", data=mdf2)  # RUN PLOT   
# plt.title("net_2 violinplot")
# plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
import pandas as pd

Training_loss_base ,Training_loss_Nan_base ,Validation_loss_base ,Validation_loss_Nan_base  = [],[],[],[]
Training_loss_Penal,Training_loss_Nan_Penal,Validation_loss_Penal,Validation_loss_Nan_Penal = [],[],[],[]

Training_Jaccard_base ,Training_Jaccard_Nan_base ,Validation_Jaccard_base , Validation_Jaccard_Nan_base  = [],[],[],[]
Training_Jaccard_Penal,Training_Jaccard_Nan_Penal,Validation_Jaccard_Penal ,Validation_Jaccard_Nan_Penal = [],[],[],[]

for i in range(50):
    Training_loss_base = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8_O0A0/epoch_"+str(i)+"training_loss",delimiter=',')
    Training_loss_Nan_base = np.append(Training_loss_Nan_base, np.mean(Training_loss_base[np.logical_not(np.isnan(Training_loss_base))]))
    
    Validation_loss_base = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8_O0A0/epoch_"+str(i)+"validation_loss",delimiter=',')
    Validation_loss_Nan_base = np.append(Validation_loss_Nan_base, np.mean(Validation_loss_base[np.logical_not(np.isnan(Validation_loss_base))]))
    
    Training_loss_Penal = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8/epoch_"+str(i)+"training_loss",delimiter=',')
    Training_loss_Nan_Penal = np.append(Training_loss_Nan_Penal, np.mean(Training_loss_Penal[np.logical_not(np.isnan(Training_loss_Penal))]))
    
    Validation_loss_Penal = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8/epoch_"+str(i)+"validation_loss",delimiter=',')
    Validation_loss_Nan_Penal = np.append(Validation_loss_Nan_Penal, np.mean(Validation_loss_Penal[np.logical_not(np.isnan(Validation_loss_Penal))]))
    
    Training_Jaccard_base = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8_O0A0/epoch_"+str(i)+"jaccard_index",delimiter=',')
    Training_Jaccard_Nan_base = np.append(Training_Jaccard_Nan_base, np.mean(Training_Jaccard_base[np.logical_not(np.isnan(Training_Jaccard_base))]))
    
    Validation_Jaccard_base = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8_O0A0/epoch_"+str(i)+"validation_jaccard_index",delimiter=',')
    Validation_Jaccard_Nan_base = np.append(Validation_Jaccard_Nan_base, np.mean(Validation_Jaccard_base[np.logical_not(np.isnan(Validation_Jaccard_base))]))
    
    Training_Jaccard_Penal = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8/epoch_"+str(i)+"jaccard_index",delimiter=',')
    Training_Jaccard_Nan_Penal = np.append(Training_Jaccard_Nan_Penal, np.mean(Training_Jaccard_Penal[np.logical_not(np.isnan(Training_Jaccard_Penal))]))
    
    Validation_Jaccard_Penal = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8/epoch_"+str(i)+"validation_jaccard_index",delimiter=',')
    Validation_Jaccard_Nan_Penal = np.append(Validation_Jaccard_Nan_Penal, np.mean(Validation_Jaccard_Penal[np.logical_not(np.isnan(Validation_Jaccard_Penal))]))
    
    
print("validation penalty model jaccard: ", Validation_Jaccard_Nan_Penal)
print("validation no penalty model jaccard: ",Validation_Jaccard_Nan_base) 
print()
print("validation penalty model loss: ", Validation_loss_Nan_Penal)
print("validation no penalty model loss: ",Validation_loss_Nan_base)  

ax = plt.subplot()
ax.plot(range(len(Training_loss_Nan_base )),Training_loss_Nan_base )
ax.plot(range(len(Training_loss_Nan_Penal)),Training_loss_Nan_Penal)
plt.title("Mean Training loss per epoch ")
ax.legend(["base model","penalty model"])
ax.set(xlabel = "Epoch", ylabel='MSE loss + penalty')
plt.show()    
    
ax = plt.subplot()
ax.plot(range(len(Validation_loss_Nan_base )),Validation_loss_Nan_base )
ax.plot(range(len(Validation_loss_Nan_Penal)),Validation_loss_Nan_Penal)
plt.title("Mean Validation loss per epoch ")
ax.legend(["base model","penalty model"])
ax.set(xlabel = "Epoch", ylabel='MSE loss + penalty')
plt.show()

ax = plt.subplot()
ax.plot(range(len(Training_Jaccard_Nan_base )),Training_Jaccard_Nan_base )
ax.plot(range(len(Training_Jaccard_Nan_Penal)),Training_Jaccard_Nan_Penal)
plt.title("Mean Training jaccard per epoch ")
ax.legend(["base model","penalty model"])
ax.set(xlabel = "Epoch", ylabel='Jaccard Index score')
plt.show()

ax = plt.subplot()
ax.plot(range(len(Validation_Jaccard_Nan_base)),Validation_Jaccard_Nan_base)
ax.plot(range(len(Validation_Jaccard_Nan_Penal)),Validation_Jaccard_Nan_Penal)
plt.title("Mean Validation jaccard per epoch ")
ax.legend(["base model","penalty model"])
ax.set(xlabel = "Epoch", ylabel='Jaccard Index score')
plt.show()

##################################################################################################################
##################################################################################################################

Val0 = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8_O0A0/epoch_"+str(50-1)+"validation_jaccard_index",delimiter=',')
Val01 = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8_O0A0/epoch_"+str(50-1)+"jaccard_index",delimiter=',')
val1 = pd.DataFrame(data=Val0, columns=range(1)).assign(Distribution="No penalty")
net_1 = pd.melt(val1, id_vars=['Distribution'])

Val2 = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8/epoch_"+str(50-1)+"validation_jaccard_index",delimiter=',')
Val21 = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8/epoch_"+str(50-1)+"jaccard_index",delimiter=',')
val3 = pd.DataFrame(data=Val2, columns=range(1)).assign(Distribution="Full penalty")
net_2 = pd.melt(val3, id_vars=['Distribution'])

validation_concat = pd.concat([val1, val3])
validation_plots = pd.melt(validation_concat, id_vars=['Distribution'])

######################################

ax = sns.boxplot(x="Distribution", y="value", data=net_1)  # RUN PLOT  
plt.title("No Penalty model boxplot for output of 50th epoch") 
ax.set(ylabel='Jaccard Index score')
plt.show()
print("No penalty mean training jaccard for epoch 50: ", np.mean(Val01[np.logical_not(np.isnan(Val01))]))
print("No penalty mean validation jaccard for epoch 50: ", np.mean(Val0[np.logical_not(np.isnan(Val0))]))

ax = sns.boxplot(x="Distribution", y="value", data=net_2)  # RUN PLOT 
plt.title("Full Penalty model boxplot for output of 50th epoch") 
ax.set(ylabel='Jaccard Index score')
plt.show()
print("Full penalty mean training jaccard for epoch 50: ", np.mean(Val21[np.logical_not(np.isnan(Val21))]))
print("Full penalty mean validation jaccard for epoch 50: ", np.mean(Val2[np.logical_not(np.isnan(Val2))]))

######################################

ax = sns.violinplot(x="Distribution", y="value", data=net_1)  # RUN PLOT   
plt.title("No Penalty model violinplot for output of 50th epoch") 
ax.set(ylabel='Jaccard Index score')
plt.show()

ax = sns.violinplot(x="Distribution", y="value", data=net_2)  # RUN PLOT   
plt.title("Full Penalty model violinplot for output of 50th epoch") 
ax.set(ylabel='Jaccard Index score')
plt.show()

######################################

ax = sns.boxplot(x="Distribution", y="value", data=validation_plots)  # RUN PLOT  
plt.title("Comparison boxplots 50th epoch, No penalty (left) vs Full penalty (right)") 
ax.set(ylabel='Jaccard Index score')
plt.show()

ax = sns.violinplot(x="Distribution", y="value", data=validation_plots)  # RUN PLOT   
plt.title("Comparison violinplots 50th epoch, No penalty (left) vs Full penalty (right)") 
ax.set(ylabel='Jaccard Index score')
plt.show()
# Out:
# validation penalty model jaccard:  [0.10079785 0.17009075 0.1305654  0.05739111 0.11903827 0.16390344
#  0.14784886 0.16979243 0.18413964 0.24833454 0.21688365 0.21806855
#  0.2776464  0.19930029 0.20668031 0.21565822 0.22765822 0.22558941
#  0.20353513 0.21925312 0.22573861 0.22055989 0.23867727 0.24266248
#  0.24532499 0.26017411 0.20676862 0.27325036 0.21506061 0.26511483
#  0.24327877 0.23703819 0.26656635 0.27716053 0.26781927 0.2734636
#  0.23483921 0.28697981 0.27113364 0.28458485 0.2648012  0.24138244
#  0.30204815 0.30952388 0.28126338 0.30507001 0.28296417 0.29407084
#  0.30069099 0.30693012]
# validation no penalty model jaccard:  [0.07123513 0.13411384 0.09903532 0.15154715 0.13670966 0.19197617
#  0.22055775 0.16563825 0.20872652 0.15503637 0.2083967  0.20584953
#  0.19136077 0.24564973 0.18861416 0.21665108 0.20871152 0.21061541
#  0.28759094 0.23443072 0.2442555  0.26604165 0.22143779 0.22605578
#  0.21290187 0.24882613 0.26847431 0.23902997 0.24862071 0.24484235
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
import pandas as pd

Training_loss_Penal,Training_loss_Nan_Penal,Validation_loss_Penal,Validation_loss_Nan_Penal = [],[],[],[]

Training_Jaccard_Penal,Training_Jaccard_Nan_Penal,Validation_Jaccard_Penal ,Validation_Jaccard_Nan_Penal = [],[],[],[]
Training_Jaccard_Penal2,Training_Jaccard_Nan_Penal2,Validation_Jaccard_Penal2 ,Validation_Jaccard_Nan_Penal2 = [],[],[],[]

for i in range(500):
    Training_loss_Penal = np.genfromtxt("Checkpoints_RANO/Unet_H16_M9_O10A0_LONGTERM/Training_loss/epoch_"+str(i)+"training_loss.csv",delimiter=',')
    Training_loss_Nan_Penal = np.append(Training_loss_Nan_Penal, np.mean(Training_loss_Penal[np.logical_not(np.isnan(Training_loss_Penal))]))
    
    Validation_loss_Penal = np.genfromtxt("Checkpoints_RANO/Unet_H16_M9_O10A0_LONGTERM/Validation_loss/epoch_"+str(i)+"validation_loss.csv",delimiter=',')
    Validation_loss_Nan_Penal = np.append(Validation_loss_Nan_Penal, np.mean(Validation_loss_Penal[np.logical_not(np.isnan(Validation_loss_Penal))]))

    Training_Jaccard_Penal = np.genfromtxt("Checkpoints_RANO/Unet_H16_M9_O10A0_LONGTERM/Training_Jaccard/epoch_"+str(i)+"jaccard_index.csv",delimiter=',')
    Training_Jaccard_Nan_Penal = np.append(Training_Jaccard_Nan_Penal, np.mean(Training_Jaccard_Penal[np.logical_not(np.isnan(Training_Jaccard_Penal))]))
    
    Validation_Jaccard_Penal = np.genfromtxt("Checkpoints_RANO/Unet_H16_M9_O10A0_LONGTERM/Validation_Jaccard/epoch_"+str(i)+"validation_jaccard_index.csv",delimiter=',')
    Validation_Jaccard_Nan_Penal = np.append(Validation_Jaccard_Nan_Penal, np.mean(Validation_Jaccard_Penal[np.logical_not(np.isnan(Validation_Jaccard_Penal))]))

Validation_Jaccard_Penal2 = np.genfromtxt("Checkpoints_RANO/Unet_H16_M9_O10A0_LONGTERM/Validation_Jaccard/epoch_269validation_jaccard_index.csv",delimiter=',')
Validation_Jaccard_Nan_Penal2 = np.append(Validation_Jaccard_Nan_Penal2, Validation_Jaccard_Penal2[np.logical_not(np.isnan(Validation_Jaccard_Penal2))])
    
print("validation penalty model jaccard: ", Validation_Jaccard_Nan_Penal)
print()
print("validation penalty model loss: ", Validation_loss_Nan_Penal)

ax = plt.subplot()
ax.plot(range(len(Training_loss_Nan_Penal)),Training_loss_Nan_Penal)
plt.title("Mean Training loss per epoch ")
ax.legend(["base model","penalty model"])
ax.set(xlabel = "Epoch", ylabel='MSE loss + penalty')
plt.show()    
    
ax = plt.subplot()
ax.plot(range(len(Validation_loss_Nan_Penal)),Validation_loss_Nan_Penal)
plt.title("Mean Validation loss per epoch ")
ax.legend(["base model","penalty model"])
ax.set(xlabel = "Epoch", ylabel='MSE loss + penalty')
plt.show()

ax = plt.subplot()
ax.plot(range(len(Training_Jaccard_Nan_Penal)),Training_Jaccard_Nan_Penal)
plt.title("Mean Training jaccard per epoch ")
ax.legend(["base model","penalty model"])
ax.set(xlabel = "Epoch", ylabel='Jaccard Index score')
plt.show()

ax = plt.subplot()
ax.plot(range(len(Validation_Jaccard_Nan_Penal)),Validation_Jaccard_Nan_Penal)
plt.title("Mean Validation jaccard per epoch ")
ax.legend(["base model","penalty model"])
ax.set(xlabel = "Epoch", ylabel='Jaccard Index score')
plt.show()

val3 = pd.DataFrame(data=Validation_Jaccard_Nan_Penal2, columns=range(1)).assign(Distribution="Full penalty")
net_2 = pd.melt(val3, id_vars=['Distribution'])

######################################

ax = sns.boxplot(x="Distribution", y="value", data=net_2)  # RUN PLOT  
ax.set(ylabel='Jaccard Index score')
plt.show()
ax = sns.violinplot(x="Distribution", y="value", data=net_2)  # RUN PLOT  
ax.set(ylabel='Jaccard Index score')
plt.show()
# Out:
# validation penalty model jaccard:  [0.13273096 0.13564872 0.19537282 0.14385097 0.18166973 0.16330984
#  0.26619723 0.20012007 0.25095977 0.22661692 0.15634982 0.19244034
#  0.18018325 0.17591737 0.19480408 0.16098265 0.15753228 0.20145798
#  0.21776375 0.24668254 0.21960113 0.21641255 0.27350326 0.22780782
#  0.18190277 0.25104825 0.21824984 0.2229298  0.25986913 0.25722949
#  0.22651843 0.25602179 0.27476226 0.2362722  0.23877296 0.23584974
#  0.29857715 0.2638484  0.23388687 0.29022482 0.23541656 0.27391626
#  0.26244604 0.26830996 0.29741582 0.26931203 0.25891155 0.27095121
#  0.27620458 0.27919816 0.30161821 0.26366054 0.25226605 0.27803521
#  0.28639703 0.30349153 0.28721332 0.29024194 0.29492138 0.23309903
#  0.29509073 0.32784343 0.26587239 0.28297145 0.30680094 0.29090796
#  0.2186132  0.30021103 0.30627796 0.28891121 0.29388566 0.29359368
#  0.30099755 0.29095892 0.26240646 0.29525899 0.29946308 0.31378083
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
import pandas as pd

Training_loss_Penal,Training_loss_Nan_Penal,Validation_loss_Penal,Validation_loss_Nan_Penal = [],[],[],[]

Training_Jaccard_Penal,Training_Jaccard_Nan_Penal,Validation_Jaccard_Penal ,Validation_Jaccard_Nan_Penal = [],[],[],[]
Training_Jaccard_Penal2,Training_Jaccard_Nan_Penal2,Validation_Jaccard_Penal2 ,Validation_Jaccard_Nan_Penal2 = [],[],[],[]

for i in range(10):
    Training_loss_Penal = np.genfromtxt("Checkpoints_RANO/Unet_H16_M9_O10A100/Training_loss/epoch_"+str(i)+"training_loss.csv",delimiter=',')
    Training_loss_Nan_Penal = np.append(Training_loss_Nan_Penal, np.mean(Training_loss_Penal[np.logical_not(np.isnan(Training_loss_Penal))]))
    
    Validation_loss_Penal = np.genfromtxt("Checkpoints_RANO/Unet_H16_M9_O10A100/Validation_loss/epoch_"+str(i)+"validation_loss.csv",delimiter=',')
    Validation_loss_Nan_Penal = np.append(Validation_loss_Nan_Penal, np.mean(Validation_loss_Penal[np.logical_not(np.isnan(Validation_loss_Penal))]))

    Training_Jaccard_Penal = np.genfromtxt("Checkpoints_RANO/Unet_H16_M9_O10A100/Training_Jaccard/epoch_"+str(i)+"jaccard_index.csv",delimiter=',')
    Training_Jaccard_Nan_Penal = np.append(Training_Jaccard_Nan_Penal, np.mean(Training_Jaccard_Penal[np.logical_not(np.isnan(Training_Jaccard_Penal))]))
    
    Validation_Jaccard_Penal = np.genfromtxt("Checkpoints_RANO/Unet_H16_M9_O10A100/Validation_Jaccard/epoch_"+str(i)+"validation_jaccard_index.csv",delimiter=',')
    print(np.nanmax(Validation_Jaccard_Penal))
    Validation_Jaccard_Nan_Penal = np.append(Validation_Jaccard_Nan_Penal, np.mean(Validation_Jaccard_Penal[np.logical_not(np.isnan(Validation_Jaccard_Penal))]))

Validation_Jaccard_Penal2 = np.genfromtxt("Checkpoints_RANO/Unet_H16_M9_O10A100/Validation_Jaccard/epoch_10validation_jaccard_index.csv",delimiter=',')
Validation_Jaccard_Nan_Penal2 = np.append(Validation_Jaccard_Nan_Penal2, Validation_Jaccard_Penal2[np.logical_not(np.isnan(Validation_Jaccard_Penal2))])
    
    
print("validation penalty model jaccard: ", Validation_Jaccard_Nan_Penal)
print()
print("validation penalty model loss: ", Validation_loss_Nan_Penal)

ax = plt.subplot()
ax.plot(range(len(Training_loss_Nan_Penal)),Training_loss_Nan_Penal)
plt.title("Mean Training loss per epoch ")
ax.legend(["base model","penalty model"])
ax.set(xlabel = "Epoch", ylabel='MSE loss + penalty')
plt.show()    
    
ax = plt.subplot()
ax.plot(range(len(Validation_loss_Nan_Penal)),Validation_loss_Nan_Penal)
plt.title("Mean Validation loss per epoch ")
ax.legend(["base model","penalty model"])
ax.set(xlabel = "Epoch", ylabel='MSE loss + penalty')
plt.show()

ax = plt.subplot()
ax.plot(range(len(Training_Jaccard_Nan_Penal)),Training_Jaccard_Nan_Penal)
plt.title("Mean Training jaccard per epoch ")
ax.legend(["base model","penalty model"])
ax.set(xlabel = "Epoch", ylabel='Jaccard Index score')
plt.show()

ax = plt.subplot()
ax.plot(range(len(Validation_Jaccard_Nan_Penal)),Validation_Jaccard_Nan_Penal)
plt.title("Mean Validation jaccard per epoch ")
ax.legend(["base model","penalty model"])
ax.set(xlabel = "Epoch", ylabel='Jaccard Index score')
plt.show()

val3 = pd.DataFrame(data=Validation_Jaccard_Nan_Penal2, columns=range(1)).assign(Distribution="Full penalty")
net_2 = pd.melt(val3, id_vars=['Distribution'])

######################################

ax = sns.boxplot(x="Distribution", y="value", data=net_2)  # RUN PLOT  
plt.title("No Penalty model boxplot for output of 50th epoch") 
ax.set(ylabel='Jaccard Index score')
plt.show()
ax = sns.violinplot(x="Distribution", y="value", data=net_2)  # RUN PLOT  
plt.title("No Penalty model boxplot for output of 50th epoch") 
ax.set(ylabel='Jaccard Index score')
plt.show()
# Out:
# 0.6414574402939376
# 0.7397521448999047
# 0.7141382868937048
# 0.7417355371900827
# 0.6710526315789473
# 0.7327223185533812
# 0.8926516157591855
# 0.8230138535482047
# 0.8558836491846629
# 0.8198469742638534
# validation penalty model jaccard:  [0.1338621  0.13640013 0.1922857  0.14018555 0.17847051 0.16121382
#  0.26365699 0.20760846 0.24131554 0.22340903]
#
# validation penalty model loss:  [1135.4164882  1222.36022214 1008.11797318 1170.76381888 1073.89284915
#  1183.50881356 1001.98314914 1079.7294389  1036.7724237  1073.64090129]

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
import pandas as pd

Training_loss_base ,Training_loss_Nan_base ,Validation_loss_base ,Validation_loss_Nan_base  = [],[],[],[]
Training_loss_Penal,Training_loss_Nan_Penal,Validation_loss_Penal,Validation_loss_Nan_Penal = [],[],[],[]

Training_Jaccard_base ,Training_Jaccard_Nan_base ,Validation_Jaccard_base , Validation_Jaccard_Nan_base  = [],[],[],[]
Training_Jaccard_Penal,Training_Jaccard_Nan_Penal,Validation_Jaccard_Penal ,Validation_Jaccard_Nan_Penal = [],[],[],[]

for i in range(100):
    Training_loss_base = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8_O4A10/epoch_"+str(i)+"training_loss",delimiter=',')
    Training_loss_Nan_base = np.append(Training_loss_Nan_base, np.mean(Training_loss_base[np.logical_not(np.isnan(Training_loss_base))]))
    
    Validation_loss_base = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8_O4A10/epoch_"+str(i)+"validation_loss",delimiter=',')
    Validation_loss_Nan_base = np.append(Validation_loss_Nan_base, np.mean(Validation_loss_base[np.logical_not(np.isnan(Validation_loss_base))]))

    Training_Jaccard_base = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8_O4A10/epoch_"+str(i)+"jaccard_index",delimiter=',')
    Training_Jaccard_Nan_base = np.append(Training_Jaccard_Nan_base, np.mean(Training_Jaccard_base[np.logical_not(np.isnan(Training_Jaccard_base))]))
    
    Validation_Jaccard_base = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8_O4A10/epoch_"+str(i)+"validation_jaccard_index",delimiter=',')
    Validation_Jaccard_Nan_base = np.append(Validation_Jaccard_Nan_base, np.mean(Validation_Jaccard_base[np.logical_not(np.isnan(Validation_Jaccard_base))]))


print("validation no penalty model jaccard: ",Validation_Jaccard_Nan_base) 
print()
print("validation no penalty model loss: ",Validation_loss_Nan_base)  

ax = plt.subplot()
ax.plot(range(len(Training_loss_Nan_base )),Training_loss_Nan_base )
#ax.plot(range(len(Training_loss_Nan_Penal)),Training_loss_Nan_Penal)
plt.title("Mean Training loss per epoch ")
ax.legend(["base model","penalty model"])
ax.set(xlabel = "Epoch", ylabel='MSE loss + penalty')
plt.show()    
    
ax = plt.subplot()
ax.plot(range(len(Validation_loss_Nan_base )),Validation_loss_Nan_base )
#ax.plot(range(len(Validation_loss_Nan_Penal)),Validation_loss_Nan_Penal)
plt.title("Mean Validation loss per epoch ")
ax.legend(["base model","penalty model"])
ax.set(xlabel = "Epoch", ylabel='MSE loss + penalty')
plt.show()

ax = plt.subplot()
ax.plot(range(len(Training_Jaccard_Nan_base )),Training_Jaccard_Nan_base )
#ax.plot(range(len(Training_Jaccard_Nan_Penal)),Training_Jaccard_Nan_Penal)
plt.title("Mean Training jaccard per epoch ")
ax.legend(["base model","penalty model"])
ax.set(xlabel = "Epoch", ylabel='Jaccard Index score')
plt.show()

ax = plt.subplot()
ax.plot(range(len(Validation_Jaccard_Nan_base)),Validation_Jaccard_Nan_base)
#ax.plot(range(len(Validation_Jaccard_Nan_Penal)),Validation_Jaccard_Nan_Penal)
plt.title("Mean Validation jaccard per epoch ")
ax.legend(["base model","penalty model"])
ax.set(xlabel = "Epoch", ylabel='Jaccard Index score')
plt.show()

##################################################################################################################
##################################################################################################################
# Out:
# validation no penalty model jaccard:  [0.12852627 0.17444844 0.23785179 0.15061653 0.20132613 0.13427932
#  0.18201018 0.13873793 0.1841996  0.22808768 0.18298905 0.20967756
#  0.21136378 0.19279169 0.19723172 0.19631008 0.19785515 0.21657984
#  0.24779388 0.20634045 0.25697254 0.22979127 0.23807253 0.24879712
#  0.22522061 0.21805745 0.24167605 0.25558775 0.23691128 0.2460287
#  0.25349684 0.259415   0.26912091 0.26589124 0.2897585  0.25460151
#  0.25343977 0.2263074  0.26510635 0.2850992  0.28309229 0.27539259
#  0.27572936 0.29051856 0.23375587 0.28529785 0.28144989 0.30237191
#  0.3121898  0.29639111 0.28071389 0.26631259 0.29313721 0.27332029
#  0.30167869 0.25134208 0.27353876 0.29101166 0.29894545 0.32998796
#  0.29943595 0.2671748  0.29611796 0.30713636 0.30008631 0.31339908
#  0.31151959 0.3083988  0.30024863 0.2813306  0.28713695 0.28920187
#  0.30897059 0.30149863 0.30935776 0.32437405 0.29630999 0.29188136
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
import pandas as pd

Training_loss_base ,Training_loss_Nan_base ,Validation_loss_base ,Validation_loss_Nan_base  = [],[],[],[]
Training_loss_Penal,Training_loss_Nan_Penal,Validation_loss_Penal,Validation_loss_Nan_Penal = [],[],[],[]

Training_Jaccard_base ,Training_Jaccard_Nan_base ,Validation_Jaccard_base , Validation_Jaccard_Nan_base  = [],[],[],[]
Training_Jaccard_Penal,Training_Jaccard_Nan_Penal,Validation_Jaccard_Penal ,Validation_Jaccard_Nan_Penal = [],[],[],[]

for i in range(100):
    Training_loss_base = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8_O4A10/epoch_"+str(i)+"training_loss",delimiter=',')
    Training_loss_Nan_base = np.append(Training_loss_Nan_base, np.mean(Training_loss_base[np.logical_not(np.isnan(Training_loss_base))]))
    
    Validation_loss_base = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8_O4A10/epoch_"+str(i)+"validation_loss",delimiter=',')
    Validation_loss_Nan_base = np.append(Validation_loss_Nan_base, np.mean(Validation_loss_base[np.logical_not(np.isnan(Validation_loss_base))]))

    Training_Jaccard_base = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8_O4A10/epoch_"+str(i)+"jaccard_index",delimiter=',')
    Training_Jaccard_Nan_base = np.append(Training_Jaccard_Nan_base, np.mean(Training_Jaccard_base[np.logical_not(np.isnan(Training_Jaccard_base))]))
    
    Validation_Jaccard_base = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8_O4A10/epoch_"+str(i)+"validation_jaccard_index",delimiter=',')
    Validation_Jaccard_Nan_base = np.append(Validation_Jaccard_Nan_base, np.mean(Validation_Jaccard_base[np.logical_not(np.isnan(Validation_Jaccard_base))]))


print("validation no penalty model jaccard: ",Validation_Jaccard_Nan_base) 
print()
print("validation no penalty model loss: ",Validation_loss_Nan_base)  

ax = plt.subplot()
ax.plot(range(len(Training_loss_Nan_base )),Training_loss_Nan_base )
#ax.plot(range(len(Training_loss_Nan_Penal)),Training_loss_Nan_Penal)
plt.title("Mean Training loss per epoch ")
ax.legend(["base model","penalty model"])
ax.set(xlabel = "Epoch", ylabel='MSE loss + penalty')
plt.show()    
    
ax = plt.subplot()
ax.plot(range(len(Validation_loss_Nan_base )),Validation_loss_Nan_base )
#ax.plot(range(len(Validation_loss_Nan_Penal)),Validation_loss_Nan_Penal)
plt.title("Mean Validation loss per epoch ")
ax.legend(["base model","penalty model"])
ax.set(xlabel = "Epoch", ylabel='MSE loss + penalty')
plt.show()

ax = plt.subplot()
ax.plot(range(len(Training_Jaccard_Nan_base )),Training_Jaccard_Nan_base )
#ax.plot(range(len(Training_Jaccard_Nan_Penal)),Training_Jaccard_Nan_Penal)
plt.title("Mean Training jaccard per epoch ")
ax.legend(["base model","penalty model"])
ax.set(xlabel = "Epoch", ylabel='Jaccard Index score')
plt.show()

ax = plt.subplot()
ax.plot(range(len(Validation_Jaccard_Nan_base)),Validation_Jaccard_Nan_base)
#ax.plot(range(len(Validation_Jaccard_Nan_Penal)),Validation_Jaccard_Nan_Penal)
plt.title("Mean Validation jaccard per epoch ")
ax.legend(["base model","penalty model"])
ax.set(xlabel = "Epoch", ylabel='Jaccard Index score')
plt.show()

##################################################################################################################
##################################################################################################################

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
import pandas as pd

x ,y ,v ,b  = [],[],[],[]
x2,y2,v2,b2 = [],[],[],[]
c ,c1,z ,z1 = [],[],[],[]
u ,u1,o ,o1 = [],[],[],[]

for i in range(50):
    x = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8_O0A0/epoch_"+str(i)+"training_loss",delimiter=',')
    v = np.append(v, np.mean(x[np.logical_not(np.isnan(x))]))
    
    y = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8_O0A0/epoch_"+str(i)+"validation_loss",delimiter=',')
    b = np.append(b, np.mean(y[np.logical_not(np.isnan(y))]))
    
    x2 = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8/epoch_"+str(i)+"training_loss",delimiter=',')
    v2 = np.append(v2, np.mean(x2[np.logical_not(np.isnan(x2))]))
    
    y2 = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8/epoch_"+str(i)+"validation_loss",delimiter=',')
    b2 = np.append(b2, np.mean(y2[np.logical_not(np.isnan(y2))]))
    
    c = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8/epoch_"+str(i)+"jaccard_index",delimiter=',')
    c = c[np.logical_not(np.isnan(c))]
    c1 = np.append(c1, np.mean(c))
    
    z = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8_O0A0/epoch_"+str(i)+"jaccard_index",delimiter=',')
    z = z[np.logical_not(np.isnan(z))]
    z1 = np.append(z1, np.mean(z))
    
    u = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8/epoch_"+str(i)+"validation_jaccard_index",delimiter=',')
    u = u[np.logical_not(np.isnan(u))]
    u1 = np.append(u1, np.mean(u))
    
    o = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8_O0A0/epoch_"+str(i)+"validation_jaccard_index",delimiter=',')
    o = o[np.logical_not(np.isnan(o))]
    o1 = np.append(o1, np.mean(o))

print("validation penalty model: ", u1)
print("validation no penalty model: ",o1)   

ax = plt.subplot()
ax.plot(range(len(v)),v)
ax.plot(range(len(v2)),v2)
plt.title("Mean Training loss per epoch ")
ax.legend(["base model","penalty model"])
ax.set(xlabel = "Epoch", ylabel='MSE loss + penalty')
plt.show()    
    
ax = plt.subplot()
ax.plot(range(len(b)),b)
ax.plot(range(len(b2)),b2)
plt.title("Mean Validation loss per epoch ")
ax.legend(["base model","penalty model"])
ax.set(xlabel = "Epoch", ylabel='MSE loss + penalty')
plt.show()

ax = plt.subplot()
ax.plot(range(len(z1)),z1)
ax.plot(range(len(c1)),c1)
plt.title("Mean Training jaccard per epoch ")
ax.legend(["base model","penalty model"])
ax.set(xlabel = "Epoch", ylabel='Jaccard Index score')
plt.show()

ax = plt.subplot()
ax.plot(range(len(o1)),o1)
ax.plot(range(len(u1)),u1)
plt.title("Mean Validation jaccard per epoch ")
ax.legend(["base model","penalty model"])
ax.set(xlabel = "Epoch", ylabel='Jaccard Index score')
plt.show()

##################################################################################################################
##################################################################################################################

Val0 = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8_O0A0/epoch_"+str(50-4)+"validation_jaccard_index",delimiter=',')
Val01 = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8_O0A0/epoch_"+str(50-4)+"jaccard_index",delimiter=',')
val1 = pd.DataFrame(data=Val0, columns=range(1)).assign(Distribution="No penalty")
net_1 = pd.melt(val1, id_vars=['Distribution'])

Val2 = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8/epoch_"+str(50-4)+"validation_jaccard_index",delimiter=',')
Val21 = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8/epoch_"+str(50-4)+"jaccard_index",delimiter=',')
val3 = pd.DataFrame(data=Val2, columns=range(1)).assign(Distribution="Full penalty")
net_2 = pd.melt(val3, id_vars=['Distribution'])

validation_concat = pd.concat([val1, val3])
validation_plots = pd.melt(validation_concat, id_vars=['Distribution'])

######################################

ax = sns.boxplot(x="Distribution", y="value", data=net_1)  # RUN PLOT  
plt.title("No Penalty model boxplot for output of 50th epoch") 
ax.set(ylabel='Jaccard Index score')
plt.show()
print("No penalty mean training jaccard for epoch 50: ", np.mean(Val01[np.logical_not(np.isnan(Val01))]))
print("No penalty mean validation jaccard for epoch 50: ", np.mean(Val0[np.logical_not(np.isnan(Val0))]))

ax = sns.boxplot(x="Distribution", y="value", data=net_2)  # RUN PLOT 
plt.title("Full Penalty model boxplot for output of 50th epoch") 
ax.set(ylabel='Jaccard Index score')
plt.show()
print("Full penalty mean training jaccard for epoch 50: ", np.mean(Val21[np.logical_not(np.isnan(Val21))]))
print("Full penalty mean validation jaccard for epoch 50: ", np.mean(Val2[np.logical_not(np.isnan(Val2))]))

######################################

ax = sns.violinplot(x="Distribution", y="value", data=net_1)  # RUN PLOT   
plt.title("No Penalty model violinplot for output of 50th epoch") 
ax.set(ylabel='Jaccard Index score')
plt.show()

ax = sns.violinplot(x="Distribution", y="value", data=net_2)  # RUN PLOT   
plt.title("Full Penalty model violinplot for output of 50th epoch") 
ax.set(ylabel='Jaccard Index score')
plt.show()

######################################

ax = sns.boxplot(x="Distribution", y="value", data=validation_plots)  # RUN PLOT  
plt.title("Comparison boxplots 50th epoch, No penalty (left) vs Full penalty (right)") 
ax.set(ylabel='Jaccard Index score')
plt.show()

ax = sns.violinplot(x="Distribution", y="value", data=validation_plots)  # RUN PLOT   
plt.title("Comparison violinplots 50th epoch, No penalty (left) vs Full penalty (right)") 
ax.set(ylabel='Jaccard Index score')
plt.show()
# Out:
# validation penalty model:  [0.10079785 0.17009075 0.1305654  0.05739111 0.11903827 0.16390344
#  0.14784886 0.16979243 0.18413964 0.24833454 0.21688365 0.21806855
#  0.2776464  0.19930029 0.20668031 0.21565822 0.22765822 0.22558941
#  0.20353513 0.21925312 0.22573861 0.22055989 0.23867727 0.24266248
#  0.24532499 0.26017411 0.20676862 0.27325036 0.21506061 0.26511483
#  0.24327877 0.23703819 0.26656635 0.27716053 0.26781927 0.2734636
#  0.23483921 0.28697981 0.27113364 0.28458485 0.2648012  0.24138244
#  0.30204815 0.30952388 0.28126338 0.30507001 0.28296417 0.29407084
#  0.30069099 0.30693012]
# validation no penalty model:  [0.07123513 0.13411384 0.09903532 0.15154715 0.13670966 0.19197617
#  0.22055775 0.16563825 0.20872652 0.15503637 0.2083967  0.20584953
#  0.19136077 0.24564973 0.18861416 0.21665108 0.20871152 0.21061541
#  0.28759094 0.23443072 0.2442555  0.26604165 0.22143779 0.22605578
#  0.21290187 0.24882613 0.26847431 0.23902997 0.24862071 0.24484235
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
import pandas as pd

x ,y ,v ,b  = [],[],[],[]
x2,y2,v2,b2 = [],[],[],[]
c ,c1,z ,z1 = [],[],[],[]
u ,u1,o ,o1 = [],[],[],[]

for i in range(100):
    x = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8_O4A10/epoch_"+str(i)+"training_loss",delimiter=',')
    v = np.append(v, np.mean(x[np.logical_not(np.isnan(x))]))
    
    y = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8_O4A10/epoch_"+str(i)+"validation_loss",delimiter=',')
    b = np.append(b, np.mean(y[np.logical_not(np.isnan(y))]))
    
    z = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8_O4A10/epoch_"+str(i)+"jaccard_index",delimiter=',')
    z = z[np.logical_not(np.isnan(z))]
    z1 = np.append(z1, np.mean(z))
    
    u = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8_O4A10/epoch_"+str(i)+"validation_jaccard_index",delimiter=',')
    u = u[np.logical_not(np.isnan(u))]
    u1 = np.append(u1, np.mean(u))

print("training penalty model: ", z1)
print("validation penalty model: ",u1)   

ax = plt.subplot()
ax.plot(range(len(v)),v)
plt.title("Mean Training loss per epoch ")
ax.legend(["base model"])
ax.set(xlabel = "Epoch", ylabel='MSE loss + penalty')
plt.show()    
    
ax = plt.subplot()
ax.plot(range(len(b)),b)
plt.title("Mean Validation loss per epoch ")
ax.legend(["base model"])
ax.set(xlabel = "Epoch", ylabel='MSE loss + penalty')
plt.show()

ax = plt.subplot()
ax.plot(range(len(z1)),z1)
plt.title("Mean Training jaccard per epoch ")
ax.legend(["base model"])
ax.set(xlabel = "Epoch", ylabel='Jaccard Index score')
plt.show()

ax = plt.subplot()
ax.plot(range(len(u1)),u1)
plt.title("Mean Validation jaccard per epoch ")
ax.legend(["base model"])
ax.set(xlabel = "Epoch", ylabel='Jaccard Index score')
plt.show()

##################################################################################################################
##################################################################################################################

Val0 = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8_O4A10/epoch_"+str(100-41)+"validation_jaccard_index",delimiter=',')
Val01 = np.genfromtxt("Checkpoints_RANO/Unet_H16_M8_O4A10/epoch_"+str(100-41)+"jaccard_index",delimiter=',')
val1 = pd.DataFrame(data=Val0, columns=range(1)).assign(Distribution="No penalty")
net_1 = pd.melt(val1, id_vars=['Distribution'])


validation_plots = pd.melt(val1, id_vars=['Distribution'])

######################################

ax = sns.boxplot(x="Distribution", y="value", data=net_1)  # RUN PLOT  
plt.title("No Penalty model boxplot for output of 50th epoch") 
ax.set(ylabel='Jaccard Index score')
plt.show()
print("No penalty mean training jaccard for epoch 50: ", np.mean(Val01[np.logical_not(np.isnan(Val01))]))
print("No penalty mean validation jaccard for epoch 50: ", np.mean(Val0[np.logical_not(np.isnan(Val0))]))

######################################

ax = sns.violinplot(x="Distribution", y="value", data=net_1)  # RUN PLOT   
plt.title("No Penalty model violinplot for output of 50th epoch") 
ax.set(ylabel='Jaccard Index score')
plt.show()

######################################

ax = sns.boxplot(x="Distribution", y="value", data=validation_plots)  # RUN PLOT  
plt.title("Comparison boxplots 50th epoch, No penalty (left) vs Full penalty (right)") 
ax.set(ylabel='Jaccard Index score')
plt.show()
# Out:
# training penalty model:  [0.07470162 0.11446023 0.14137714 0.16467978 0.17469362 0.18288053
#  0.18506514 0.19658223 0.20045281 0.20501846 0.20710988 0.20888932
#  0.21496629 0.22483723 0.2250458  0.23394366 0.23761125 0.24241911
#  0.24861703 0.25411749 0.26485075 0.26555234 0.27373201 0.2813131
#  0.28608722 0.29927295 0.30206518 0.30479715 0.31328058 0.31615558
#  0.32333543 0.33051393 0.33611627 0.34516997 0.33870727 0.35574746
#  0.35651886 0.35601978 0.36686902 0.3833795  0.366953   0.37789572
#  0.3741117  0.39727157 0.40691691 0.39140816 0.38532785 0.39739069
#  0.42361838 0.43116044 0.43430654 0.39918126 0.41527907 0.44302844
#  0.45414535 0.45158812 0.39287907 0.44215411 0.46178539 0.47475489
#  0.41048264 0.45724239 0.4587184  0.48222193 0.48434234 0.41163378
#  0.4539422  0.47308478 0.49037347 0.49791445 0.46236204 0.43710791
#  0.50081018 0.5102008  0.51776696 0.51117376 0.47859866 0.46946939
#  0.50469072 0.51417316 0.5274855  0.52843332 0.43938448 0.50146513
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
import pandas as pd

Training_loss_0 = []
Training_loss_Nan_0 = []
Training_loss_1 = []
Training_loss_Nan_1 = []
Training_loss_2 = []
Training_loss_Nan_2 = []
Training_loss_3 = []
Training_loss_Nan_3 = []


for i in range(100):
    Training_loss_0 = np.genfromtxt("Checkpoints_RANO/Unet_H16_M9_O0A0/epoch_"+str(i)+"training_loss",delimiter=',')
    Training_loss_Nan_0 = np.append(Training_loss_Nan_0, np.mean(Training_loss_0[np.logical_not(np.isnan(Training_loss_0))]))
    
    Training_loss_1 = np.genfromtxt("Checkpoints_RANO/Unet_H16_M9_O4A0/epoch_"+str(i)+"training_loss",delimiter=',')
    Training_loss_Nan_1 = np.append(Training_loss_Nan_1, np.mean(Training_loss_1[np.logical_not(np.isnan(Training_loss_1))]))
    
    Training_loss_2 = np.genfromtxt("Checkpoints_RANO/Unet_H16_M9_O10A0/epoch_"+str(i)+"training_loss",delimiter=',')
    Training_loss_Nan_2 = np.append(Training_loss_Nan_2, np.mean(Training_loss_2[np.logical_not(np.isnan(Training_loss_2))]))
    
    Training_loss_3 = np.genfromtxt("Checkpoints_RANO/Unet_H16_M9_O20A0/epoch_"+str(i)+"training_loss",delimiter=',')
    Training_loss_Nan_3 = np.append(Training_loss_Nan_3, np.mean(Training_loss_3[np.logical_not(np.isnan(Training_loss_3))]))
    
print("training 0 model loss: ", Training_loss_Nan_0[-1])
print("training 1 model loss: ", Training_loss_Nan_1[-1])
print("training 2 model loss: ", Training_loss_Nan_2[-1])
print("training 3 model loss: ", Training_loss_Nan_3[-1])

ax = plt.subplot()
ax.plot(range(len(Training_loss_Nan_0)),Training_loss_Nan_0)
ax.plot(range(len(Training_loss_Nan_1)),Training_loss_Nan_1)
ax.plot(range(len(Training_loss_Nan_1)),Training_loss_Nan_2)
ax.plot(range(len(Training_loss_Nan_1)),Training_loss_Nan_3)
plt.title("Mean Training loss per epoch ")
ax.legend(["0","1","2","3"])
ax.set(xlabel = "Epoch", ylabel='MSE loss + penalty')
plt.show()    

Training_loss_0 = []
Training_loss_Nan_0 = []
Training_loss_1 = []
Training_loss_Nan_1 = []
Training_loss_2 = []
Training_loss_Nan_2 = []
Training_loss_3 = []
Training_loss_Nan_3 = []
Training_loss_all = []
Training_loss_Nan_all = []

for i in range(100):
    Training_loss_0 = np.genfromtxt("Checkpoints_RANO/Unet_H16_M9_O0A0/epoch_"+str(i)+"validation_loss",delimiter=',')
    Training_loss_Nan_0 = np.append(Training_loss_Nan_0, np.mean(Training_loss_0[np.logical_not(np.isnan(Training_loss_0))]))
    
    Training_loss_1 = np.genfromtxt("Checkpoints_RANO/Unet_H16_M9_O4A0/epoch_"+str(i)+"validation_loss",delimiter=',')
    Training_loss_Nan_1 = np.append(Training_loss_Nan_1, np.mean(Training_loss_1[np.logical_not(np.isnan(Training_loss_1))]))
    
    Training_loss_2 = np.genfromtxt("Checkpoints_RANO/Unet_H16_M9_O10A0/epoch_"+str(i)+"validation_loss",delimiter=',')
    Training_loss_Nan_2 = np.append(Training_loss_Nan_2, np.mean(Training_loss_2[np.logical_not(np.isnan(Training_loss_2))]))
    
    Training_loss_3 = np.genfromtxt("Checkpoints_RANO/Unet_H16_M9_O20A0/epoch_"+str(i)+"validation_loss",delimiter=',')
    Training_loss_Nan_3 = np.append(Training_loss_Nan_3, np.mean(Training_loss_3[np.logical_not(np.isnan(Training_loss_3))]))
    
print("training 0 model loss: ", Training_loss_Nan_0[-1])
print("training 1 model loss: ", Training_loss_Nan_1[-1])
print("training 2 model loss: ", Training_loss_Nan_2[-1])
print("training 3 model loss: ", Training_loss_Nan_3[-1])

ax = plt.subplot()
ax.plot(range(len(Training_loss_Nan_0)),Training_loss_Nan_0)
ax.plot(range(len(Training_loss_Nan_1)),Training_loss_Nan_1)
ax.plot(range(len(Training_loss_Nan_1)),Training_loss_Nan_2)
ax.plot(range(len(Training_loss_Nan_1)),Training_loss_Nan_3)
plt.title("Mean Training loss per epoch ")
ax.legend(["0","1","2","3"])
ax.set(xlabel = "Epoch", ylabel='MSE loss + penalty')
plt.show()    

Training_loss_0 = []
Training_loss_Nan_0 = []
Training_loss_1 = []
Training_loss_Nan_1 = []
Training_loss_2 = []
Training_loss_Nan_2 = []
Training_loss_3 = []
Training_loss_Nan_3 = []
Training_loss_all = []
Training_loss_Nan_all = []

for i in range(100):
    Training_loss_0 = np.genfromtxt("Checkpoints_RANO/Unet_H16_M9_O0A0/epoch_"+str(i)+"jaccard_index",delimiter=',')
    Training_loss_Nan_0 = np.append(Training_loss_Nan_0, np.mean(Training_loss_0[np.logical_not(np.isnan(Training_loss_0))]))
    
    Training_loss_1 = np.genfromtxt("Checkpoints_RANO/Unet_H16_M9_O4A0/epoch_"+str(i)+"jaccard_index",delimiter=',')
    Training_loss_Nan_1 = np.append(Training_loss_Nan_1, np.mean(Training_loss_1[np.logical_not(np.isnan(Training_loss_1))]))
    
    Training_loss_2 = np.genfromtxt("Checkpoints_RANO/Unet_H16_M9_O10A0/epoch_"+str(i)+"jaccard_index",delimiter=',')
    Training_loss_Nan_2 = np.append(Training_loss_Nan_2, np.mean(Training_loss_2[np.logical_not(np.isnan(Training_loss_2))]))
    
    Training_loss_3 = np.genfromtxt("Checkpoints_RANO/Unet_H16_M9_O20A0/epoch_"+str(i)+"jaccard_index",delimiter=',')
    Training_loss_Nan_3 = np.append(Training_loss_Nan_3, np.mean(Training_loss_3[np.logical_not(np.isnan(Training_loss_3))]))
    
    Training_loss_all = np.genfromtxt("Checkpoints_RANO/Unet_H16_M9_O4A4/epoch_"+str(i)+"jaccard_index",delimiter=',')
    Training_loss_Nan_all = np.append(Training_loss_Nan_all, np.mean(Training_loss_all[np.logical_not(np.isnan(Training_loss_all))]))
    
print("training 0 model jaccard: ", Training_loss_Nan_0[-1])
print("training 1 model jaccard: ", Training_loss_Nan_1[-1])
print("training 2 model jaccard: ", Training_loss_Nan_2[-1])
print("training 3 model jaccard: ", Training_loss_Nan_3[-1])
print("training 4 model jaccard: ", Training_loss_Nan_all[-1])

print("")
print(Training_loss_Nan_2[38])
print(Training_loss_Nan_2[39])
print(Training_loss_Nan_2[40])
print("")

ax = plt.subplot()
ax.plot(range(len(Training_loss_Nan_0)),Training_loss_Nan_0)
ax.plot(range(len(Training_loss_Nan_1)),Training_loss_Nan_1)
ax.plot(range(len(Training_loss_Nan_1)),Training_loss_Nan_2)
ax.plot(range(len(Training_loss_Nan_1)),Training_loss_Nan_3)
ax.plot(range(len(Training_loss_Nan_1)),Training_loss_Nan_all)
plt.title("Mean Training Jaccard per epoch ")
ax.legend(["0","1","2","3","all"])

ax.set(xlabel = "Epoch", ylabel='MSE loss + penalty')
plt.show()    

ax = plt.subplot()
ax.plot(range(len(Training_loss_Nan_0)),Training_loss_Nan_0)
ax.plot(range(len(Training_loss_Nan_1)),Training_loss_Nan_2)
ax.plot(range(len(Training_loss_Nan_1)),Training_loss_Nan_all)
plt.title("Mean Training Jaccard per epoch ")
ax.legend(["0","2","all"])

ax.set(xlabel = "Epoch", ylabel='Mean Jaccard score')
plt.show()    

##################################################################################################################
##################################################################################################################
# Out:
# training 0 model loss:  0.5804717674007781
# training 1 model loss:  0.7701416114850891
# training 2 model loss:  0.7746063945152694
# training 3 model loss:  0.9863508703853217
# training 0 model loss:  135.12783883224319
# training 1 model loss:  136.85609462924444
# training 2 model loss:  150.13576818908714
# training 3 model loss:  152.26341013069933
# training 0 model jaccard:  0.5820279155004628
# training 1 model jaccard:  0.5632512871848645
# training 2 model jaccard:  0.5903698674381533
# training 3 model jaccard:  0.5915256256807715
# training 4 model jaccard:  0.5710294166720825
#
# 0.3666940648667926
# 0.3748092542632948
# 0.3865899269201261

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
import pandas as pd

input_names = ["Unet_H16_M9_O0A0_V2","Unet_H16_M9_O4A0_V2","Unet_H16_M9_O10A0","Unet_H16_M9_O20A0"]
legend_names = [" 0 orth 0 Area", " 4 orth 0 Area", "10 orth 0 Area", "20 orth 0 Area"]
output_type = ["validation_loss", "validation_jaccard_index","training_loss","jaccard_index"]
output_axis = ["MSE loss + penalty", "jaccard_index","MSE loss + penalty","jaccard_index"]

loss_0 = []
loss_Nan_0 = []

for c in range(len(output_type)):
    ax = plt.subplot()
    for s in range(len(input_names)):
        for i in range(50):
            loss_0 = np.genfromtxt("Checkpoints_RANO/"+input_names[s]+"/epoch_"+str(i)+output_type[c],delimiter=',')
            loss_Nan_0 = np.append(loss_Nan_0, np.mean(loss_0[np.logical_not(np.isnan(loss_0))]))
        ax.plot(range(len(loss_Nan_0)),loss_Nan_0)
        loss_0 = []
        loss_Nan_0 = []

    plt.title(output_type[c]+ " per epoch ")
    ax.legend(legend_names)
    ax.set(xlabel = "Epoch", ylabel=output_axis[c])
    plt.show()    
    
for i in range(35,45):
    loss_0 = np.genfromtxt("Checkpoints_RANO/Unet_H16_M9_O10A0/epoch_"+str(i)+"validation_jaccard_index",delimiter=',')
    loss_Nan_0 = np.append(loss_Nan_0, np.mean(loss_0[np.logical_not(np.isnan(loss_0))]))
print(loss_Nan_0)
# Out:
# [0.27586581 0.28868434 0.26188564 0.25132385 0.26069624 0.26678633
#  0.2709763  0.26781247 0.29049048 0.28095697]

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
import pandas as pd

input_names = ["Unet_H16_M9_O0A0_V2","Unet_H16_M9_O0A4","Unet_H16_M9_O0A10","Unet_H16_M9_O0A20"]
legend_names = [" 0 orth 0 Area", " 0 orth 4 Area", "0 orth 10 Area", "0 orth 20 Area"]
output_type = ["validation_loss", "validation_jaccard_index","training_loss","jaccard_index"]
output_axis = ["MSE loss + penalty", "jaccard_index","MSE loss + penalty","jaccard_index"]

loss_0 = []
loss_Nan_0 = []

for c in range(len(output_type)):
    ax = plt.subplot()
    for s in range(len(input_names)):
        for i in range(50):
            loss_0 = np.genfromtxt("Checkpoints_RANO/"+input_names[s]+"/epoch_"+str(i)+output_type[c],delimiter=',')
            loss_Nan_0 = np.append(loss_Nan_0, np.mean(loss_0[np.logical_not(np.isnan(loss_0))]))
        ax.plot(range(len(loss_Nan_0)),loss_Nan_0)
        loss_0 = []
        loss_Nan_0 = []

    plt.title(output_type[c]+ " per epoch ")
    ax.legend(legend_names)
    ax.set(xlabel = "Epoch", ylabel=output_axis[c])
    plt.show()    
    
for i in range(35,45):
    loss_0 = np.genfromtxt("Checkpoints_RANO/Unet_H16_M9_O10A0/epoch_"+str(i)+"validation_jaccard_index",delimiter=',')
    loss_Nan_0 = np.append(loss_Nan_0, np.mean(loss_0[np.logical_not(np.isnan(loss_0))]))
print(loss_Nan_0)
# Out:
# [0.27586581 0.28868434 0.26188564 0.25132385 0.26069624 0.26678633
#  0.2709763  0.26781247 0.29049048 0.28095697]

# %%
Training_loss_0 = []
Training_loss_Nan_0 = []
Training_loss_1 = []
Training_loss_Nan_1 = []
Training_loss_2 = []
Training_loss_Nan_2 = []
Training_loss_3 = []
Training_loss_Nan_3 = []
Training_loss_all = []
Training_loss_Nan_all = []

for i in range(100):
    Training_loss_0 = np.genfromtxt("Checkpoints_RANO/Unet_H16_M9_O0A0/epoch_"+str(i)+"validation_jaccard_index",delimiter=',')
    Training_loss_Nan_0 = np.append(Training_loss_Nan_0, np.mean(Training_loss_0[np.logical_not(np.isnan(Training_loss_0))]))
    
    Training_loss_1 = np.genfromtxt("Checkpoints_RANO/Unet_H16_M9_O4A0/epoch_"+str(i)+"validation_jaccard_index",delimiter=',')
    Training_loss_Nan_1 = np.append(Training_loss_Nan_1, np.mean(Training_loss_1[np.logical_not(np.isnan(Training_loss_1))]))
    
    Training_loss_2 = np.genfromtxt("Checkpoints_RANO/Unet_H16_M9_O10A0/epoch_"+str(i)+"validation_jaccard_index",delimiter=',')
    Training_loss_Nan_2 = np.append(Training_loss_Nan_2, np.mean(Training_loss_2[np.logical_not(np.isnan(Training_loss_2))]))
    
    Training_loss_3 = np.genfromtxt("Checkpoints_RANO/Unet_H16_M9_O20A0/epoch_"+str(i)+"validation_jaccard_index",delimiter=',')
    Training_loss_Nan_3 = np.append(Training_loss_Nan_3, np.mean(Training_loss_3[np.logical_not(np.isnan(Training_loss_3))]))
    
    Training_loss_all = np.genfromtxt("Checkpoints_RANO/Unet_H16_M9_O4A4/epoch_"+str(i)+"validation_jaccard_index",delimiter=',')
    Training_loss_Nan_all = np.append(Training_loss_Nan_all, np.mean(Training_loss_all[np.logical_not(np.isnan(Training_loss_all))]))
    
print("validation 0 model jaccard: ", Training_loss_Nan_0[-1])
print("validation 1 model jaccard: ", Training_loss_Nan_1[-1])
print("validation 2 model jaccard: ", Training_loss_Nan_2[-1])
print("validation 3 model jaccard: ", Training_loss_Nan_3[-1])
print("validation 4 model jaccard: ", Training_loss_Nan_all[-1])

ax = plt.subplot()
ax.plot(range(len(Training_loss_Nan_0)),Training_loss_Nan_0)
ax.plot(range(len(Training_loss_Nan_1)),Training_loss_Nan_1)
ax.plot(range(len(Training_loss_Nan_1)),Training_loss_Nan_2)
ax.plot(range(len(Training_loss_Nan_1)),Training_loss_Nan_3)
ax.plot(range(len(Training_loss_Nan_1)),Training_loss_Nan_all)
plt.title("Mean Training Jaccard per epoch ")
ax.legend(["0","1","2","3","all"])

ax.set(xlabel = "Epoch", ylabel='MSE loss + penalty')
plt.show()    

ax = plt.subplot()
ax.plot(range(len(Training_loss_Nan_0)),Training_loss_Nan_0)
ax.plot(range(len(Training_loss_Nan_1)),Training_loss_Nan_2)
ax.plot(range(len(Training_loss_Nan_1)),Training_loss_Nan_all)
plt.title("Mean Training Jaccard per epoch ")
ax.legend(["0","2","all"])

ax.set(xlabel = "Epoch", ylabel='Mean Jaccard score')
plt.show()    

##################################################################################################################
##################################################################################################################
# Out:
# validation 0 model jaccard:  0.32453928955936245
# validation 1 model jaccard:  0.3034520214763521
# validation 2 model jaccard:  0.3288933654555524
# validation 3 model jaccard:  0.31488342723740204
# validation 4 model jaccard:  0.30810719238039275

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
import pandas as pd

data=["Unet_H16_M9_O0A0_V2","Unet_H16_M9_O4A0_V2","Unet_H16_M9_O4A4_V2"]
output=["training_loss","validation_loss","jaccard_index","validation_jaccard_index"]
axis_val=["MSE loss + penalty","MSE loss + penalty","jaccard index","jaccard index"]

titles=["No penalty","Orthog","Orthog + Area"]

for c in range(len(output)):
    ax = plt.subplot()
    for j in range(len(data)):
        Training_loss_0 = []
        Training_loss_Nan_0 = []
        for i in range(50):
            Training_loss_0 = np.genfromtxt("Checkpoints_RANO/"+data[j]+"/epoch_"+str(i)+output[c],delimiter=',')
            Training_loss_Nan_0 = np.append(Training_loss_Nan_0, np.mean(Training_loss_0[np.logical_not(np.isnan(Training_loss_0))]))
        print("training " +str(j)+ " model loss: ", Training_loss_Nan_0[-1])
        ax.plot(range(len(Training_loss_Nan_0)),Training_loss_Nan_0)
    plt.title("Mean "+output[c]+" per epoch ")
    ax.legend(titles)
    ax.set(xlabel = "Epoch", ylabel=axis_val[c])
    plt.show()    

# data=["Unet_H16_M9_O10A0"]
# output=["training_loss","Validation_loss/validation_loss","Training_Jaccard/jaccard_index","Validation_Jaccard/validation_jaccard_index"]
# axis_val=["MSE loss + penalty","MSE loss + penalty","jaccard index","jaccard index"]

# for c in range(len(output)):
#     ax = plt.subplot()
#     for j in range(len(data)):
#         Training_loss_0 = []
#         Training_loss_Nan_0 = []
#         for i in range(20):
#             Training_loss_0 = np.genfromtxt("Checkpoints_RANO/"+data[j]+"/epoch_"+str(i)+output[c],delimiter=',')
#             Training_loss_Nan_0 = np.append(Training_loss_Nan_0, np.mean(Training_loss_0[np.logical_not(np.isnan(Training_loss_0))]))
#         print("training " +str(j)+ " model loss: ", Training_loss_Nan_0[-1])
#         ax.plot(range(len(Training_loss_Nan_0)),Training_loss_Nan_0)
#     plt.title("Mean "+output[c]+" per epoch ")
#     ax.legend(data)
#     ax.set(xlabel = "Epoch", ylabel=axis_val[c])
#     plt.show()    

##################################################################################################################
##################################################################################################################

# one mistake that i have been making is to not allocate a seed when testing the hyperparameters or anything 
# regarding changes to the model - it might be a case of false positives in the minute differences.
# this should not be an issue in the larger scope of things but still something to think about
# Out:
# training 0 model loss:  2.0502166845543703
# training 1 model loss:  1.8267640969045915
# training 2 model loss:  4.621737975485668
# training 0 model loss:  142.29943356369037
# training 1 model loss:  135.73697027402366
# training 2 model loss:  173.4756391054853
# training 0 model loss:  0.4131860955715142
# training 1 model loss:  0.42870860137721145
# training 2 model loss:  0.4285912175045047
# training 0 model loss:  0.2732654255139118
# training 1 model loss:  0.262485970116618
# training 2 model loss:  0.2642785768472061
