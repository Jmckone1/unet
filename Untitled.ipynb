# %%
import os
import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# go through each of the image channels and check the min, max and histogram layouts 
# for each of the examples before and after normalisation.

image_path = "Brats_2018_data/Brats_2018_data/HGG/Brats18_CBICA_ABB_1/"
possible_outputs = [
    "Brats18_CBICA_ABB_1_flair.nii.gz",
    "Brats18_CBICA_ABB_1_t1.nii.gz",
    "Brats18_CBICA_ABB_1_t1ce.nii.gz",
    "Brats18_CBICA_ABB_1_t2.nii.gz"
]

for i in range(len(possible_outputs)):
    img_a = nib.load(image_path + possible_outputs[i])
    img_data = img_a.get_fdata()

    print(np.min(img_data[:,:,73]),"-", np.max(img_data[:,:,73]))
    print("")
    plt.imshow(img_data[:,:,73],"gray")
    plt.show()
    
    score_data = pd.DataFrame(data = img_data[:,:,73].flatten(),columns=['score']).assign(group = 'Group A')
    
    sns.histplot(data = score_data,x="score")
    plt.show()
    
image_path = "Brats_2018_data/Brats_2018_data/HGG/Brats18_CBICA_ABB_1/"
possible_outputs = [
    "Brats18_CBICA_ABB_1_whimg_norm.nii.gz"
]

for i in range(4):
    img_a = nib.load(image_path + possible_outputs[0])
    img_data = img_a.get_fdata()

    print(np.min(img_data[i,:,:,73]),"-", np.max(img_data[i,:,:,73]))
    print("")
    plt.imshow(img_data[i,:,:,73],"gray")
    plt.show()
    
    score_data = pd.DataFrame(data = img_data[i,:,:,73].flatten(),columns=['score']).assign(group = 'Group A')
    
    sns.histplot(data = score_data,x="score")
    plt.show()

# for i in range(4):
#     img_a = nib.load(image_path + possible_outputs[0])
#     img_data = img_a.get_fdata()

#     print(np.min(img_data[i]),"-", np.max(img_data[i]))
#     print("")
    
#     plt.hist(img_data, bins = 32)
#     plt.show()
# Out:
# 0.0 - 602.0
# 0.0 - 845.0
# 0.0 - 1368.0
# 0.0 - 414.0
# -3.1956939697265625 - 5.4648027420043945
# -2.9032130241394043 - 8.374218940734863
# -2.534015655517578 - 8.450512886047363
# -2.3110404014587402 - 4.337629795074463

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
import pandas as pd
loss_0 = []
loss_Nan_0 = []
x = 0

# input_val = ["0003_bce", "00003_bce", "0003_dice", "00003_dice"]
# input_val = ["0003_bce","0003_dice"]
# input_val = ["00003_bce","00003_dice"]

input_val = ["0003_dice","00003_dice"]
for j in range(3):
    for s in range(len(input_val)):
        loss_0 = np.genfromtxt("Checkpoints/split_data_experiments/Full_model_MK6_H16_PTE_CO100_R3_lr_"+input_val[s]+"_main_21072022/epoch_"+str(j)+"training_dice.csv")
        for i in range(len(loss_0)):
            x = x + loss_0[i]
            if i % 16 == 0:
                loss_Nan_0 = np.append(loss_Nan_0, x / 16)
                x = 0

        plt.plot(range(len(loss_Nan_0)),loss_Nan_0)
        loss_0 = []
        loss_Nan_0 = []

    plt.plot(range(len(loss_Nan_0)),loss_Nan_0)
    loss_0 = []
    loss_Nan_0 = []

    plt.legend(input_val)
    plt.show()

    for s in range(len(input_val)):
        loss_0 = np.genfromtxt("Checkpoints/split_data_experiments/Full_model_MK6_H16_PTE_CO100_R3_lr_"+input_val[s]+"_main_21072022/epoch_"+str(j)+"validation_dice.csv")
        for i in range(len(loss_0)):
            x = x + loss_0[i]
            if i % 16 == 0:
                loss_Nan_0 = np.append(loss_Nan_0, x / 16)
                x = 0

        plt.plot(range(len(loss_Nan_0)),loss_Nan_0)
        loss_0 = []
        loss_Nan_0 = []

    plt.plot(range(len(loss_Nan_0)),loss_Nan_0)
    loss_0 = []
    loss_Nan_0 = []

    plt.legend(input_val)
    plt.show()

# %%
#### import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns
sns.set_theme()
import pandas as pd
loss_0 = []
loss_1 = []
loss_2 = []
loss_Nan_0 = []
x = 0
loss = []

from matplotlib.pyplot import figure



# input_val = ["0003_bce", "00003_bce", "0003_dice", "00003_dice"]
# input_val = ["0003_bce","0003_dice"]
# input_val = ["00003_bce","00003_dice"]

#input_val = ["0003_bce","00003_bce"]

l_s = ["loss","dice"]
output_l_s = ["loss, ","dice score, "]
b_d = ["using BCE loss", "using dice loss"]
train_val = [""]
for switch_loss_dice in range(2):
    for switch in range(2):
        if switch == 0:
            # "003_dice_main_22072022",
            input_val = ["Checkpoints/split_data_experiments/Full_model_MK6_H16_PTE_CO100_R3_lr_0003_bce_main_22072022" ,
                         "Checkpoints/split_data_experiments/Full_model_MK6_H16_PTE_CO100_R3_lr_00003_bce_main_22072022" ,
                         "Checkpoints/split_data_experiments/Full_model_MK6_H16_PTE_CO100_R3_lr_000003_bce_main_22072022"]
            label_val = ["LR = 0.0003",
                         "LR = 0.00003",
                         "LR = 0.000003"]
        if switch == 1:
            # "003_dice_main_22072022",
            input_val = ["Checkpoints/split_data_experiments/1_Full_model_MK6_H16_PTE_CO100_R3_lr_0003_dice_main",
                         "Checkpoints/split_data_experiments/Full_model_MK6_H16_PTE_CO100_R3_lr_00003_dice_main_21072022",
                         "Checkpoints/split_data_experiments/Full_model_MK6_H16_PTE_CO100_R3_lr_000003_dice_main_22072022"]
            label_val = ["LR = 0.0003",
                         "LR = 0.00003",
                         "LR = 0.000003"]
        figure(figsize=(14, 6), dpi=80)
        for s in range(len(input_val)):

            loss_0 = np.genfromtxt(input_val[s]+"/epoch_0training_"+l_s[switch_loss_dice]+".csv")
            loss_1 = np.genfromtxt(input_val[s]+"/epoch_1training_"+l_s[switch_loss_dice]+".csv")
            loss_2 = np.genfromtxt(input_val[s]+"/epoch_2training_"+l_s[switch_loss_dice]+".csv")

            for i in loss_0:
                loss = np.append(loss,i)
            for i in loss_1:
                loss = np.append(loss,i)
            for i in loss_2:
                loss = np.append(loss,i)

            for i in range(len(loss)):
                x = x + loss[i]
                if i % 16 == 0:
                    loss_Nan_0 = np.append(loss_Nan_0, x / 16)
                    x = 0
            
            plt.plot(range(len(loss_Nan_0[1:])),loss_Nan_0[1:])
            loss = []
            loss_0 = []
            loss_1 = []
            loss_2 = []
            loss_Nan_0 = []
        
        plt.title("Mean Training " + output_l_s[switch_loss_dice]+ b_d[switch] + " per batch of 16 images, for 3 learning rates.", fontsize=16)
        if switch_loss_dice == 1:
            plt.ylim([-0.05,1.05])
        plt.legend(label_val,bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0, fontsize=16)
        plt.show()
        figure(figsize=(14, 6), dpi=80)

        for s in range(len(input_val)):

            loss_0 = np.genfromtxt(input_val[s]+"/epoch_0validation_"+l_s[switch_loss_dice]+".csv")
            loss_1 = np.genfromtxt(input_val[s]+"/epoch_1validation_"+l_s[switch_loss_dice]+".csv")
            loss_2 = np.genfromtxt(input_val[s]+"/epoch_2validation_"+l_s[switch_loss_dice]+".csv")

            for i in loss_0:
                loss = np.append(loss,i)
            for i in loss_1:
                loss = np.append(loss,i)
            for i in loss_2:
                loss = np.append(loss,i)

            for i in range(len(loss)):
                x = x + loss[i]
                if i % 16 == 0:
                    loss_Nan_0 = np.append(loss_Nan_0, x / 16)
                    x = 0

            plt.plot(range(len(loss_Nan_0[1:])),loss_Nan_0[1:])
            loss = []
            loss_0 = []
            loss_1 = []
            loss_2 = []
            loss_Nan_0 = []
        plt.title("Mean Validation " + output_l_s[switch_loss_dice]+ b_d[switch] + " per batch of 16 images, for 3 learning rates.", fontsize=16)
        if switch_loss_dice == 1:
            plt.ylim([-0.05,1.05])
        plt.legend(label_val,bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0, fontsize=16)
        
        plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
import pandas as pd
loss_0 = []
loss_1 = []
loss_2 = []
loss_Nan_0 = []
x = 0
loss = []

from matplotlib.pyplot import figure

import seaborn as sns
sns.set_context('paper')


# input_val = ["0003_bce", "00003_bce", "0003_dice", "00003_dice"]
# input_val = ["0003_bce","0003_dice"]
# input_val = ["00003_bce","00003_dice"]

#input_val = ["0003_bce","00003_bce"]

l_s = ["loss","dice"]
train_val = [""]

            # "003_dice_main_22072022",
input_val = ["RI_dice_0822","PFE_dice_0822" ,"PTE_dice_0822"]
for x_plot in range(3):
    figure(figsize=(14, 6), dpi=80)
    for s in range(len(input_val)):

        # Predictions/MK_6_model_predictions/PTE_dice_0822/MK_5_base_step_0/0_All_slice_validation_dice.csv
        # "Predictions/MK_6_model_predictions/PTE_dice_0822/MK_5_base_step_0_" + f + "/0_All_slice_validation_dice.csv"
        loss_0 = np.genfromtxt("Predictions/MK_6_model_predictions/"+input_val[s]+"/MK_5_base_step_"+str(x_plot)+"/0_All_slice_validation_dice.csv",delimiter=',')
    #             print(loss_0)
    #             for i in loss_0:
    #                 loss = np.append(loss,i)

    #             for i in range(len(loss)):
    #                 x = x + loss[i]
    #                 if i % 16 == 0:
    #                     loss_Nan_0 = np.append(loss_Nan_0, x / 16)
    #                     x = 0

        plt.plot(range(len(loss_0)),loss_0)
        loss = []
        loss_0 = []
        loss_1 = []
        loss_2 = []
        loss_Nan_0 = []



    # plt.title("training " + l_s[switch_loss_dice])
    plt.title("line plot of volume-wise mean dice score for epoch " + str(x_plot + 1))
    plt.legend(input_val)
    plt.show()



    # load dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
import pandas as pd
loss_0 = []
loss_1 = []
loss_2 = []
loss_Nan_0 = []
x = 0
loss = []

from matplotlib.pyplot import figure

import seaborn as sns
#sns.set_context('paper')


# input_val = ["0003_bce", "00003_bce", "0003_dice", "00003_dice"]
# input_val = ["0003_bce","0003_dice"]
# input_val = ["00003_bce","00003_dice"]

#input_val = ["0003_bce","00003_bce"]

l_s = ["loss","dice"]
train_val = [""]

            # "003_dice_main_22072022",
input_val = ["RI_dice_0822","PFE_dice_0822" ,"PTE_dice_0822"]

figure(figsize=(14, 6), dpi=80)

loss_0 = np.genfromtxt("Predictions/MK_6_model_predictions/"+input_val[0]+"/MK_5_base_step_2/0_All_slice_validation_dice.csv",delimiter=',')
loss_1 = np.genfromtxt("Predictions/MK_6_model_predictions/"+input_val[1]+"/MK_5_base_step_2/0_All_slice_validation_dice.csv",delimiter=',')
loss_1 = np.genfromtxt("Predictions/MK_6_model_predictions/"+input_val[2]+"/MK_5_base_step_2/0_All_slice_validation_dice.csv",delimiter=',')

df1 = pd.DataFrame({'loss':loss_0,'class':"ri", 'score':range(len(loss_0))})
df2 = pd.DataFrame({'loss':loss_1,'class':"pfe", 'score':range(len(loss_1))})
df3 = pd.DataFrame({'loss':loss_2,'class':"pte", 'score':range(len(loss_2))})

score_data = pd.concat([df1, df2, df3,df1])#.groupby(by=['class'])

sns.barplot(data = score_data, x = 'score', y = 'loss', hue = 'class')


# g = sns.FacetGrid(score_data, col="score", height=3, hue='class', col_wrap=6)

# g.map(sns.barplot, 'score', 'loss', order=['ri','pfe','pte'])

plt.legend(input_val)
plt.show()

# %%
# import nibabel as nib
# import numpy as np
# import os

# data = np.ones((4,240,240,17), dtype=np.int16) # dummy data in numpy matrix
# img = nib.Nifti1Image(data, np.eye(4))  # Save axis for data (just identity)

# img.header.get_xyzt_units()
# img.to_filename(os.path.join('mini_test/mini_test/HGG/brats_1','brats_1_whimg_norm.nii.gz'))  # Save as NiBabel file

# data = np.ones((240,240,17), dtype=np.int16) # dummy data in numpy matrix
# img = nib.Nifti1Image(data, np.eye(4))  # Save axis for data (just identity)

# img.header.get_xyzt_units()
# img.to_filename(os.path.join('mini_test/mini_test/HGG/brats_1','brats_1_whseg_norm.nii.gz'))  # Save as NiBabel file

# data = np.ones((4,240,240,16), dtype=np.int16) # dummy data in numpy matrix
# img = nib.Nifti1Image(data, np.eye(4))  # Save axis for data (just identity)

# img.header.get_xyzt_units()
# img.to_filename(os.path.join('mini_test/mini_test/LGG/brats_2','brats_2_whimg_norm.nii.gz'))  # Save as NiBabel file

# data = np.ones((240,240,16), dtype=np.int16) # dummy data in numpy matrix
# img = nib.Nifti1Image(data, np.eye(4))  # Save axis for data (just identity)

# img.header.get_xyzt_units()
# img.to_filename(os.path.join('mini_test/mini_test/LGG/brats_2','brats_2_whseg_norm.nii.gz'))  # Save as NiBabel file

# %%
### make sure to run the model for the ends of epoch 1, 2 and 3, make sure to label them corectly

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

x = np.linspace(50, 550, num=11)
x = x.tolist()

empty_data = []
base_dice_frame_total = pd.DataFrame(data=empty_data, columns=range(1)).assign(Data="Base Model")
fr_dice_frame_total = pd.DataFrame(data=empty_data, columns=range(1)).assign(Data="Frozen Model")
unfr_dice_frame_total = pd.DataFrame(data=empty_data, columns=range(1)).assign(Data="Unfrozen Model")

fr_mean = []
unfr_mean = []
base_mean = []

fr_med = []
unfr_med = []
base_med = []

fr_std = []
unfr_std = []
base_std = []

plt.figure(figsize=(20,5))

for i in range(len(x)):
    f = str(int(x[i])) 
    validation_dice_base = np.genfromtxt("Predictions/MK_6_model_predictions/RI_dice_0822/MK_5_base_step_0_" + f + "/0_All_slice_validation_dice.csv",delimiter=',')
    base_dice = pd.DataFrame(data=validation_dice_base, columns=range(1)).assign(Data="Base Dice")

    base_dice_frame = pd.DataFrame(data=base_dice, columns=range(1)).assign(Data="Step " + str(int(x[i])))

    base_dice_frame_total = pd.concat([base_dice_frame_total,base_dice_frame])

    dice_output = pd.melt(base_dice_frame_total, id_vars=['Data'])
    ax = sns.boxplot(x="Data", y="value", data=dice_output)
    base_mean.append(np.mean(base_dice_frame[0].to_numpy()))
    base_med.append(np.median(base_dice_frame[0].to_numpy()))
    base_std.append(np.std(base_dice_frame[0].to_numpy()))
    
for i in range(3):
    f = str(i) 
    validation_dice_base = np.genfromtxt("Predictions/MK_6_model_predictions/RI_dice_0822/MK_5_base_step_" + f + "/0_All_slice_validation_dice.csv",delimiter=',')
    base_dice = pd.DataFrame(data=validation_dice_base, columns=range(1)).assign(Data="Base Dice")

    base_dice_frame = pd.DataFrame(data=base_dice, columns=range(1)).assign(Data="Epoch " + str(i))

    base_dice_frame_total = pd.concat([base_dice_frame_total,base_dice_frame])

    dice_output = pd.melt(base_dice_frame_total, id_vars=['Data'])
    ax = sns.boxplot(x="Data", y="value", data=dice_output)
    base_mean.append(np.mean(base_dice_frame[0].to_numpy()))
    base_med.append(np.median(base_dice_frame[0].to_numpy()))
    base_std.append(np.std(base_dice_frame[0].to_numpy()))
    
plt.ylim([-0.05,1])
plt.title("Box plot for validation dice scores, Randomly init all slices")
plt.ylabel("Mean dice score")
plt.xlabel("")

plt.show()

empty_data = []
# base_dice_frame_total = pd.DataFrame(data=empty_data, columns=range(1)).assign(Data="Base Model")
# fr_dice_frame_total = pd.DataFrame(data=empty_data, columns=range(1)).assign(Data="Frozen Model")
# unfr_dice_frame_total = pd.DataFrame(data=empty_data, columns=range(1)).assign(Data="Unfrozen Model")

plt.figure(figsize=(20,5))

for i in range(len(x)):
    f = str(int(x[i])) 
    validation_dice_fr = np.genfromtxt("Predictions/MK_6_model_predictions/PFE_dice_0822/MK_5_base_step_0_" + f + "/0_All_slice_validation_dice.csv",delimiter=',')
    fr_dice = pd.DataFrame(data=validation_dice_fr, columns=range(1)).assign(Data="Fr Dice")

    fr_dice_frame = pd.DataFrame(data=fr_dice, columns=range(1)).assign(Data="Step " + str(int(x[i])))

    fr_dice_frame_total = pd.concat([fr_dice_frame_total,fr_dice_frame])

    dice_output = pd.melt(fr_dice_frame_total, id_vars=['Data'])
    ax = sns.boxplot(x="Data", y="value", data=dice_output)
    fr_mean.append(np.mean(fr_dice_frame[0].to_numpy()))
    fr_med.append(np.median(fr_dice_frame[0].to_numpy()))
    fr_std.append(np.std(fr_dice_frame[0].to_numpy()))
    
for i in range(3):
    f = str(i) 
    validation_dice_base = np.genfromtxt("Predictions/MK_6_model_predictions/PFE_dice_0822/MK_5_base_step_" + f + "/0_All_slice_validation_dice.csv",delimiter=',')
    fr_dice = pd.DataFrame(data=validation_dice_base, columns=range(1)).assign(Data="Fr Dice")

    fr_dice_frame = pd.DataFrame(data=fr_dice, columns=range(1)).assign(Data="Epoch " + str(i))

    fr_dice_frame_total = pd.concat([fr_dice_frame_total,fr_dice_frame])

    dice_output = pd.melt(fr_dice_frame_total, id_vars=['Data'])
    ax = sns.boxplot(x="Data", y="value", data=dice_output)
    fr_mean.append(np.mean(fr_dice_frame[0].to_numpy()))
    fr_med.append(np.median(fr_dice_frame[0].to_numpy()))
    fr_std.append(np.std(fr_dice_frame[0].to_numpy()))
    
plt.ylim([-0.05,1])
plt.title("Box plot for validation dice scores, Frozen encoder all slices")
plt.ylabel("Mean dice score")
plt.xlabel("")

plt.show()

empty_data = []
# base_dice_frame_total = pd.DataFrame(data=empty_data, columns=range(1)).assign(Data="Base Model")
# fr_dice_frame_total = pd.DataFrame(data=empty_data, columns=range(1)).assign(Data="Frozen Model")
# unfr_dice_frame_total = pd.DataFrame(data=empty_data, columns=range(1)).assign(Data="Unfrozen Model")


plt.figure(figsize=(20,5))

for i in range(len(x)):
    f = str(int(x[i])) 
    validation_dice_unfr = np.genfromtxt("Predictions/MK_6_model_predictions/PTE_dice_0822/MK_5_base_step_0_" + f + "/0_All_slice_validation_dice.csv",delimiter=',')
    unfr_dice = pd.DataFrame(data=validation_dice_unfr, columns=range(1)).assign(Data="Unfr Dice")

    unfr_dice_frame = pd.DataFrame(data=unfr_dice, columns=range(1)).assign(Data="Step " + str(int(x[i])))

    unfr_dice_frame_total = pd.concat([unfr_dice_frame_total,unfr_dice_frame])

    dice_output = pd.melt(unfr_dice_frame_total, id_vars=['Data'])
    ax = sns.boxplot(x="Data", y="value", data=dice_output)
    unfr_mean.append(np.mean(unfr_dice_frame[0].to_numpy()))
    unfr_med.append(np.median(unfr_dice_frame[0].to_numpy()))
    unfr_std.append(np.std(unfr_dice_frame[0].to_numpy()))
    
for i in range(3):
    f = str(i) 
    validation_dice_unfr = np.genfromtxt("Predictions/MK_6_model_predictions/PTE_dice_0822/MK_5_base_step_" + f + "/0_All_slice_validation_dice.csv",delimiter=',')
    unfr_dice = pd.DataFrame(data=validation_dice_unfr, columns=range(1)).assign(Data="Unfr Dice")

    unfr_dice_frame = pd.DataFrame(data=unfr_dice, columns=range(1)).assign(Data="Epoch " + str(i))

    unfr_dice_frame_total = pd.concat([unfr_dice_frame_total,unfr_dice_frame])

    dice_output = pd.melt(unfr_dice_frame_total, id_vars=['Data'])
    ax = sns.boxplot(x="Data", y="value", data=dice_output)
    unfr_mean.append(np.mean(unfr_dice_frame[0].to_numpy()))
    unfr_med.append(np.median(unfr_dice_frame[0].to_numpy()))
    unfr_std.append(np.std(unfr_dice_frame[0].to_numpy()))
    
plt.ylim([-0.05,1])
plt.title("Box plot for validation dice scores, Trainable encoder all slices")
plt.ylabel("Mean dice score")
plt.xlabel("")

plt.show()

# %%
from tabulate import tabulate
print("########### mean ############")
df = pd.DataFrame({'key' : [50,100,150,200,250,300,350,400,450,500,550,1,2,3],
                   'RI' : base_mean,
                   'PFE' : fr_mean,
                   'PTE' : unfr_med})

print(tabulate(df,["Step/Epoch","----- RI -----","---- PFE ----","--- PTE ---"], tablefmt="fancy_grid"))

print("########### median ############")
df = pd.DataFrame({'key' : [50,100,150,200,250,300,350,400,450,500,550,1,2,3],
                   'RI' : base_med,
                   'PFE' : fr_med,
                   'PTE' : unfr_med})

print(tabulate(df,["Step/Epoch","----- RI -----","---- PFE ----","--- PTE ---"], tablefmt="fancy_grid"))
              
print("########### std ############")
df = pd.DataFrame({'key' : [50,100,150,200,250,300,350,400,450,500,550,1,2,3],
                   'RI' : base_std,
                   'PFE' : fr_std,
                   'PTE' : unfr_std})

print(tabulate(df,["Step/Epoch","----- RI -----","---- PFE ----","--- PTE ---"], tablefmt="fancy_grid"))
# Out:
# ########### mean ############
# ╒════╤══════════════╤══════════════════╤═════════════════╤═══════════════╕
# │    │   Step/Epoch │   ----- RI ----- │   ---- PFE ---- │   --- PTE --- │
# ╞════╪══════════════╪══════════════════╪═════════════════╪═══════════════╡
# │  0 │           50 │         0.754939 │        0.748319 │      0.744267 │
# ├────┼──────────────┼──────────────────┼─────────────────┼───────────────┤
# │  1 │          100 │         0.76376  │        0.773783 │      0.810144 │
# ├────┼──────────────┼──────────────────┼─────────────────┼───────────────┤
# │  2 │          150 │         0.762182 │        0.800833 │      0.805088 │
# ├────┼──────────────┼──────────────────┼─────────────────┼───────────────┤
# │  3 │          200 │         0.789058 │        0.819539 │      0.819791 │
# ├────┼──────────────┼──────────────────┼─────────────────┼───────────────┤
# │  4 │          250 │         0.786784 │        0.824761 │      0.81615  │
# ...

# %%
### make sure to run the model for the ends of epoch 1, 2 and 3, make sure to label them corectly

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

x = np.linspace(50, 550, num=11)
x = x.tolist()

empty_data = []
base_dice_frame_total = pd.DataFrame(data=empty_data, columns=range(1)).assign(Data="Base Model")
fr_dice_frame_total = pd.DataFrame(data=empty_data, columns=range(1)).assign(Data="Frozen Model")
unfr_dice_frame_total = pd.DataFrame(data=empty_data, columns=range(1)).assign(Data="Unfrozen Model")

fr_mean = []
unfr_mean = []
base_mean = []

fr_med = []
unfr_med = []
base_med = []

fr_std = []
unfr_std = []
base_std = []

# output_type = "All"
output_type = "Tumour"
# output_type = "None"

plt.figure(figsize=(20,5))

for i in range(len(x)):
    f = str(int(x[i])) 
    validation_dice_base = np.genfromtxt("Predictions/MK_6_model_predictions/RI_dice_0822/MK_5_base_step_0_" + f + "/0_"+output_type+"_slice_validation_dice.csv",delimiter=',')
    base_dice = pd.DataFrame(data=validation_dice_base, columns=range(1)).assign(Data="Base Dice")

    base_dice_frame = pd.DataFrame(data=base_dice, columns=range(1)).assign(Data="Step " + str(int(x[i])))

    base_dice_frame_total = pd.concat([base_dice_frame_total,base_dice_frame])

    dice_output = pd.melt(base_dice_frame_total, id_vars=['Data'])
    ax = sns.boxplot(x="Data", y="value", data=dice_output)
    base_mean.append(np.mean(base_dice_frame[0].to_numpy()))
    base_med.append(np.median(base_dice_frame[0].to_numpy()))
    base_std.append(np.std(base_dice_frame[0].to_numpy()))
    
for i in range(3):
    f = str(i) 
    validation_dice_base = np.genfromtxt("Predictions/MK_6_model_predictions/RI_dice_0822/MK_5_base_step_" + f + "/0_Tumour_slice_validation_dice.csv",delimiter=',')
    base_dice = pd.DataFrame(data=validation_dice_base, columns=range(1)).assign(Data="Base Dice")

    base_dice_frame = pd.DataFrame(data=base_dice, columns=range(1)).assign(Data="Epoch " + str(i))

    base_dice_frame_total = pd.concat([base_dice_frame_total,base_dice_frame])

    dice_output = pd.melt(base_dice_frame_total, id_vars=['Data'])
    ax = sns.boxplot(x="Data", y="value", data=dice_output)
    base_mean.append(np.mean(base_dice_frame[0].to_numpy()))
    base_med.append(np.median(base_dice_frame[0].to_numpy()))
    base_std.append(np.std(base_dice_frame[0].to_numpy()))
    
plt.ylim([-0.05,1])
plt.title("Box plot for validation dice scores, Randomly init all slices")
plt.ylabel("Mean dice score")
plt.xlabel("")

plt.show()

empty_data = []
# base_dice_frame_total = pd.DataFrame(data=empty_data, columns=range(1)).assign(Data="Base Model")
# fr_dice_frame_total = pd.DataFrame(data=empty_data, columns=range(1)).assign(Data="Frozen Model")
# unfr_dice_frame_total = pd.DataFrame(data=empty_data, columns=range(1)).assign(Data="Unfrozen Model")

plt.figure(figsize=(20,5))

for i in range(len(x)):
    f = str(int(x[i])) 
    validation_dice_fr = np.genfromtxt("Predictions/MK_6_model_predictions/PFE_dice_0822/MK_5_base_step_0_" + f + "/0_"+output_type+"_slice_validation_dice.csv",delimiter=',')
    fr_dice = pd.DataFrame(data=validation_dice_fr, columns=range(1)).assign(Data="Fr Dice")

    fr_dice_frame = pd.DataFrame(data=fr_dice, columns=range(1)).assign(Data="Step " + str(int(x[i])))

    fr_dice_frame_total = pd.concat([fr_dice_frame_total,fr_dice_frame])

    dice_output = pd.melt(fr_dice_frame_total, id_vars=['Data'])
    ax = sns.boxplot(x="Data", y="value", data=dice_output)
    fr_mean.append(np.mean(fr_dice_frame[0].to_numpy()))
    fr_med.append(np.median(fr_dice_frame[0].to_numpy()))
    fr_std.append(np.std(fr_dice_frame[0].to_numpy()))
    
for i in range(3):
    f = str(i) 
    validation_dice_fr = np.genfromtxt("Predictions/MK_6_model_predictions/PFE_dice_0822/MK_5_base_step_" + f + "/0_Tumour_slice_validation_dice.csv",delimiter=',')
    fr_dice = pd.DataFrame(data=validation_dice_fr, columns=range(1)).assign(Data="Fr Dice")

    fr_dice_frame = pd.DataFrame(data=fr_dice, columns=range(1)).assign(Data="Epoch " + str(i))

    fr_dice_frame_total = pd.concat([fr_dice_frame_total,fr_dice_frame])

    dice_output = pd.melt(fr_dice_frame_total, id_vars=['Data'])
    ax = sns.boxplot(x="Data", y="value", data=dice_output)
    fr_mean.append(np.mean(fr_dice_frame[0].to_numpy()))
    fr_med.append(np.median(fr_dice_frame[0].to_numpy()))
    fr_std.append(np.std(fr_dice_frame[0].to_numpy()))
    
plt.ylim([-0.05,1])
plt.title("Box plot for validation dice scores, Frozen encoder all slices")
plt.ylabel("Mean dice score")
plt.xlabel("")

plt.show()

empty_data = []
# base_dice_frame_total = pd.DataFrame(data=empty_data, columns=range(1)).assign(Data="Base Model")
# fr_dice_frame_total = pd.DataFrame(data=empty_data, columns=range(1)).assign(Data="Frozen Model")
# unfr_dice_frame_total = pd.DataFrame(data=empty_data, columns=range(1)).assign(Data="Unfrozen Model")


plt.figure(figsize=(20,5))

for i in range(len(x)):
    f = str(int(x[i])) 
    validation_dice_unfr = np.genfromtxt("Predictions/MK_6_model_predictions/PTE_dice_0822/MK_5_base_step_0_" + f + "/0_"+output_type+"_slice_validation_dice.csv",delimiter=',')
    unfr_dice = pd.DataFrame(data=validation_dice_unfr, columns=range(1)).assign(Data="Unfr Dice")

    unfr_dice_frame = pd.DataFrame(data=unfr_dice, columns=range(1)).assign(Data="Step " + str(int(x[i])))

    unfr_dice_frame_total = pd.concat([unfr_dice_frame_total,unfr_dice_frame])

    dice_output = pd.melt(base_dice_frame_total, id_vars=['Data'])
    ax = sns.boxplot(x="Data", y="value", data=dice_output)
    unfr_mean.append(np.mean(unfr_dice_frame[0].to_numpy()))
    unfr_med.append(np.median(unfr_dice_frame[0].to_numpy()))
    unfr_std.append(np.std(unfr_dice_frame[0].to_numpy()))
    
for i in range(3):
    f = str(i) 
    validation_dice_unfr = np.genfromtxt("Predictions/MK_6_model_predictions/PTE_dice_0822/MK_5_base_step_" + f + "/0_Tumour_slice_validation_dice.csv",delimiter=',')
    unfr_dice = pd.DataFrame(data=validation_dice_unfr, columns=range(1)).assign(Data="unfr Dice")

    unfr_dice_frame = pd.DataFrame(data=unfr_dice, columns=range(1)).assign(Data="Epoch " + str(i))

    unfr_dice_frame_total = pd.concat([base_dice_frame_total,base_dice_frame])

    dice_output = pd.melt(unfr_dice_frame_total, id_vars=['Data'])
    ax = sns.boxplot(x="Data", y="value", data=dice_output)
    unfr_mean.append(np.mean(unfr_dice_frame[0].to_numpy()))
    unfr_med.append(np.median(unfr_dice_frame[0].to_numpy()))
    unfr_std.append(np.std(unfr_dice_frame[0].to_numpy()))
    
plt.ylim([-0.05,1])
plt.title("Box plot for validation dice scores, Trainable encoder all slices")
plt.ylabel("Mean dice score")
plt.xlabel("")

plt.show()

# %%
from tabulate import tabulate
print("########### mean ############")
df = pd.DataFrame({'key' : [50,100,150,200,250,300,350,400,450,500,550,1,2,3],
                   'RI' : base_mean,
                   'PFE' : fr_mean,
                   'PTE' : unfr_med})

print(tabulate(df,["Step/Epoch","----- RI -----","---- PFE ----","--- PTE ---"], tablefmt="fancy_grid"))

print("########### median ############")
df = pd.DataFrame({'key' : [50,100,150,200,250,300,350,400,450,500,550,1,2,3],
                   'RI' : base_med,
                   'PFE' : fr_med,
                   'PTE' : unfr_med})

print(tabulate(df,["Step/Epoch","----- RI -----","---- PFE ----","--- PTE ---"], tablefmt="fancy_grid"))
              
print("########### std ############")
df = pd.DataFrame({'key' : [50,100,150,200,250,300,350,400,450,500,550,1,2,3],
                   'RI' : base_std,
                   'PFE' : fr_std,
                   'PTE' : unfr_std})

print(tabulate(df,["Step/Epoch","----- RI -----","---- PFE ----","--- PTE ---"], tablefmt="fancy_grid"))
# Out:
# ########### mean ############
# ╒════╤══════════════╤══════════════════╤═════════════════╤═══════════════╕
# │    │   Step/Epoch │   ----- RI ----- │   ---- PFE ---- │   --- PTE --- │
# ╞════╪══════════════╪══════════════════╪═════════════════╪═══════════════╡
# │  0 │           50 │         0.527194 │        0.449359 │      0.448912 │
# ├────┼──────────────┼──────────────────┼─────────────────┼───────────────┤
# │  1 │          100 │         0.57891  │        0.53434  │      0.623419 │
# ├────┼──────────────┼──────────────────┼─────────────────┼───────────────┤
# │  2 │          150 │         0.468914 │        0.622978 │      0.628052 │
# ├────┼──────────────┼──────────────────┼─────────────────┼───────────────┤
# │  3 │          200 │         0.610241 │        0.672428 │      0.624414 │
# ├────┼──────────────┼──────────────────┼─────────────────┼───────────────┤
# │  4 │          250 │         0.619387 │        0.653544 │      0.575001 │
# ...

# %%
import os
import numpy as np
from nibabel.testing import data_path
import nibabel as nib
from matplotlib import pyplot as plt

path1 = "Brats_2018_data/Brats_2018_data/HGG/Brats18_CBICA_AUN_1/Brats18_CBICA_AUN_1_whseg_norm.nii.gz"
path2 = "Brats_2018_data/Brats_2018_data/HGG/Brats18_CBICA_AUN_1/Brats18_CBICA_AUN_1_whimg_norm.nii.gz"

fig, ax = plt.subplots(1, 2,figsize=(8, 4))

slice_val = 80

img = nib.load(path1)
data = img.get_fdata()
print(data.shape)
ax[0].imshow(data[:,:,slice_val], cmap='Greys_r', interpolation='nearest')
ax[0].grid(None) 
ax[0].axis('off')

img = nib.load(path2)
data = img.get_fdata()
print(data.shape)
ax[1].imshow(data[1,:,:,slice_val], cmap='Greys_r', interpolation='nearest')
ax[1].grid(None) 
ax[1].axis('off')
plt.show()

# img = nib.load(path1)
# data = img.get_fdata()

# img = nib.load(path2)
# data2 = img.get_fdata()
# print(data2.shape)
# plt.imshow(data2[1,:,:,118], cmap='Greys_r', interpolation='nearest')
# plt.grid(None) 
# plt.axis('off')
# plt.show()

# data[:,:,118][ data[:,:,118]==0 ] = np.nan
# plt.imshow(data2[1,:,:,118], cmap='Greys_r', interpolation='nearest')
# plt.imshow((data[:,:,118]), cmap='jet', interpolation='nearest',alpha=0.5)
# plt.grid(None) 
# plt.axis('off')
# plt.show()
# Out:
# (240, 240, 155)
# (4, 240, 240, 155)

# %%
import os
import numpy as np
from nibabel.testing import data_path
import nibabel as nib
from matplotlib import pyplot as plt
from pylab import figure, text, scatter, show

slice_val = 45
slice_name = "ASH"


path1 = "Brats_2018_data/Brats_2018_data/LGG/Brats18_2013_15_1/Brats18_2013_15_1_whseg_norm.nii.gz"
path2 = "Brats_2018_data/Brats_2018_data/LGG/Brats18_2013_15_1/Brats18_2013_15_1_whimg_norm.nii.gz"

fig, ax = plt.subplots(1, 2,figsize=(8, 4))

img = nib.load(path1)
data = img.get_fdata()
print(data.shape)
print(data.shape)
ax[0].imshow(data[:,:,slice_val], cmap='Greys_r', interpolation='nearest')
ax[0].grid(None) 
ax[0].axis('off')

img = nib.load(path2)
data = img.get_fdata()
print(data.shape)
ax[1].imshow(data[1,:,:,slice_val], cmap='Greys_r', interpolation='nearest')
ax[1].grid(None) 
ax[1].axis('off')
plt.show()

#path1 = "Predictions/MK_5_model_predictions_2/MK_5_base_step_50/HGG_Brats18_CBICA_AUN_1_0_.nii.gz"

path1 = "Predictions/MK_6_model_predictions/RI_dice_0822/MK_5_base_step_0_100/LGG_Brats18_CBICA_"+slice_name+"_1.nii.gz"
path2 = "Predictions/MK_6_model_predictions/RI_dice_0822/MK_5_base_step_0_550/LGG_Brats18_CBICA_"+slice_name+"_1.nii.gz"
path3 = "Predictions/MK_6_model_predictions/RI_dice_0822/MK_5_base_step_0/LGG_Brats18_CBICA_"+slice_name+"_1.nii.gz"
path4 = "Predictions/MK_6_model_predictions/RI_dice_0822/MK_5_base_step_1/LGG_Brats18_CBICA_"+slice_name+"_1.nii.gz"

output_score = [0.58 ,0.59,0.59,0.68]

x = [path1,path2,path3,path4]

fig, ax = plt.subplots(1, 4,figsize=(18, 4))

for i in range(len(x)):
    img = nib.load(x[i])
    data = img.get_fdata()
    print(data.shape)
    ax[i].imshow(data[:,:,slice_val], cmap='Greys_r', interpolation='nearest')
    ax[i].grid(None) 
    ax[i].axis('off')
    text(0.32, 0.95,'Dice Score = '+ str(output_score[i]),
        horizontalalignment='center',
        verticalalignment='center',
        transform = ax[i].transAxes,
        color = "white"
        )
plt.show()

path1 = "Predictions/MK_6_model_predictions/PFE_dice_0822/MK_5_base_step_0_100/LGG_Brats18_CBICA_"+slice_name+"_1.nii.gz"
path2 = "Predictions/MK_6_model_predictions/PFE_dice_0822/MK_5_base_step_0_550/LGG_Brats18_CBICA_"+slice_name+"_1.nii.gz"
path3 = "Predictions/MK_6_model_predictions/PFE_dice_0822/MK_5_base_step_0/LGG_Brats18_CBICA_"+slice_name+"_1.nii.gz"
path4 = "Predictions/MK_6_model_predictions/PFE_dice_0822/MK_5_base_step_1/LGG_Brats18_CBICA_"+slice_name+"_1.nii.gz"

output_score = [0.58 ,0.59,0.59,0.68]

x = [path1,path2,path3,path4]

fig, ax = plt.subplots(1, 4,figsize=(18, 4))

for i in range(len(x)):
    img = nib.load(x[i])
    data = img.get_fdata()
    ax[i].imshow(data[:,:,slice_val], cmap='Greys_r', interpolation='nearest')
    ax[i].grid(None) 
    ax[i].axis('off')
    text(0.32, 0.95,'Dice Score = '+ str(output_score[i]),
        horizontalalignment='center',
        verticalalignment='center',
        transform = ax[i].transAxes,
        color = "white"
        )
plt.show()

path1 = "Predictions/MK_6_model_predictions/PTE_dice_0822/MK_5_base_step_0_100/LGG_Brats18_CBICA_"+slice_name+"_1.nii.gz"
path2 = "Predictions/MK_6_model_predictions/PTE_dice_0822/MK_5_base_step_0_550/LGG_Brats18_CBICA_"+slice_name+"_1.nii.gz"
path3 = "Predictions/MK_6_model_predictions/PTE_dice_0822/MK_5_base_step_0/LGG_Brats18_CBICA_"+slice_name+"_1.nii.gz"
path4 = "Predictions/MK_6_model_predictions/PTE_dice_0822/MK_5_base_step_1/LGG_Brats18_CBICA_"+slice_name+"_1.nii.gz"

output_score = [0.58 ,0.59,0.59,0.68]

x = [path1,path2,path3,path4]

fig, ax = plt.subplots(1, 4,figsize=(18, 4))

for i in range(len(x)):
    img = nib.load(x[i])
    data = img.get_fdata()
    ax[i].imshow(data[:,:,slice_val], cmap='Greys_r', interpolation='nearest')
    ax[i].grid(None) 
    ax[i].axis('off')
    text(0.32, 0.95,'Dice Score = '+ str(output_score[i]),
        horizontalalignment='center',
        verticalalignment='center',
        transform = ax[i].transAxes,
        color = "white"
        )
plt.show()
# Out:
# (240, 240, 155)
# (240, 240, 155)
# (4, 240, 240, 155)
# (240, 240, 155)
# (240, 240, 155)
# (240, 240, 155)
# (240, 240, 155)

# %%
import os
import numpy as np
from nibabel.testing import data_path
import nibabel as nib
from matplotlib import pyplot as plt
from pylab import figure, text, scatter, show

slice_val = 31

mode = ["RI","PFE","PTE"]
selection = "AUN"

path1 = "Brats_2018_data/Brats_2018_data/HGG/Brats18_CBICA_"+selection+"_1/Brats18_CBICA_"+selection+"_1_whseg_norm.nii.gz"
path2 = "Brats_2018_data/Brats_2018_data/HGG/Brats18_CBICA_"+selection+"_1/Brats18_CBICA_"+selection+"_1_whimg_norm.nii.gz"

fig, ax = plt.subplots(1, 2,figsize=(8, 4))

img = nib.load(path1)
data = img.get_fdata()
print(data.shape)
print(data.shape)
ax[0].imshow(data[:,:,slice_val], cmap='Greys_r', interpolation='nearest')
ax[0].grid(None) 
ax[0].axis('off')

img = nib.load(path2)
data = img.get_fdata()
print(data.shape)
ax[1].imshow(data[1,:,:,slice_val], cmap='Greys_r', interpolation='nearest')
ax[1].grid(None) 
ax[1].axis('off')
plt.show()

for j in range(len(mode)):
    path1 = "Predictions/MK_6_model_predictions/"+mode[j]+"_dice_0822_2/step_0_100/Brats18_CBICA_"+selection+"_1.nii.gz"
    path2 = "Predictions/MK_6_model_predictions/"+mode[j]+"_dice_0822_2/step_0_550/Brats18_CBICA_"+selection+"_1.nii.gz"
    path3 = "Predictions/MK_6_model_predictions/"+mode[j]+"_dice_0822_2/MK_5_base_step_0/Brats18_CBICA_"+selection+"_1.nii.gz"
    path4 = "Predictions/MK_6_model_predictions/"+mode[j]+"_dice_0822_2/MK_5_base_step_1/Brats18_CBICA_"+selection+"_1.nii.gz"

    output_score = [0,0,0,0]

    x = [path1,path2,path3,path4]

    fig, ax = plt.subplots(1, 4,figsize=(18, 4))

    for i in range(len(x)):
        img = nib.load(x[i])
        data = img.get_fdata()
        ax[i].imshow(data[:,:,slice_val], cmap='Greys_r', interpolation='nearest')
        ax[i].grid(None) 
        ax[i].axis('off')
#         text(0.32, 0.95,'Dice Score = '+ str(output_score[i]),
#             horizontalalignment='center',
#             verticalalignment='center',
#             transform = ax[i].transAxes,
#             color = "white"
#             )
    print(mode[j])
    plt.show()
# Out:
# (240, 240, 155)
# (240, 240, 155)
# (4, 240, 240, 155)
# RI
# PFE
# PTE

# %%
index = np.load("Brats_2018_data/Brats_2018_data/index_max_original.npy")
print(index)
# Out:
# [    0   155   310   465   620   775   930  1085  1240  1395  1550  1705
#   1860  2015  2170  2325  2480  2635  2790  2945  3100  3255  3410  3565
#   3720  3875  4030  4185  4340  4495  4650  4805  4960  5115  5270  5425
#   5580  5735  5890  6045  6200  6355  6510  6665  6820  6975  7130  7285
#   7440  7595  7750  7905  8060  8215  8370  8525  8680  8835  8990  9145
#   9300  9455  9610  9765  9920 10075 10230 10385 10540 10695 10850 11005
#  11160 11315 11470 11625 11780 11935 12090 12245 12400 12555 12710 12865
#  13020 13175 13330 13485 13640 13795 13950 14105 14260 14415 14570 14725
#  14880 15035 15190 15345 15500 15655 15810 15965 16120 16275 16430 16585
#  16740 16895 17050 17205 17360 17515 17670 17825 17980 18135 18290 18445
#  18600 18755 18910 19065 19220 19375 19530 19685 19840 19995 20150 20305
#  20460 20615 20770 20925 21080 21235 21390 21545 21700 21855 22010 22165
#  22320 22475 22630 22785 22940 23095 23250 23405 23560 23715 23870 24025
# ...

# %%
import os
import numpy as np
from nibabel.testing import data_path
import nibabel as nib
from matplotlib import pyplot as plt
from pylab import figure, text, scatter, show

# Brats18_TCIA03_138
# PFE[32]
# PTE[33,34]
# errors [84,86,89,91]

# Brats18_CBICA_AVG

slice_val = 60

mode = ["RI","PFE","PTE"]
# selection = "Brats18_CBICA_AVG"
selection = "Brats18_TCIA03_138"

path1 = "Brats_2018_data/Brats_2018_data/HGG/"+selection+"_1/"+selection+"_1_whseg_norm.nii.gz"
path2 = "Brats_2018_data/Brats_2018_data/HGG/"+selection+"_1/"+selection+"_1_whimg_norm.nii.gz"

fig, ax = plt.subplots(1, 2,figsize=(8, 4))

img = nib.load(path1)
data_truth = img.get_fdata()
print(data_truth.shape)
print(data_truth.shape)
ax[0].imshow(data_truth[:,:,slice_val], cmap='Greys_r', interpolation='nearest')
ax[0].grid(None) 
ax[0].axis('off')

img = nib.load(path2)
data = img.get_fdata()
print(data.shape)
ax[1].imshow(data[1,:,:,slice_val], cmap='Greys_r', interpolation='nearest')
ax[1].grid(None) 
ax[1].axis('off')
plt.show()

# C = np.bincount(((mask==255)*2 + (data_truth[:,:,slice_val]==255)).ravel())

for j in range(len(mode)):
    path1 = "Predictions/MK_6_model_predictions/"+mode[j]+"_dice_0822_3_3_small/step_0_50/"+selection+"_1.nii.gz"
    path2 = "Predictions/MK_6_model_predictions/"+mode[j]+"_dice_0822_3_3_small/step_0_550/"+selection+"_1.nii.gz"
#     path3 = "Predictions/MK_6_model_predictions/"+mode[j]+"_dice_0822_3_3_small/step_0_550/"+selection+"_1.nii.gz"
    
    path3 = "Predictions/MK_6_model_predictions/"+mode[j]+"_dice_0822_3_3_small/step_0/"+selection+"_1.nii.gz"
    path4 = "Predictions/MK_6_model_predictions/"+mode[j]+"_dice_0822_3_3_small/step_2/"+selection+"_1.nii.gz"

    output_score = [0,0,0,0]

    x = [path1,path2,path3,path4]

    fig, ax = plt.subplots(1, 4,figsize=(18, 4))

    for i in range(len(x)):
        
        img = nib.load(x[i])
        data = img.get_fdata()
        
        mask = data[:,:,slice_val]
        truth = data_truth[:,:,slice_val]
        
        tp = int(np.sum(mask * truth))
        tn = len(mask.flat) - np.count_nonzero(mask + truth)
        fp = np.count_nonzero(mask - truth == 1)
        fn = np.count_nonzero(truth - mask == 1)
        
        sensitivity = tp / ((tp + fn) + 0.00001)
        specificity = tn / ((fp + tn) + 0.00001)
        precision = tp / ((tp + fp) + 0.00001)
#         recall = tp / (tp + fn) 
        f1 = 2 * (precision * sensitivity) / ((precision + sensitivity) + 0.00001)
        
        print("MAX", np.max(truth))
        dice = np.sum(mask[truth==1])*2.0 / ((np.sum(mask) + np.sum(truth)) + 0.00001)
        
        #print(tp,tn,fp,fn)
        #print("")
        print("Pixelwise statistics of image ", i+1)
        print("sensitivity",sensitivity)
        print("specificity",specificity)
        print("precision",precision)
        print("f1",f1)
        print("Dice", dice)
        print("")
        
        ax[i].imshow(data[:,:,slice_val], cmap='Greys_r', interpolation='nearest')
        ax[i].grid(None) 
        ax[i].axis('off')
        text(0.32, 0.95,'Dice Score = '+ str(output_score[i]),
            horizontalalignment='center',
            verticalalignment='center',
            transform = ax[i].transAxes,
            color = "white"
            )
    print(mode[j])
    plt.show()
    
   # [68,72,74,72]
# Out:
# (240, 240, 155)
# (240, 240, 155)
# (4, 240, 240, 155)
# MAX 1.0
# Pixelwise statistics of image  1
# sensitivity 0.9457231159542318
# specificity 0.9930333337612621
# precision 0.8784301184478936
# f1 0.910830404976195
# Dice 0.9108353996512235
#
# MAX 1.0
# Pixelwise statistics of image  2
# sensitivity 0.9498454106841449
# specificity 0.9970377953524405
# precision 0.9446532253342903
# f1 0.9472372030538685
# Dice 0.9472422046124663
#
# MAX 1.0
# Pixelwise statistics of image  3
# sensitivity 0.9642734422388407
# specificity 0.9968732284377345
# precision 0.9425789088563501
# f1 0.9532977653081478
# Dice 0.9533027662535188
#
# MAX 1.0
# Pixelwise statistics of image  4
# sensitivity 0.9309515598387098
# specificity 0.9979154855642056
# precision 0.9596317246471964
# f1 0.9450691042457032
# Dice 0.945074104716523
#
# RI
# MAX 1.0
# Pixelwise statistics of image  1
# sensitivity 0.8395740266589693
# specificity 0.9880780411073381
# precision 0.7894056822047619
# ...

# %%
import os
import numpy as np
from nibabel.testing import data_path
import nibabel as nib
from matplotlib import pyplot as plt
from pylab import figure, text, scatter, show

slice_val = 69

mode = ["RI","PFE","PTE"]
# selection = "Brats18_CBICA_AVG"
selection = "Brats18_TCIA03_138"

path1 = "Brats_2018_data/Brats_2018_data/HGG/"+selection+"_1/"+selection+"_1_whseg_norm.nii.gz"
path2 = "Brats_2018_data/Brats_2018_data/HGG/"+selection+"_1/"+selection+"_1_whimg_norm.nii.gz"

fig, ax = plt.subplots(1, 2,figsize=(8, 4))

img = nib.load(path1)
data_truth = img.get_fdata()
print(data_truth.shape)
print(data_truth.shape)
ax[0].imshow(data_truth[:,:,slice_val], cmap='Greys_r', interpolation='nearest')
ax[0].grid(None) 
ax[0].axis('off')

img = nib.load(path2)
data = img.get_fdata()
print(data.shape)
ax[1].imshow(data[1,:,:,slice_val], cmap='Greys_r', interpolation='nearest')
ax[1].grid(None) 
ax[1].axis('off')
plt.show()

# C = np.bincount(((mask==255)*2 + (data_truth[:,:,slice_val]==255)).ravel())

for j in range(len(mode)):
    path1 = "Predictions/MK_6_model_predictions/"+mode[j]+"_dice_0822_3_3/step_0_50/"+selection+"_1.nii.gz"
    path2 = "Predictions/MK_6_model_predictions/"+mode[j]+"_dice_0822_3_3/step_0_550/"+selection+"_1.nii.gz"
#     path3 = "Predictions/MK_6_model_predictions/"+mode[j]+"_dice_0822_3_3_small/step_0_550/"+selection+"_1.nii.gz"
    
    path3 = "Predictions/MK_6_model_predictions/"+mode[j]+"_dice_0822_3_3/step_0/"+selection+"_1.nii.gz"
    path4 = "Predictions/MK_6_model_predictions/"+mode[j]+"_dice_0822_3_3/step_2/"+selection+"_1.nii.gz"

    output_score = [0,0,0,0]

    x = [path1,path2,path3,path4]

    fig, ax = plt.subplots(1, 4,figsize=(18, 4))

    for i in range(len(x)):
        
        img = nib.load(x[i])
        data = img.get_fdata()
        
        mask = data[:,:,slice_val]
        truth = data_truth[:,:,slice_val]
        
        tp = int(np.sum(mask * truth))
        tn = len(mask.flat) - np.count_nonzero(mask + truth)
        fp = np.count_nonzero(mask - truth == 1)
        fn = np.count_nonzero(truth - mask == 1)
        
        sensitivity = tp / (tp + fn)
        specificity = tn / (fp + tn)
        precision = tp / (tp + fp)
#         recall = tp / (tp + fn) 
        f1 = 2 * (precision * sensitivity) / (precision + sensitivity)
        
        #print(tp,tn,fp,fn)
        #print("")
        print("Pixelwise statistics of image ", i+1)
        print("sensitivity",sensitivity)
        print("specificity",specificity)
        print("precision",precision)
        print("f1",f1)
        print("")
        
        ax[i].imshow(data[:,:,slice_val], cmap='Greys_r', interpolation='nearest')
        ax[i].grid(None) 
        ax[i].axis('off')
        text(0.32, 0.95,'Dice Score = '+ str(output_score[i]),
            horizontalalignment='center',
            verticalalignment='center',
            transform = ax[i].transAxes,
            color = "white"
            )
    print(mode[j])
    plt.show()
# Out:
# (240, 240, 155)
# (240, 240, 155)
# (4, 240, 240, 155)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/nibabel/loadsave.py in load(filename, **kwargs)
#      41     try:
# ---> 42         stat_result = os.stat(filename)
#      43     except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Predictions/MK_6_model_predictions/RI_dice_0822_3_3/step_0_50/Brats18_TCIA03_138_1.nii.gz'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-3167e9d84f13> in <module>
#      51     for i in range(len(x)):
#      52
# ---> 53         img = nib.load(x[i])
#      54         data = img.get_fdata()
#      55
#
# /usr/local/lib/python3.6/dist-packages/nibabel/loadsave.py in load(filename, **kwargs)
# ...

# %%
#### import os
import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# go through each of the image channels and check the min, max and histogram layouts 
# for each of the examples before and after normalisation.

input_string = "ALX"
output_titles = ["T1","FLAIR","T1ce","T2"]
output_titles_seg = ["Segmentation ground\ntruth"]
image_path = "Brats_2018_data/Brats_2018_data/HGG/Brats18_CBICA_" + input_string + "_1/"
# possible_outputs = [
#     "Brats18_CBICA_" + input_string + "_1_flair.nii.gz",
#     "Brats18_CBICA_" + input_string + "_1_t1.nii.gz",
#     "Brats18_CBICA_" + input_string + "_1_t1ce.nii.gz",
#     "Brats18_CBICA_" + input_string + "_1_t2.nii.gz",
#     "Brats18_CBICA_" + input_string + "_1_whseg_norm.nii.gz"
# ]

possible_outputs_seg = ["Brats18_CBICA_" + input_string + "_1_whseg_norm.nii.gz"]

for i in range(len(possible_outputs_seg)):
    print(output_titles[i])
    img_a = nib.load(image_path + possible_outputs_seg[i])
    img_data = img_a.get_fdata()
    plt.imshow(img_data[:,:,80],"gray")
    plt.grid(False)
    plt.axis('off')
#     if i == len(possible_outputs) -1:
        
    plt.text(0.5, 38.5,output_titles_seg[i],c = "w", size = "xx-large")
#     else:
#         plt.text(0.5, 15.5,output_titles[i],c = "w", size = "xx-large")
                 
    
    plt.show()

image_path = "Brats_2018_data/Brats_2018_data/HGG/Brats18_CBICA_" + input_string + "_1/"
possible_outputs = ["Brats18_CBICA_"+input_string+"_1_whimg_norm.nii.gz"]

for i in range(4):
    img_a = nib.load(image_path + possible_outputs[0])
    img_data = img_a.get_fdata()
    
#     if i == len(possible_outputs) -1:
#         plt.text(0.5, 38.5,output_titles[i],c = "w", size = "xx-large")
#     else:
    plt.text(0.5, 15.5,output_titles[i],c = "w", size = "xx-large")
            

#     print(np.min(img_data[i,:,:,73]),"-", np.max(img_data[i,:,:,73]))
#     print("")
    plt.imshow(img_data[i,:,:,80],"gray")
    plt.grid(False)
    plt.axis('off')
    plt.show()
    
#     score_data = pd.DataFrame(data = img_data[i,:,:,73].flatten(),columns=['score']).assign(group = 'Group A')
    
#     sns.histplot(data = score_data,x="score")
#     plt.show()
    

# image_path = "Brats_2018_data/Brats_2018_data/HGG/Brats18_CBICA_ABB_1/"
# possible_outputs = [
#     "Brats18_CBICA_ABB_1_whimg_norm.nii.gz"
# ]

RANO_output = "Brats18_CBICA_" + input_string + "_1_RANO.npz"

img_a = nib.load(image_path + possible_outputs_seg[0])
img_data = img_a.get_fdata()
plt.imshow(img_data[:,:,80],"gray")
plt.grid(False)

slice_val = 80

data = np.load(image_path + RANO_output)
lst = data.files
for item in lst:
    data_in = data[item][:,slice_val]

D1 = np.asarray([[data_in[1],data_in[3]],[data_in[0],data_in[2]]]) 
D2 = np.asarray([[data_in[5],data_in[7]],[data_in[4],data_in[6]]]) 

plt.plot(D1[0, :], D1[1, :], lw=2, c='r',label='_nolegend_')
plt.plot(D2[0, :], D2[1, :], lw=2, c='r',label='Prediction')

plt.axis('off')
plt.text(0.5, 15.5,"RANO on Ground truth",c = "w", size = "xx-large")


plt.show()
# Out:
# T1
