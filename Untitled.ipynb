# %%
for i in range(10):
    # %run "Code_UNet_2/Code_UNet/Test_Augment.py"
# Out:
# (1, 8)
# [[ 65. 136.  52. 129.  63. 128.  57. 139.]]
# Before (8,)
# After (1, 8)
# Truth before Augmentation
# YIN [[123.21495327  48.04672897 114.8411215   32.4953271  113.64485981
#    45.65420561 126.80373832  38.47663551]]
# (1, 8)
# [[123.21495327  48.04672897 114.8411215   32.4953271  113.64485981
#    45.65420561 126.80373832  38.47663551]]
# Before (8,)
# After (1, 8)
# Output after Augmentation
# (1, 8)
# [[ 65. 136.  52. 129.  63. 128.  57. 139.]]
# Before (8,)
# After (1, 8)
# Truth before Augmentation
# YIN [[ 65. 136.  52. 129.  63. 128.  57. 139.]]
# (1, 8)
# [[ 65. 136.  52. 129.  63. 128.  57. 139.]]
# Before (8,)
# After (1, 8)
# Output after Augmentation
# (1, 8)
# [[ 65. 136.  52. 129.  63. 128.  57. 139.]]
# Before (8,)
# After (1, 8)
# Truth before Augmentation
# YIN [[ 65. 136.  52. 129.  63. 128.  57. 139.]]
# (1, 8)
# [[ 65. 136.  52. 129.  63. 128.  57. 139.]]
# Before (8,)
# After (1, 8)
# Output after Augmentation
# (1, 8)
# ...
