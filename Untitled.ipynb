# %%
# %run "Code_UNet_2/Code_UNet/Train.py"
# Out:
# Train_seg.py start
# Torch version:  1.10.1+cu102
#
# Seed                          0
# device                        cuda
# GPU                           3
# Param_location                Code_UNet_2/Code_UNet/Net_modules/Parameters_SEG.py
# Debug                         True
# Cosine_penalty                100
# Epochs                        50
# Batch_size                    8
# Learning_rate                 0.0003
# Weight_decay                  1e-08
# Betas                         (0.9, 0.999)
# Input_dim                     1
# Label_dim                     1
# Hidden_dim                    16
# Train_split                   0.7
# Validation_split              0.1
# Test_split                    0.2
# Custom_split                  0.5
# Batch_display_step            100
# Confirm_display_step          True
# Image_scale                   1
# New_index                     False
# Image_size                    [256, 256]
# Evaluate                      False
# ...
