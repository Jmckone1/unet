# %%
values = np.linspace(50, 550, num=11)
values
# Out:
# array([ 50., 100., 150., 200., 250., 300., 350., 400., 450., 500., 550.])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

x = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_base/epoch_0training_loss.csv", delimiter=',')
#plt.plot(range(len(x) ),x)
plt.plot(range(250),x[:250])
x = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_frozen/epoch_0training_loss.csv", delimiter=',')
#plt.plot(range(len(x) ),x)
plt.plot(range(250),x[:250])
x = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen/epoch_0training_loss.csv", delimiter=',')
#plt.plot(range(len(x) ),x)
plt.plot(range(250),x[:250])
plt.title("first 250 batches for 3 models loss")
plt.xlabel("Trained batches")
plt.ylabel("loss - BCEWithLogitsLoss")
plt.legend(["Base", "Frozen", "Unfrozen"])
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

list_total = []
for j in range(1):
    x = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_base/epoch_"+str(j)+"training_loss.csv", delimiter=',')
    y = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_frozen/epoch_"+str(j)+"training_loss.csv", delimiter=',')
    z = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen/epoch_"+str(j)+"training_loss.csv", delimiter=',')
    
    list_total = np.concatenate((list_total,x))

plt.plot(range(len(list_total)),list_total)
plt.title("First epoch of mean training BCE with Logits Loss per batch of the Baseline model")
plt.xlabel("Trained batches")
plt.ylabel("mean batch loss - BCEWithLogitsLoss")
#plt.ylim([-0.001, 0.035])
plt.show()
print("mean of the last 50 values: ", np.nanmean(x[:-50]))

x_array,y_array,z_array = np.array([]),np.array([]),np.array([])
for j in range(3):
    x = np.nanmean(np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_base/epoch_"+str(j)+"validation_loss.csv", delimiter=','))
    x_array = np.append(x_array, x)
    y = np.nanmean(np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_frozen/epoch_"+str(j)+"validation_loss.csv", delimiter=','))
    y_array = np.append(y_array, y)
    z = np.nanmean(np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen/epoch_"+str(j)+"validation_loss.csv", delimiter=','))
    z_array = np.append(z_array, z)
    
    
print(empty_array)
plt.plot(range(len(x_array)),x_array)
plt.title("Validation loss")
#plt.ylim([-0.001, 0.035])
#plt.show()
print("mean validation: ", np.nanmean(x))

plt.plot(range(len(y_array)),y_array)
#plt.ylim([-0.001, 0.035])
#plt.show()
print("mean validation: ", np.nanmean(y))

plt.plot(range(len(z_array)),z_array)
plt.xlabel("Epoch")
plt.ylabel("Mean validation loss")
#plt.ylim([-0.001, 0.035])
plt.legend(["Baseline","Frozen","Un-Frozen"])
plt.show()
print("mean validation: ", np.nanmean(z))
    
x0 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_base/epoch_0training_dice.csv", delimiter=',')
y0 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_frozen/epoch_0training_dice.csv", delimiter=',')
z0 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen/epoch_0training_dice.csv", delimiter=',')
    
print("One Epoch equals" , len(x0)/(50*16))

mean_output_x,mean_output_y,mean_output_z = [],[],[]
each_number_x,each_number_y,each_number_z = [],[],[]

for i in range(len(x0)):
    each_number_x.append(x0[i])
    each_number_y.append(y0[i])
    each_number_z.append(z0[i])
    if len(each_number_x) == (50*16):
        mean_output_x.append(np.mean(each_number_x))
        mean_output_y.append(np.mean(each_number_y))
        mean_output_z.append(np.mean(each_number_z))
        each_number_x,each_number_y,each_number_z = [],[],[]
    if i == len(x0):
        mean_output_x.append(np.mean(each_number_x))
        mean_output_y.append(np.mean(each_number_y))
        mean_output_z.append(np.mean(each_number_z))

print("Base")
print(list(np.around(np.array(mean_output_x[:20]),3)))

length = np.linspace(50, 1900, num=38)        
print(length)
plt.plot(length,mean_output_x)
plt.plot(length,mean_output_y)
plt.plot(length,mean_output_z)
plt.title("Mean training dice score over 50 batches")
plt.ylim([0.5, 1])
plt.xlabel("Trained batches")
plt.ylabel("Mean Dice similarity score")
plt.legend(["Baseline","Frozen","Un-Frozen"])
plt.show()

x0 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_base/epoch_0validation_dice.csv", delimiter=',')
x0.tolist().append(np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_base/epoch_1validation_dice.csv", delimiter=',').tolist())
x0.tolist().append(np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_base/epoch_2validation_dice.csv", delimiter=',').tolist())

y0 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_frozen/epoch_0validation_dice.csv", delimiter=',')
y0.tolist().append(np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_frozen/epoch_1validation_dice.csv", delimiter=',').tolist())
y0.tolist().append(np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_frozen/epoch_2validation_dice.csv", delimiter=',').tolist())

z0 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen/epoch_0validation_dice.csv", delimiter=',')
z0.tolist().append(np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen/epoch_1validation_dice.csv", delimiter=',').tolist())
z0.tolist().append(np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen/epoch_2validation_dice.csv", delimiter=',').tolist())

# plt.plot(range(len(z0)),z0)
# plt.show()
# print("One Epoch equals" , len(x0)/(50*16))

mean_output_x,mean_output_y,mean_output_z = [],[],[]
each_number_x,each_number_y,each_number_z = [],[],[]

for i in range(len(x0)):
    each_number_x.append(x0[i])
    each_number_y.append(y0[i])
    each_number_z.append(z0[i])
    if len(each_number_x) == (50*4):
        mean_output_x.append(np.mean(each_number_x))
        mean_output_y.append(np.mean(each_number_y))
        mean_output_z.append(np.mean(each_number_z))
        each_number_x,each_number_y,each_number_z = [],[],[]
    if i == len(x0):
        mean_output_x.append(np.mean(each_number_x))
        mean_output_y.append(np.mean(each_number_y))
        mean_output_z.append(np.mean(each_number_z))

print("Base")
print(list(np.around(np.array(mean_output_x[:20]),3)))

length = np.linspace(50, 1900, num=38)        
print(length)
plt.plot(range(len(mean_output_x)),mean_output_x)
plt.plot(range(len(mean_output_y)),mean_output_y)
plt.plot(range(len(mean_output_z)),mean_output_z)
plt.title("First epoch of mean training dice score over 50 batches")
plt.xlabel("Trained batches")
plt.ylabel("Mean Dice similarity score")
plt.legend(["Baseline","Frozen","Un-Frozen"])
plt.show()
# Out:
# mean of the last 50 values:  0.00019651072029240144
# [0.00064506 0.00054517 0.00054556]
# mean validation:  0.0005455579142135135
# mean validation:  0.0006307795239256367
# mean validation:  0.0005057769668100795
# One Epoch equals 38.75
# Base
# [0.583, 0.554, 0.558, 0.663, 0.752, 0.745, 0.746, 0.762, 0.75, 0.789, 0.777, 0.8, 0.773, 0.781, 0.804, 0.788, 0.806, 0.796, 0.81, 0.839]
# [  50.  100.  150.  200.  250.  300.  350.  400.  450.  500.  550.  600.
#   650.  700.  750.  800.  850.  900.  950. 1000. 1050. 1100. 1150. 1200.
#  1250. 1300. 1350. 1400. 1450. 1500. 1550. 1600. 1650. 1700. 1750. 1800.
#  1850. 1900.]
# Base
# [0.889, 0.83, 0.835, 0.852, 0.876, 0.85, 0.764, 0.88, 0.82, 0.842, 0.843, 0.906, 0.91, 0.827, 0.859, 0.947, 0.83, 0.807, 0.865, 0.845]
# [  50.  100.  150.  200.  250.  300.  350.  400.  450.  500.  550.  600.
#   650.  700.  750.  800.  850.  900.  950. 1000. 1050. 1100. 1150. 1200.
#  1250. 1300. 1350. 1400. 1450. 1500. 1550. 1600. 1650. 1700. 1750. 1800.
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

x = np.genfromtxt("Checkpoints/Full_model_MK4_H16_O4A4_base/epoch_0training_loss.csv", delimiter=',')
plt.plot(range(len(x) ),x)
#plt.plot(range(550),x[:250])
x = np.genfromtxt("Checkpoints/Full_model_MK4_H16_O4A4_frozen/epoch_0training_loss.csv", delimiter=',')
plt.plot(range(len(x) ),x)
#plt.plot(range(550),x[:250])
x = np.genfromtxt("Checkpoints/Full_model_MK4_H16_O4A4_unfrozen/epoch_0training_loss.csv", delimiter=',')
plt.plot(range(len(x) ),x)
#plt.plot(range(550),x[:250])
plt.title("first epoch of batches for 3 models loss")
plt.xlabel("Trained batches")
plt.ylabel("loss - BCEWithLogitsLoss")
plt.legend(["Base", "Frozen", "Unfrozen"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-60-735abd28cb10> in <module>
#       5 sns.set_theme()
#       6
# ----> 7 x = np.genfromtxt("Checkpoints/Full_model_MK4_H16_O4A4_base/epoch_0training_loss.csv", delimiter=',')
#       8 plt.plot(range(len(x) ),x)
#       9 #plt.plot(range(550),x[:250])
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding)
#    1747             fname = os_fspath(fname)
#    1748         if isinstance(fname, str):
# -> 1749             fid = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1750             fid_ctx = contextlib.closing(fid)
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

x = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_base/epoch_0training_loss.csv", delimiter=',')
#plt.plot(range(len(x) ),x)
plt.plot(range(250),x[:250])
plt.show()

Train0 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_base/epoch_0validation_dice.csv",delimiter=',')
print("Mean validation Dice for epoch 0:", np.mean(Train0))
Train0[Train0 == 1.0] = 'nan'

Train1 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_base/epoch_1validation_dice.csv",delimiter=',')
print("Mean validation Dice for epoch 1:", np.mean(Train1))
Train1[Train1 == 1.0] = 'nan'

Train2 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_base/epoch_2validation_dice.csv",delimiter=',')
print("Mean validation Dice for epoch 2:", np.mean(Train2))
Train2[Train2 == 1.0] = 'nan'

train0 = pd.DataFrame(data=Train0, columns=range(1)).assign(Data="Epoch 0")
train1 = pd.DataFrame(data=Train1, columns=range(1)).assign(Data="Epoch 1")
train2 = pd.DataFrame(data=Train2, columns=range(1)).assign(Data="Epoch 2")

train_data = pd.concat([train0,train1,train2])

train_data_2 = pd.melt(train_data, id_vars=['Data'])
ax = sns.boxplot(x="Data", y="value", data=train_data_2)
plt.title("Box plot for validation dice scores, Base model")
plt.ylabel("Mean dice score")
plt.xlabel("")
plt.show()
ax = sns.violinplot(x="Data", y="value", data=train_data_2)
plt.title("Violin plot for validation dice scores, Base model")
plt.ylabel("Mean dice score")
plt.xlabel("")
plt.show()
# Out:
# Mean validation Dice for epoch 0: 0.856321489562165
# Mean validation Dice for epoch 1: 0.867222730439563
# Mean validation Dice for epoch 2: 0.8786389037066271

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

x = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen/epoch_0training_loss.csv", delimiter=',')
#plt.plot(range(len(x) ),x)
plt.plot(range(250),x[:250])
plt.show()

Train0 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen/epoch_0validation_dice.csv",delimiter=',')
print("Mean validation Dice for epoch 0:", np.mean(Train0))
Train0[Train0 == 1.0] = 'nan'

Train1 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen/epoch_1validation_dice.csv",delimiter=',')
print("Mean validation Dice for epoch 0:", np.mean(Train1))
Train1[Train1 == 1.0] = 'nan'

Train2 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen/epoch_2validation_dice.csv",delimiter=',')
print("Mean validation Dice for epoch 0:", np.mean(Train2))
Train2[Train2 == 1.0] = 'nan'

train0 = pd.DataFrame(data=Train0, columns=range(1)).assign(Data="Epoch 0")
train1 = pd.DataFrame(data=Train1, columns=range(1)).assign(Data="Epoch 1")
train2 = pd.DataFrame(data=Train2, columns=range(1)).assign(Data="Epoch 2")

train_data = pd.concat([train0,train1,train2])

train_data_2 = pd.melt(train_data, id_vars=['Data'])
ax = sns.boxplot(x="Data", y="value", data=train_data_2)
plt.title("Box plot for validation dice scores, Unfrozen model")
plt.ylabel("Mean dice score")
plt.xlabel("")
plt.show()
ax = sns.violinplot(x="Data", y="value", data=train_data_2)
plt.title("Violin plot for validation dice scores, Unfrozen model")
plt.ylabel("Mean dice score")
plt.xlabel("")
plt.show()
# Out:
# Mean validation Dice for epoch 0: 0.862016646868284
# Mean validation Dice for epoch 0: 0.8690790221543272
# Mean validation Dice for epoch 0: 0.8788521921089525

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

x0 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_base/epoch_0training_dice.csv", delimiter=',')
x1 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_base/epoch_1training_dice.csv", delimiter=',')
x2 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_base/epoch_2training_dice.csv", delimiter=',')

#x = x0
x = np.concatenate((x0,x1,x2))

print("One Epoch equals" , len(x0)/(50*16))

mean_output = []
each_number = []
for i in range(len(x)):
    each_number.append(x[i])
    if len(each_number) == (50*16):
        mean_output.append(np.mean(each_number))
        each_number = []
    if i == len(x):
        mean_output.append(np.mean(each_number))
        
print("Base")
print(list(np.around(np.array(mean_output[:20]),3)))
        
plt.plot(range(len(mean_output)),mean_output )

x0 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_frozen/epoch_0training_dice.csv", delimiter=',')
x1 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_frozen/epoch_1training_dice.csv", delimiter=',')
x2 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_frozen/epoch_2training_dice.csv", delimiter=',')

#x = x0
x = np.concatenate((x0,x1,x2))

mean_output = []
each_number = []
for i in range(len(x)):
    each_number.append(x[i])
    if len(each_number) == (50*16):
        mean_output.append(np.mean(each_number))
        each_number = []
    if i == len(x):
        mean_output.append(np.mean(each_number))
        
print("Unfrozen")
print(list(np.around(np.array(mean_output[:20]),3)))

plt.plot(range(len(mean_output)),mean_output )

x0 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen/epoch_0training_dice.csv", delimiter=',')
x1 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen/epoch_1training_dice.csv", delimiter=',')
x2 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen/epoch_2training_dice.csv", delimiter=',')

x = np.concatenate((x0,x1,x2))

mean_output = []
each_number = []
for i in range(len(x)):
    each_number.append(x[i])
    if len(each_number) == (50*16):
        mean_output.append(np.mean(each_number))
        each_number = []
    if i == len(x):
        mean_output.append(np.mean(each_number))
        
print("Unfrozen")
print(list(np.around(np.array(mean_output[:20]),3)))

plt.plot(range(len(mean_output)),mean_output )

x0 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen_alldata/epoch_0training_dice.csv", delimiter=',')
x1 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen_alldata/epoch_1training_dice.csv", delimiter=',')
#x2 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen_alldata/epoch_2training_dice.csv", delimiter=',')

x = np.concatenate((x0,x1))

mean_output = []
each_number = []
for i in range(len(x)):
    each_number.append(x[i])
    if len(each_number) == (50*16):
        mean_output.append(np.mean(each_number))
        each_number = []
    if i == len(x):
        mean_output.append(np.mean(each_number))
        
print("Unfrozen")
print(list(np.around(np.array(mean_output[:20]),3)))

plt.plot(range(len(mean_output)),mean_output )
plt.title("Mean Training dice score for every 50 batches over 3 epochs")
plt.xlabel("Values per 50 batches (800 volumes)")
plt.ylabel("Mean Dice Similarity Score")
plt.legend(["Base", "Frozen", "Unfrozen","Unfr_alldata"])

plt.show()
        
########################################################################################################################    

x0 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_base/epoch_0training_loss.csv", delimiter=',')
x1 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_base/epoch_1training_loss.csv", delimiter=',')
x2 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_base/epoch_2training_loss.csv", delimiter=',')

#x = x0
x = np.concatenate((x0,x1,x2))

mean_output = []
each_number = []
for i in range(len(x)):
    each_number.append(x[i])
    if len(each_number) == 50:
        mean_output.append(np.mean(each_number))
        each_number = []
    if i == len(x):
        mean_output.append(np.mean(each_number))
        
plt.plot(range(len(mean_output[0:20])),mean_output[0:20] )

x0 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_frozen/epoch_0training_loss.csv", delimiter=',')
x1 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_frozen/epoch_1training_loss.csv", delimiter=',')
x2 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_frozen/epoch_2training_loss.csv", delimiter=',')

#x = x0
x = np.concatenate((x0,x1,x2))

mean_output = []
each_number = []
for i in range(len(x)):
    each_number.append(x[i])
    if len(each_number) == 50:
        mean_output.append(np.mean(each_number))
        each_number = []
    if i == len(x):
        mean_output.append(np.mean(each_number))
        
plt.plot(range(len(mean_output[0:20])),mean_output[0:20] )

x0 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen/epoch_0training_loss.csv", delimiter=',')
x1 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen/epoch_1training_loss.csv", delimiter=',')
x2 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen/epoch_2training_loss.csv", delimiter=',')

#x = x0
x = np.concatenate((x0,x1,x2))

mean_output = []
each_number = []
for i in range(len(x)):
    each_number.append(x[i])
    if len(each_number) == 50:
        mean_output.append(np.mean(each_number))
        each_number = []
    if i == len(x):
        mean_output.append(np.mean(each_number))
        
plt.plot(range(len(mean_output[0:20])),mean_output[0:20] )

x0 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen_alldata/epoch_0training_loss.csv", delimiter=',')
x1 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen_alldata/epoch_1training_loss.csv", delimiter=',')
#x2 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen_alldata/epoch_2training_loss.csv", delimiter=',')

#x = x0
x = np.concatenate((x0,x1))

mean_output = []
each_number = []
for i in range(len(x)):
    each_number.append(x[i])
    if len(each_number) == 50:
        mean_output.append(np.mean(each_number))
        each_number = []
    if i == len(x):
        mean_output.append(np.mean(each_number))
        
plt.plot(range(len(mean_output[0:20])),mean_output[0:20] )
plt.title("Mean Training Loss for every 50 batches over 3 epochs using all slices")
plt.xlabel("Values per 50 batches (800 volumes)")
plt.ylabel("Mean loss - BCEWithLogitsLoss")
plt.legend(["Base", "Frozen", "Unfrozen", "unfr_alldata"])
plt.show()
# Out:
# One Epoch equals 38.75
# Base
# [0.583, 0.554, 0.558, 0.663, 0.752, 0.745, 0.746, 0.762, 0.75, 0.789, 0.777, 0.8, 0.773, 0.781, 0.804, 0.788, 0.806, 0.796, 0.81, 0.839]
# Unfrozen
# [0.582, 0.526, 0.669, 0.838, 0.839, 0.818, 0.84, 0.845, 0.849, 0.827, 0.848, 0.853, 0.842, 0.838, 0.835, 0.84, 0.836, 0.833, 0.848, 0.862]
# Unfrozen
# [0.575, 0.609, 0.796, 0.805, 0.819, 0.839, 0.814, 0.83, 0.845, 0.84, 0.876, 0.837, 0.852, 0.859, 0.87, 0.86, 0.847, 0.852, 0.846, 0.846]
# Unfrozen
# [0.594, 0.566, 0.653, 0.799, 0.805, 0.81, 0.824, 0.82, 0.829, 0.859, 0.844, 0.849, 0.84, 0.866, 0.856, 0.836, 0.86, 0.847, 0.859, 0.863]

# %%
########################################################################################################################    

x0 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_base/epoch_0training_loss.csv", delimiter=',')
x1 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_base/epoch_1training_loss.csv", delimiter=',')
x2 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_base/epoch_2training_loss.csv", delimiter=',')

x = np.concatenate((x0,x1,x2))
plt.plot(range(len(x[0:150])),x[0:150] )

x0 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_frozen/epoch_0training_loss.csv", delimiter=',')
x1 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_frozen/epoch_1training_loss.csv", delimiter=',')
x2 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_frozen/epoch_2training_loss.csv", delimiter=',')

x = np.concatenate((x0,x1,x2))

plt.plot(range(len(x[0:150])),x[0:150] )

x0 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen/epoch_0training_loss.csv", delimiter=',')
x1 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen/epoch_1training_loss.csv", delimiter=',')
x2 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen/epoch_2training_loss.csv", delimiter=',')

x = np.concatenate((x0,x1,x2))
        
plt.plot(range(len(x[0:150])),x[0:150] )

# x0 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen_alldata/epoch_0training_loss.csv", delimiter=',')
# x1 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen_alldata/epoch_1training_loss.csv", delimiter=',')
# #x2 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen_alldata/epoch_2training_loss.csv", delimiter=',')

# x = np.concatenate((x0,x1))
        
# plt.plot(range(len(x[0:150])),x[0:150] )
plt.title("Mean Training Loss for the first 150 batches of 3 models")
plt.xlabel("Mean values per batch")
plt.ylabel("Mean loss - BCEWithLogitsLoss")
plt.legend(["RI", "PTFE", "PTTE"])
plt.show()

# %%
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
# sns.set_theme()

# Slice = "_300"
# #Slice = "_0_600"

# #validation_dice_base = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_base_step" + Slice + "/0_Tumour_slice_validation_dice.csv",delimiter=',')
# validation_dice_base = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen_alldata/epoch_0validation_dice.csv",delimiter=',')
# print("Total Mean validation Dice - Base Model:", np.mean(validation_dice_base))
# print("Total Mean standard deviation Dice - Base Model:", np.std(validation_dice_base))
# base_dice = pd.DataFrame(data=validation_dice_base, columns=range(1)).assign(Data="Base Dice")

# #validation_dice_unfr = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_unfrozen_step" + Slice + "/0_Tumour_slice_validation_dice.csv",delimiter=',')
# validation_dice_unfr = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen/epoch_0validation_dice.csv",delimiter=',')
# print("Total Mean validation Dice - Unfrozen Model:", np.mean(validation_dice_unfr))
# print("Total standard deviation validation Dice - Unfrozen Model:", np.std(validation_dice_unfr))
# unfr_dice = pd.DataFrame(data=validation_dice_unfr, columns=range(1)).assign(Data="Unfr Dice")

# base_dice_frame = pd.DataFrame(data=base_dice, columns=range(1)).assign(Data="Base Model")
# unfr_dice_frame = pd.DataFrame(data=unfr_dice, columns=range(1)).assign(Data="Unfrozen Model")

# total_dice = pd.concat([base_dice_frame,unfr_dice_frame])

# dice_output = pd.melt(total_dice, id_vars=['Data'])
# ax = sns.boxplot(x="Data", y="value", data=dice_output)
# plt.title("Box plot for validation dice scores, between Base and unfrozen models")
# plt.ylabel("Mean dice score")
# plt.xlabel("")
# plt.show()
# ax = sns.violinplot(x="Data", y="value", data=dice_output)
# plt.title("Violin plot for validation dice scores, between Base and unfrozen models")
# plt.ylabel("Mean dice score")
# plt.xlabel("")
# plt.show()

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

x = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen_alldata/epoch_0training_loss.csv", delimiter=',')
#plt.plot(range(len(x) ),x)
plt.plot(range(250),x[:250])
plt.show()

Train0 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen_alldata/epoch_0validation_dice.csv",delimiter=',')
print("Mean validation Dice for epoch 0:", np.mean(Train0))
Train0[Train0 == 1.0] = 'nan'

Train1 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen_alldata/epoch_1validation_dice.csv",delimiter=',')
print("Mean validation Dice for epoch 1:", np.mean(Train1))
Train1[Train1 == 1.0] = 'nan'

Train2 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen_alldata/epoch_2validation_dice.csv",delimiter=',')
print("Mean validation Dice for epoch 2:", np.mean(Train2))
Train2[Train2 == 1.0] = 'nan'

train0 = pd.DataFrame(data=Train0, columns=range(1)).assign(Data="Epoch 0")
train1 = pd.DataFrame(data=Train1, columns=range(1)).assign(Data="Epoch 1")
train2 = pd.DataFrame(data=Train2, columns=range(1)).assign(Data="Epoch 2")

train_data = pd.concat([train0,train1,train2])
#train_data = pd.concat([train0,train1])

train_data_2 = pd.melt(train_data, id_vars=['Data'])
ax = sns.boxplot(x="Data", y="value", data=train_data_2)
plt.title("Box plot for validation dice scores, Unfrozen model")
plt.ylabel("Mean dice score")
plt.xlabel("")
plt.show()
ax = sns.violinplot(x="Data", y="value", data=train_data_2)
plt.title("Violin plot for validation dice scores, Unfrozen model")
plt.ylabel("Mean dice score")
plt.xlabel("")
plt.show()
# Out:
# Mean validation Dice for epoch 0: 0.886323299755284
# Mean validation Dice for epoch 0: 0.8856524486767349
# Mean validation Dice for epoch 0: 0.8885679979312273

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

Slice = "_300"
#Slice = "_0_600"

#validation_dice_base = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_base_step" + Slice + "/0_Tumour_slice_validation_dice.csv",delimiter=',')
validation_dice_base = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_base_Epoch_2_validation/0_All_slice_validation_dice.csv",delimiter=',')
print("Total Mean validation Dice - Base Model:", np.mean(validation_dice_base))
print("Total Mean standard deviation Dice - Base Model:", np.std(validation_dice_base))
base_dice = pd.DataFrame(data=validation_dice_base, columns=range(1)).assign(Data="Base Dice")

#validation_dice_unfr = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_unfrozen_step" + Slice + "/0_Tumour_slice_validation_dice.csv",delimiter=',')
validation_dice_unfr = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_unfrozen_Epoch_2_validation/0_All_slice_validation_dice.csv",delimiter=',')
print("Total Mean validation Dice - Unfrozen Model:", np.mean(validation_dice_unfr))
print("Total standard deviation validation Dice - Unfrozen Model:", np.std(validation_dice_unfr))
unfr_dice = pd.DataFrame(data=validation_dice_unfr, columns=range(1)).assign(Data="Unfr Dice")

base_dice_frame = pd.DataFrame(data=base_dice, columns=range(1)).assign(Data="Base Model")
unfr_dice_frame = pd.DataFrame(data=unfr_dice, columns=range(1)).assign(Data="Unfrozen Model")

total_dice = pd.concat([base_dice_frame,unfr_dice_frame])

dice_output = pd.melt(total_dice, id_vars=['Data'])
ax = sns.boxplot(x="Data", y="value", data=dice_output)
plt.title("Box plot for validation dice scores, between Base and unfrozen models")
plt.ylabel("Mean dice score")
plt.xlabel("")
plt.show()
ax = sns.violinplot(x="Data", y="value", data=dice_output)
plt.title("Violin plot for validation dice scores, between Base and unfrozen models")
plt.ylabel("Mean dice score")
plt.xlabel("")
plt.show()
# Out:
# Total Mean validation Dice - Base Model: 0.8757977334990604
# Total Mean standard deviation Dice - Base Model: 0.056051369805018174
# Total Mean validation Dice - Unfrozen Model: 0.8833899280029064
# Total standard deviation validation Dice - Unfrozen Model: 0.04674216714660895

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

mean_val_base = []
mean_val_frozen = []
mean_val_unfrozen = []

for i in range(38):

        validation_dice_base = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_base_step_0_" + str((i+1)*50) + "/0_All_slice_validation_dice.csv",delimiter=',')
        mean_val_base.append(np.mean(validation_dice_base))

        validation_dice_frozen = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_frozen_step_0_" + str((i+1)*50) + "/0_All_slice_validation_dice.csv",delimiter=',')
        mean_val_frozen.append(np.mean(validation_dice_frozen))

        validation_dice_unfrozen = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_unfrozen_step_0_" + str((i+1)*50) + "/0_All_slice_validation_dice.csv",delimiter=',')
        mean_val_unfrozen.append(np.mean(validation_dice_unfrozen))

x = np.linspace(50, 1900, num=38)
x = x.tolist()

# for j in range(3):
#     for i in range(38):

#         validation_dice_base = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_base_step_" + str(j) + "_" + str((i+1)*50) + "/0_All_slice_validation_dice.csv",delimiter=',')
#         mean_val_base.append(np.mean(validation_dice_base))

#         validation_dice_frozen = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_frozen_step_" + str(j) + "_" + str((i+1)*50) + "/0_All_slice_validation_dice.csv",delimiter=',')
#         mean_val_frozen.append(np.mean(validation_dice_frozen))

#         validation_dice_unfrozen = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_unfrozen_step_" + str(j) + "_" + str((i+1)*50) + "/0_All_slice_validation_dice.csv",delimiter=',')
#         mean_val_unfrozen.append(np.mean(validation_dice_unfrozen))


# x = np.linspace(50, 5700, num=114)
# x = x.tolist()



plt.title("Mean validation score for each 50 batches")
plt.plot(x,mean_val_base)
plt.plot(x,mean_val_frozen)
plt.plot(x,mean_val_unfrozen)
plt.ylim([0.5, 1])

plt.xlabel("Trained batches")
plt.ylabel("Dice score")

plt.legend(["Baseline","Frozen","Un-Frozen"],loc='lower right')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

mean_val_base = []
mean_val_frozen = []
mean_val_unfrozen = []

for i in range(38):

    validation_dice_base = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_base_step_0_" + str((i+1)*50) + "/0_Tumour_slice_validation_dice.csv",delimiter=',')
    mean_val_base.append(np.mean(validation_dice_base))

    validation_dice_frozen = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_frozen_step_0_" + str((i+1)*50) + "/0_Tumour_slice_validation_dice.csv",delimiter=',')
    mean_val_frozen.append(np.mean(validation_dice_frozen))

    validation_dice_unfrozen = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_unfrozen_step_0_" + str((i+1)*50) + "/0_Tumour_slice_validation_dice.csv",delimiter=',')
    mean_val_unfrozen.append(np.mean(validation_dice_unfrozen))

x = np.linspace(50, 1900, num=38)
x = x.tolist()

# for j in range(3):
#     for i in range(38):

#         validation_dice_base = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_base_step_" + str(j) + "_" + str((i+1)*50) + "/0_Tumour_slice_validation_dice.csv",delimiter=',')
#         mean_val_base.append(np.mean(validation_dice_base))

#         validation_dice_frozen = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_frozen_step_" + str(j) + "_" + str((i+1)*50) + "/0_Tumour_slice_validation_dice.csv",delimiter=',')
#         mean_val_frozen.append(np.mean(validation_dice_frozen))

#         validation_dice_unfrozen = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_unfrozen_step_" + str(j) + "_" + str((i+1)*50) + "/0_Tumour_slice_validation_dice.csv",delimiter=',')
#         mean_val_unfrozen.append(np.mean(validation_dice_unfrozen))

# x = np.linspace(50, 5700, num=114)
# x = x.tolist()

#s = np.linspace(50,5850, num = 117)    

plt.title("mean validation score for each 50 batches - Tumour dice only")
plt.plot(x,mean_val_base)
plt.plot(x,mean_val_frozen)
plt.plot(x,mean_val_unfrozen)

plt.xlabel("Batches")
plt.ylabel("Dice score")

plt.legend(["base","frozen","unfrozen"])
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

mean_val_base = []
mean_val_frozen = []
mean_val_unfrozen = []

for i in range(38):

    validation_dice_base = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_base_step_0_" + str((i+1)*50) + "/0_None_slice_validation_dice.csv",delimiter=',')
    mean_val_base.append(np.mean(validation_dice_base))

    validation_dice_frozen = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_frozen_step_0_" + str((i+1)*50) + "/0_None_slice_validation_dice.csv",delimiter=',')
    mean_val_frozen.append(np.mean(validation_dice_frozen))

    validation_dice_unfrozen = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_unfrozen_step_0_" + str((i+1)*50) + "/0_None_slice_validation_dice.csv",delimiter=',')
    mean_val_unfrozen.append(np.mean(validation_dice_unfrozen))

x = np.linspace(50, 1900, num=38)
x = x.tolist()

# for j in range(3):
#     for i in range(38):

#         validation_dice_base = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_base_step_" + str(j) + "_" + str((i+1)*50) + "/0_None_slice_validation_dice.csv",delimiter=',')
#         mean_val_base.append(np.mean(validation_dice_base))

#         validation_dice_frozen = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_frozen_step_" + str(j) + "_" + str((i+1)*50) + "/0_None_slice_validation_dice.csv",delimiter=',')
#         mean_val_frozen.append(np.mean(validation_dice_frozen))

#         validation_dice_unfrozen = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_unfrozen_step_" + str(j) + "_" + str((i+1)*50) + "/0_None_slice_validation_dice.csv",delimiter=',')
#         mean_val_unfrozen.append(np.mean(validation_dice_unfrozen))


# x = np.linspace(50, 5700, num=114)
# x = x.tolist()

#s = np.linspace(50,5850, num = 117)    

plt.title("mean validation score for each 50 batches - No Tumour dice only")
plt.plot(x,mean_val_base)
plt.plot(x,mean_val_frozen)
plt.plot(x,mean_val_unfrozen)

plt.xlabel("Batches")
plt.ylabel("Dice score")

plt.legend(["base","frozen","unfrozen"])
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

x = np.linspace(50, 550, num=11)
x = x.tolist()

empty_data = []
base_dice_frame_total = pd.DataFrame(data=empty_data, columns=range(1)).assign(Data="Base Model")
fr_dice_frame_total = pd.DataFrame(data=empty_data, columns=range(1)).assign(Data="Frozen Model")
unfr_dice_frame_total = pd.DataFrame(data=empty_data, columns=range(1)).assign(Data="Unfrozen Model")

fr_mean = []
unfr_mean = []
base_mean = []

fr_med = []
unfr_med = []
base_med = []

fr_std = []
unfr_std = []
base_std = []

plt.figure(figsize=(20,5))

for i in range(len(x)):
    f = str(int(x[i])) 
    validation_dice_base = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_base_step_" + f + "/0_Tumour_slice_validation_dice.csv",delimiter=',')
    base_dice = pd.DataFrame(data=validation_dice_base, columns=range(1)).assign(Data="Base Dice")

    base_dice_frame = pd.DataFrame(data=base_dice, columns=range(1)).assign(Data="Step " + str(int(x[i])))

    base_dice_frame_total = pd.concat([base_dice_frame_total,base_dice_frame])

    dice_output = pd.melt(base_dice_frame_total, id_vars=['Data'])
    ax = sns.boxplot(x="Data", y="value", data=dice_output)
    base_mean.append(np.mean(base_dice_frame[0].to_numpy()))
    base_med.append(np.median(base_dice_frame[0].to_numpy()))
    base_std.append(np.std(base_dice_frame[0].to_numpy()))
    
for i in range(3):
    f = str(i) 
    validation_dice_base = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_base_Epoch_"+f+"_validation/0_Tumour_slice_validation_dice.csv",delimiter=',')
    base_dice = pd.DataFrame(data=validation_dice_base, columns=range(1)).assign(Data="Base Dice")

    base_dice_frame = pd.DataFrame(data=base_dice, columns=range(1)).assign(Data="Epoch " + str(i))

    base_dice_frame_total = pd.concat([base_dice_frame_total,base_dice_frame])

    dice_output = pd.melt(base_dice_frame_total, id_vars=['Data'])
    ax = sns.boxplot(x="Data", y="value", data=dice_output)
    base_mean.append(np.mean(base_dice_frame[0].to_numpy()))
    base_med.append(np.median(base_dice_frame[0].to_numpy()))
    base_std.append(np.std(base_dice_frame[0].to_numpy()))
    
plt.ylim([-0.05,1])
plt.title("Box plot for validation dice scores, Baseline model for Tumour slices only")
plt.ylabel("Mean dice score")
plt.xlabel("")

plt.show()

plt.figure(figsize=(20,5))

for i in range(len(x)):
    f = str(int(x[i])) 
    
    validation_dice_fr = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_frozen_step_" + f + "/0_Tumour_slice_validation_dice.csv",delimiter=',')
    fr_dice = pd.DataFrame(data=validation_dice_fr, columns=range(1)).assign(Data="fr Dice")

    fr_dice_frame = pd.DataFrame(data=fr_dice, columns=range(1)).assign(Data="Step " + str(int(x[i])))

    fr_dice_frame_total = pd.concat([fr_dice_frame_total,fr_dice_frame])

    dice_output = pd.melt(fr_dice_frame_total, id_vars=['Data'])
    ax = sns.boxplot(x="Data", y="value", data=dice_output)
    fr_mean.append(np.mean(fr_dice_frame[0].to_numpy()))
    fr_med.append(np.median(fr_dice_frame[0].to_numpy()))
    fr_std.append(np.std(fr_dice_frame[0].to_numpy()))

for i in range(3):
    f = str(i) 

    validation_dice_fr = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_frozen_Epoch_"+ f +"_validation/0_Tumour_slice_validation_dice.csv",delimiter=',')
    fr_dice = pd.DataFrame(data=validation_dice_fr, columns=range(1)).assign(Data="fr Dice")

    fr_dice_frame = pd.DataFrame(data=fr_dice, columns=range(1)).assign(Data="Epoch " + str(i))

    fr_dice_frame_total = pd.concat([fr_dice_frame_total,fr_dice_frame])

    dice_output = pd.melt(fr_dice_frame_total, id_vars=['Data'])
    ax = sns.boxplot(x="Data", y="value", data=dice_output)
    fr_mean.append(np.mean(fr_dice_frame[0].to_numpy()))
    fr_med.append(np.median(fr_dice_frame[0].to_numpy()))
    fr_std.append(np.std(fr_dice_frame[0].to_numpy()))

plt.ylim([-0.05,1])
plt.title("Box plot for validation dice scores, frozen pre-trained model for Tumour slices only")
plt.ylabel("Mean dice score")
plt.xlabel("")
plt.show()

plt.figure(figsize=(20,5))

for i in range(len(x)):
    f = str(int(x[i])) 
    
    validation_dice_unfr = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_unfrozen_step_" + f + "/0_Tumour_slice_validation_dice.csv",delimiter=',')
    unfr_dice = pd.DataFrame(data=validation_dice_unfr, columns=range(1)).assign(Data="Unfr Dice")

    unfr_dice_frame = pd.DataFrame(data=unfr_dice, columns=range(1)).assign(Data="Step " + str(int(x[i])))

    unfr_dice_frame_total = pd.concat([unfr_dice_frame_total,unfr_dice_frame])

    dice_output = pd.melt(unfr_dice_frame_total, id_vars=['Data'])
    ax = sns.boxplot(x="Data", y="value", data=dice_output)
    unfr_mean.append(np.mean(unfr_dice_frame[0].to_numpy()))
    unfr_med.append(np.median(unfr_dice_frame[0].to_numpy()))
    unfr_std.append(np.std(unfr_dice_frame[0].to_numpy()))

for i in range(3):
    f = str(i) 

    validation_dice_unfr = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_unfrozen_Epoch_"+f+"_validation/0_Tumour_slice_validation_dice.csv",delimiter=',')
    unfr_dice = pd.DataFrame(data=validation_dice_unfr, columns=range(1)).assign(Data="Unfr Dice")

    unfr_dice_frame = pd.DataFrame(data=unfr_dice, columns=range(1)).assign(Data="Epoch " + str(i))

    unfr_dice_frame_total = pd.concat([unfr_dice_frame_total,unfr_dice_frame])

    dice_output = pd.melt(unfr_dice_frame_total, id_vars=['Data'])
    ax = sns.boxplot(x="Data", y="value", data=dice_output)
    unfr_mean.append(np.mean(unfr_dice_frame[0].to_numpy()))
    unfr_med.append(np.median(unfr_dice_frame[0].to_numpy()))
    unfr_std.append(np.std(unfr_dice_frame[0].to_numpy()))
    
plt.ylim([-0.05,1])
plt.title("Box plot for validation dice scores, unfrozen pre-trained model for Tumour slices only")
plt.ylabel("Mean dice score")
plt.xlabel("")
plt.show()
# print(base_mean)

# x = [np.asarray(base_mean), np.asarray(fr_mean),np.asarray(unfr_mean)]
# y = [50,100,150,200,250,300,350,400,450,500,550,0,1,2]
# print(x)
# Out:
# [0.0030449241714319156, 0.0030449241714319156, 0.006257918837812767, 0.5426519132078444, 0.6087106060066266, 0.6171289508554157, 0.6619801465706273, 0.6144261672075431, 0.6375695227544206, 0.6525988279561112, 0.6000061028581996, 0.7324095589020203, 0.6999889710905657, 0.7253556285150758]
# [array([0.00304492, 0.00304492, 0.00625792, 0.54265191, 0.60871061,
#        0.61712895, 0.66198015, 0.61442617, 0.63756952, 0.65259883,
#        0.6000061 , 0.73240956, 0.69998897, 0.72535563]), array([0.00304492, 0.0030456 , 0.54281248, 0.68895223, 0.69244431,
#        0.71663716, 0.62919332, 0.66714286, 0.64103763, 0.69957244,
#        0.68626836, 0.72802494, 0.72627839, 0.71486877]), array([0.00304492, 0.44645862, 0.58950246, 0.69667404, 0.65987893,
#        0.68460194, 0.65969541, 0.71904601, 0.7048502 , 0.6754951 ,
#        0.70845162, 0.68560503, 0.73087115, 0.76647378])]

# %%
from tabulate import tabulate
df = pd.DataFrame({'key' : [50,100,150,200,250,300,350,400,450,500,550,"Epoch 0","Epoch 1","Epoch 2"],
                   'Baseline' : base_mean,
                   'Frozen' : fr_mean,
                   'Unfrozen' : unfr_med})

print(tabulate(df,["Step/Epoch","----- base -----","---- frozen ----","--- unfrozen ---"], tablefmt="fancy_grid"))

df = pd.DataFrame({'key' : [50,100,150,200,250,300,350,400,450,500,550,"Epoch 0","Epoch 1","Epoch 2"],
                   'Baseline' : base_med,
                   'Frozen' : fr_med,
                   'Unfrozen' : unfr_med})

print(tabulate(df,["Step/Epoch","----- base -----","---- frozen ----","--- unfrozen ---"], tablefmt="fancy_grid"))
                   
df = pd.DataFrame({'key' : [50,100,150,200,250,300,350,400,450,500,550,"Epoch 0","Epoch 1","Epoch 2"],
                   'Baseline' : base_std,
                   'Frozen' : fr_std,
                   'Unfrozen' : unfr_std})

print(tabulate(df,["Step/Epoch","----- base -----","---- frozen ----","--- unfrozen ---"], tablefmt="fancy_grid"))
# Out:
# ╒════╤══════════════╤════════════════════╤════════════════════╤════════════════════╕
# │    │ Step/Epoch   │   ----- base ----- │   ---- frozen ---- │   --- unfrozen --- │
# ╞════╪══════════════╪════════════════════╪════════════════════╪════════════════════╡
# │  0 │ 50           │         0.00304492 │         0.00304492 │           0        │
# ├────┼──────────────┼────────────────────┼────────────────────┼────────────────────┤
# │  1 │ 100          │         0.00304492 │         0.0030456  │           0.475169 │
# ├────┼──────────────┼────────────────────┼────────────────────┼────────────────────┤
# │  2 │ 150          │         0.00625792 │         0.542812   │           0.618048 │
# ├────┼──────────────┼────────────────────┼────────────────────┼────────────────────┤
# │  3 │ 200          │         0.542652   │         0.688952   │           0.705768 │
# ├────┼──────────────┼────────────────────┼────────────────────┼────────────────────┤
# ...

# %%
from tabulate import tabulate
df = pd.DataFrame({'key' : [50,100,150,200,250,300,350,400,450,500,550,"Epoch 0","Epoch 1","Epoch 2"],
                   'Baseline' : base_mean,
                   'Frozen' : fr_mean,
                   'Unfrozen' : unfr_med})

print(tabulate(df,["Step/Epoch","----- base -----","---- frozen ----","--- unfrozen ---"], tablefmt="fancy_grid"))

df = pd.DataFrame({'key' : [50,100,150,200,250,300,350,400,450,500,550,"Epoch 0","Epoch 1","Epoch 2"],
                   'Baseline' : base_med,
                   'Frozen' : fr_med,
                   'Unfrozen' : unfr_med})

print(tabulate(df,["Step/Epoch","----- base -----","---- frozen ----","--- unfrozen ---"], tablefmt="fancy_grid"))
                   
df = pd.DataFrame({'key' : [50,100,150,200,250,300,350,400,450,500,550,"Epoch 0","Epoch 1","Epoch 2"],
                   'Baseline' : base_std,
                   'Frozen' : fr_std,
                   'Unfrozen' : unfr_std})

print(tabulate(df,["Step/Epoch","----- base -----","---- frozen ----","--- unfrozen ---"], tablefmt="fancy_grid"))
# Out:
# ╒════╤══════════════╤════════════════════╤════════════════════╤════════════════════╕
# │    │ Step/Epoch   │   ----- base ----- │   ---- frozen ---- │   --- unfrozen --- │
# ╞════╪══════════════╪════════════════════╪════════════════════╪════════════════════╡
# │  0 │ 50           │           0.579109 │           0.579109 │           0.562903 │
# ├────┼──────────────┼────────────────────┼────────────────────┼────────────────────┤
# │  1 │ 100          │           0.579109 │           0.578718 │           0.787742 │
# ├────┼──────────────┼────────────────────┼────────────────────┼────────────────────┤
# │  2 │ 150          │           0.575914 │           0.801996 │           0.846774 │
# ├────┼──────────────┼────────────────────┼────────────────────┼────────────────────┤
# │  3 │ 200          │           0.774645 │           0.856004 │           0.87034  │
# ├────┼──────────────┼────────────────────┼────────────────────┼────────────────────┤
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#sns.set_theme()

empty_data = []
base_dice_frame_total = pd.DataFrame(data=empty_data, columns=range(1)).assign(Data="Base Model")
unfr_dice_frame_total = pd.DataFrame(data=empty_data, columns=range(1)).assign(Data="Unfrozen Model")

t_type = "Tumour_slice"
#t_type = "All_slice"

#m_type = "base"
#m_type = "frozen"
m_type = "unfrozen"

# validation_dice_01 = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_unfrozen_step_0/0_"+ t_type +"_validation_dice.csv",delimiter=',')
# unfr_01 = pd.DataFrame(data=validation_dice_01, columns=range(1)).assign(Data="Unfr Dice_1")
# unfr_dice_01 = pd.DataFrame(data=unfr_01, columns=range(1)).assign(Data="Step_0")

validation_dice_02 = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_"+ m_type +"_step_50/0_"+ t_type +"_validation_dice.csv",delimiter=',')
unfr_02 = pd.DataFrame(data=validation_dice_02, columns=range(1)).assign(Data="Unfr Dice_02")
unfr_dice_02 = pd.DataFrame(data=unfr_02, columns=range(1)).assign(Data="Step_050")

validation_dice_03 = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_"+ m_type +"_step_100/0_"+ t_type +"_validation_dice.csv",delimiter=',')
unfr_03 = pd.DataFrame(data=validation_dice_03, columns=range(1)).assign(Data="Unfr Dice_03")
unfr_dice_03 = pd.DataFrame(data=unfr_03, columns=range(1)).assign(Data="Step_100")

validation_dice_1 = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_"+ m_type +"_step_150/0_"+ t_type +"_validation_dice.csv",delimiter=',')
unfr_1 = pd.DataFrame(data=validation_dice_1, columns=range(1)).assign(Data="Unfr Dice_1")
unfr_dice_1 = pd.DataFrame(data=unfr_1, columns=range(1)).assign(Data="Step_150")

validation_dice_2 = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_"+ m_type +"_step_200/0_"+ t_type +"_validation_dice.csv",delimiter=',')
unfr_2 = pd.DataFrame(data=validation_dice_2, columns=range(1)).assign(Data="Unfr Dice_2")
unfr_dice_2 = pd.DataFrame(data=unfr_2, columns=range(1)).assign(Data="Step_200")

validation_dice_3 = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_"+ m_type +"_step_250/0_"+ t_type +"_validation_dice.csv",delimiter=',')
unfr_3 = pd.DataFrame(data=validation_dice_3, columns=range(1)).assign(Data="Unfr Dice_3")
unfr_dice_3 = pd.DataFrame(data=unfr_3, columns=range(1)).assign(Data="Step_250")

validation_dice_4 = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_"+ m_type +"_step_300/0_"+ t_type +"_validation_dice.csv",delimiter=',')
unfr_4 = pd.DataFrame(data=validation_dice_4, columns=range(1)).assign(Data="Unfr Dice_4")
unfr_dice_4 = pd.DataFrame(data=unfr_4, columns=range(1)).assign(Data="Step_300")

validation_dice_5 = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_"+ m_type +"_step_350/0_"+ t_type +"_validation_dice.csv",delimiter=',')
unfr_5 = pd.DataFrame(data=validation_dice_5, columns=range(1)).assign(Data="Unfr Dice_5")
unfr_dice_5 = pd.DataFrame(data=unfr_5, columns=range(1)).assign(Data="Step_350")

validation_dice_6 = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_"+ m_type +"_step_400/0_"+ t_type +"_validation_dice.csv",delimiter=',')
unfr_6 = pd.DataFrame(data=validation_dice_6, columns=range(1)).assign(Data="Unfr Dice_6")
unfr_dice_6 = pd.DataFrame(data=unfr_6, columns=range(1)).assign(Data="Step_400")

validation_dice_7 = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_"+ m_type +"_step_450/0_"+ t_type +"_validation_dice.csv",delimiter=',')
unfr_7 = pd.DataFrame(data=validation_dice_7, columns=range(1)).assign(Data="Unfr Dice_7")
unfr_dice_7 = pd.DataFrame(data=unfr_7, columns=range(1)).assign(Data="Step_450")

validation_dice_8 = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_"+ m_type +"_step_500/0_"+ t_type +"_validation_dice.csv",delimiter=',')
unfr_8 = pd.DataFrame(data=validation_dice_8, columns=range(1)).assign(Data="Unfr Dice_8")
unfr_dice_8 = pd.DataFrame(data=unfr_8, columns=range(1)).assign(Data="Step_500")

validation_dice_9 = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_"+ m_type +"_step_550/0_"+ t_type +"_validation_dice.csv",delimiter=',')
unfr_9 = pd.DataFrame(data=validation_dice_9, columns=range(1)).assign(Data="Unfr Dice_9")
unfr_dice_9 = pd.DataFrame(data=unfr_9, columns=range(1)).assign(Data="Step_550")

validation_dice_10 = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_"+ m_type +"_Epoch_0_validation/0_"+ t_type +"_validation_dice.csv",delimiter=',')
unfr_10 = pd.DataFrame(data=validation_dice_10, columns=range(1)).assign(Data="Unfr Dice_10")
unfr_dice_10 = pd.DataFrame(data=unfr_10, columns=range(1)).assign(Data="epoch_0")

validation_dice_11 = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_"+ m_type +"_Epoch_1_validation/0_"+ t_type +"_validation_dice.csv",delimiter=',')
unfr_11 = pd.DataFrame(data=validation_dice_11, columns=range(1)).assign(Data="Unfr Dice_11")
unfr_dice_11 = pd.DataFrame(data=unfr_11, columns=range(1)).assign(Data="epoch_1")

validation_dice_12 = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_"+ m_type +"_Epoch_2_validation/0_"+ t_type +"_validation_dice.csv",delimiter=',')
unfr_12 = pd.DataFrame(data=validation_dice_12, columns=range(1)).assign(Data="Unfr Dice_12")
unfr_dice_12 = pd.DataFrame(data=unfr_12, columns=range(1)).assign(Data="epoch_2")

if m_type == "unfrozen":
    #unfrozen
    plt.figure(figsize=(5,5))
    dice_output = pd.melt(unfr_dice_02, id_vars=['Data'])
    ax = sns.violinplot(x="Data", y="value", data=dice_output)
    plt.ylim([-0.1,1.1])
    plt.show()
    
    unfr_dice_frame_total = pd.concat([unfr_dice_03,
                                       unfr_dice_1,unfr_dice_2,unfr_dice_3,
                                       unfr_dice_4,unfr_dice_5,unfr_dice_6,
                                       unfr_dice_7,unfr_dice_8,unfr_dice_9,
                                       unfr_dice_10,unfr_dice_11,unfr_dice_12])
elif m_type == "frozen":
    #frozen
    plt.figure(figsize=(10,5))
    unfr_dice_frame_total = pd.concat([unfr_dice_02,unfr_dice_03])
    dice_output = pd.melt(unfr_dice_frame_total, id_vars=['Data'])
    ax = sns.violinplot(x="Data", y="value", data=dice_output)
    plt.ylim([-0.1,1.1])
    plt.show()
    
    unfr_dice_frame_total = pd.concat([unfr_dice_1,unfr_dice_2,unfr_dice_3,
                                       unfr_dice_4,unfr_dice_5,unfr_dice_6,
                                       unfr_dice_7,unfr_dice_8,unfr_dice_9,
                                       unfr_dice_10,unfr_dice_11,unfr_dice_12])

#baseline
elif m_type == "base":
    plt.figure(figsize=(15,5))
    unfr_dice_frame_total = pd.concat([unfr_dice_02,unfr_dice_03, unfr_dice_1])
    dice_output = pd.melt(unfr_dice_frame_total, id_vars=['Data'])
    ax = sns.violinplot(x="Data", y="value", data=dice_output)
    plt.ylim([-0.1,1.1])
    plt.show()

    unfr_dice_frame_total = pd.concat([unfr_dice_2,unfr_dice_3,
                                       unfr_dice_4,unfr_dice_5,unfr_dice_6,
                                       unfr_dice_7,unfr_dice_8,unfr_dice_9,
                                       unfr_dice_10,unfr_dice_11,unfr_dice_12])

plt.figure(figsize=(25,5))
dice_output = pd.melt(unfr_dice_frame_total, id_vars=['Data'])
ax = sns.violinplot(x="Data", y="value", data=dice_output)

plt.show()

unfr_dice_frame_total = pd.concat([unfr_dice_02,unfr_dice_03,
                                   unfr_dice_1,unfr_dice_2,unfr_dice_3,
                                   unfr_dice_4,unfr_dice_5,unfr_dice_6,
                                   unfr_dice_7,unfr_dice_8,unfr_dice_9,
                                   unfr_dice_10,unfr_dice_11,unfr_dice_12])

plt.figure(figsize=(25,5))
dice_output = pd.melt(unfr_dice_frame_total, id_vars=['Data'])
ax = sns.boxplot(x="Data", y="value", data=dice_output)
plt.show()
print(dice_output.groupby(["Data"])["value"].describe())
# Out:
#           count      mean       std       min       25%       50%       75%  \
# Data
# Step_050   28.0  0.003045  0.004423  0.000000  0.000000  0.000000  0.006089
# Step_100   28.0  0.446459  0.156888  0.033038  0.398260  0.475169  0.547570
# Step_150   28.0  0.589502  0.162052  0.116496  0.559617  0.618048  0.684274
# Step_200   28.0  0.696674  0.121148  0.302883  0.662863  0.705768  0.771375
# Step_250   28.0  0.659879  0.161760  0.131580  0.646273  0.680633  0.749360
# Step_300   28.0  0.684602  0.150591  0.270471  0.666013  0.703159  0.770243
# Step_350   28.0  0.659695  0.153761  0.177852  0.619287  0.676565  0.749519
# Step_400   28.0  0.719046  0.117964  0.309475  0.678424  0.725642  0.792210
# Step_450   28.0  0.704850  0.129406  0.241214  0.658474  0.715787  0.772275
# Step_500   28.0  0.675495  0.152056  0.151666  0.640321  0.695930  0.756122
# Step_550   28.0  0.708452  0.143751  0.272246  0.676863  0.727825  0.785276
# ...

# %%
from zipfile import ZipFile
with ZipFile("Brats_2018_data_all.zip", 'r') as zipObj:
   # Extract all the contents of zip file in current directory
   zipObj.extractall()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

mean_val_base = []
mean_val_frozen = []
mean_val_unfrozen = []

for i in range(38):

        validation_dice_base = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_base_step_0_" + str((i+1)*50) + "/0_All_slice_validation_dice.csv",delimiter=',')
        mean_val_base.append(np.mean(validation_dice_base))

        validation_dice_frozen = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_frozen_step_0_" + str((i+1)*50) + "/0_All_slice_validation_dice.csv",delimiter=',')
        mean_val_frozen.append(np.mean(validation_dice_frozen))

        validation_dice_unfrozen = np.genfromtxt("Predictions/MK_5_model_predictions_2/MK_5_unfrozen_step_0_" + str((i+1)*50) + "/0_All_slice_validation_dice.csv",delimiter=',')
        mean_val_unfrozen.append(np.mean(validation_dice_unfrozen))

x = np.linspace(50, 1900, num=38)
x = x.tolist()

plt.title("Mean validation score for each 50 batches")
plt.plot(x,mean_val_base)
plt.plot(x,mean_val_frozen)
plt.plot(x,mean_val_unfrozen)

plt.xlabel("Trained batches")
plt.ylabel("Dice score")

plt.legend(["Baseline","Frozen","Un-Frozen"])
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

list_total = []
for j in range(1):
    #x = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_base/epoch_"+str(j)+"training_loss.csv", delimiter=',')
    y = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O10A0_unfrozen_alldata/epoch_"+str(j)+"training_loss.csv", delimiter=',')
    z = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen_alldata/epoch_"+str(j)+"training_loss.csv", delimiter=',')
    
    #list_total = np.concatenate((list_total,x))

# plt.plot(range(len(list_total)),list_total)
# plt.title("First epoch of mean training BCE with Logits Loss per batch of the Baseline model")
# plt.xlabel("Trained batches")
# plt.ylabel("mean batch loss - BCEWithLogitsLoss")
# plt.show()

#plt.plot(range(len(x)),x)
plt.plot(range(len(y)),y)
plt.plot(range(len(z)),z)
plt.title("First epoch of mean training BCE with Logits Loss per batch")
plt.xlabel("Trained batches")
plt.ylabel("Mean batch loss - BCEWithLogitsLoss")
plt.legend(["Baseline","Frozen","Un-Frozen"])
plt.show()
    
#x0 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_base/epoch_0training_dice.csv", delimiter=',')
y0 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O10A0_unfrozen_alldata/epoch_0training_dice.csv", delimiter=',')
z0 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen_alldata/epoch_0training_dice.csv", delimiter=',')
    
print("One Epoch equals" , len(z0)/(50*16))

mean_output_x,mean_output_y,mean_output_z = [],[],[]
each_number_x,each_number_y,each_number_z = [],[],[]

for i in range(len(z0)):
    #each_number_x.append(x0[i])
    each_number_y.append(y0[i])
    each_number_z.append(z0[i])
    if len(each_number_z) == (50*16):
        #mean_output_x.append(np.mean(each_number_x))
        mean_output_y.append(np.mean(each_number_y))
        mean_output_z.append(np.mean(each_number_z))
        each_number_x,each_number_y,each_number_z = [],[],[]
    if i == len(z0):
        #mean_output_x.append(np.mean(each_number_x))
        mean_output_y.append(np.mean(each_number_y))
        mean_output_z.append(np.mean(each_number_z))

print("Base")
print(list(np.around(np.array(mean_output_x[:20]),3)))

length = np.linspace(50, 1900, num=38)        
print(length)
#plt.plot(length,mean_output_x)
plt.plot(range(len(mean_output_y)),mean_output_y)
plt.plot(range(len(mean_output_z)),mean_output_z)
plt.title("First epoch of mean training dice score over 50 batches")
plt.xlabel("Trained batches")
plt.ylabel("Mean Dice similarity score")
plt.legend(["Baseline","Frozen","Un-Frozen"])
plt.show()
# Out:
# One Epoch equals 55.21875
# Base
# []
# [  50.  100.  150.  200.  250.  300.  350.  400.  450.  500.  550.  600.
#   650.  700.  750.  800.  850.  900.  950. 1000. 1050. 1100. 1150. 1200.
#  1250. 1300. 1350. 1400. 1450. 1500. 1550. 1600. 1650. 1700. 1750. 1800.
#  1850. 1900.]

# %%
x0 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O4A4_unfrozen_alldata/epoch_0training_loss.csv", delimiter=',')
plt.plot(range(len(x0[0:150])),x0[0:150] )

x0 = np.genfromtxt("Checkpoints/Full_model_MK5_H16_O10A0_unfrozen_alldata/epoch_0training_loss.csv", delimiter=',')
plt.plot(range(len(x0[0:150])),x0[0:150] )

plt.title("Mean Training Loss for the first 150 batches of 3 models")
plt.xlabel("Mean values per batch")
plt.ylabel("Mean loss - BCEWithLogitsLoss")
plt.legend(["orth 4 area 4", "orth 10 area 0"])
plt.show()
