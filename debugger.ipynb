# %%
# %run "Code_UNet_2/Code_UNet/Train.py"
# Out:
# Torch version:  1.10.1+cu102
#
# Seed                          0
# device                        cuda
# GPU                           1
# Param_location                Code_UNet_2/Code_UNet/Net_modules/Parameters_SEG.py
# Debug                         False
# Net                           UNet
# Cosine_penalty                100
# Epochs                        3
# Batch_size                    16
# Learning_rate                 0.0003
# Weight_decay                  1e-08
# Betas                         (0.9, 0.999)
# Input_dim                     4
# Label_dim                     1
# Hidden_dim                    16
# Train_split                   0.7
# Validation_split              0.1
# Test_split                    0.2
# Custom_split                  0.5
# Batch_display_step            100
# Image_scale                   1
# Image_size                    [240, 240]
# Evaluate                      False
# Regress                       False
# Allow_update                  True
# ...

# %%
# %run "Code_UNet_2/Code_UNet/Train.py"

# %%
# %run "Code_UNet_2/Code_UNet_Re/Test_RANO.py"
x = "0"
# Out:
# <class 'Net_modules.Model_hyperparameters.Parameters'>
# Torch version:  1.10.1+cu102
#
# Seed                          11
# device                        cuda
# GPU                           3
# Param_location                Code_UNet_2/Code_UNet_Re/Net_modules/Model_hyperparameters.py
# Debug                         False
# Net                           UNet
# Enable_Determinism            True
# Cosine_penalty                10
# Epochs                        50
# Batch_size                    8
# Learning_rate                 0.0003
# Weight_decay                  1e-08
# Betas                         (0.9, 0.999)
# Input_dim                     4
# Label_dim                     1
# Hidden_dim                    16
# Train_split                   [0, 1, 2, 3, 4, 5, 6]
# Validation_split              [7]
# Test_split                    [8, 9]
# Custom_split                  [0, 1, 2, 3, 4, 5]
# Batch_display_step            100
# Image_scale                   1
# ...

# %%
# %run "Code_UNet_2/Code_UNet_Re/Test_RANO.py"
x = "5"
# Out:
# Torch version:  1.10.1+cu102
#
# Seed                          11
# device                        cuda
# GPU                           3
# Param_location                Code_UNet_2/Code_UNet_Re/Net_modules/Model_hyperparameters.py
# Debug                         False
# Net                           UNet
# Enable_Determinism            True
# Cosine_penalty                10
# Epochs                        50
# Batch_size                    8
# Learning_rate                 0.0003
# Weight_decay                  1e-08
# Betas                         (0.9, 0.999)
# Input_dim                     4
# Label_dim                     1
# Hidden_dim                    16
# Train_split                   [0, 1, 2, 3, 4, 5, 6]
# Validation_split              [7]
# Test_split                    [8, 9]
# Custom_split                  [0, 1, 2, 3, 4, 5]
# Batch_display_step            100
# Image_scale                   1
# Image_size                    [240, 240]
# ...

# %%
# %run "Code_UNet_2/Code_UNet_Re/Test_RANO.py"
x = "100"
# Out:
# <class 'Net_modules.Model_hyperparameters.Parameters'>
# Torch version:  1.10.1+cu102
#
# Seed                          11
# device                        cuda
# GPU                           3
# Param_location                Code_UNet_2/Code_UNet_Re/Net_modules/Model_hyperparameters.py
# Debug                         False
# Net                           UNet
# Enable_Determinism            True
# Cosine_penalty                10
# Epochs                        50
# Batch_size                    8
# Learning_rate                 0.0003
# Weight_decay                  1e-08
# Betas                         (0.9, 0.999)
# Input_dim                     4
# Label_dim                     1
# Hidden_dim                    16
# Train_split                   [0, 1, 2, 3, 4, 5, 6]
# Validation_split              [7]
# Test_split                    [8, 9]
# Custom_split                  [0, 1, 2, 3, 4, 5]
# Batch_display_step            100
# Image_scale                   1
# ...

# %%
# %run "Code_UNet_2/Code_UNet_Re/Test_RANO.py"
x = "100"
# Out:
# <class 'Net_modules.Model_hyperparameters.Parameters'>
# Torch version:  1.10.1+cu102
#
# Seed                          11
# device                        cuda
# GPU                           2
# Param_location                Code_UNet_2/Code_UNet_Re/Net_modules/Model_hyperparameters.py
# Debug                         False
# Net                           UNet
# Enable_Determinism            True
# Cosine_penalty                10
# Epochs                        50
# Batch_size                    8
# Learning_rate                 0.0003
# Weight_decay                  1e-08
# Betas                         (0.9, 0.999)
# Input_dim                     4
# Label_dim                     1
# Hidden_dim                    16
# Train_split                   [0, 1, 2, 3, 4, 5, 6]
# Validation_split              [7]
# Test_split                    [8, 9]
# Custom_split                  [0, 1, 2, 3, 4, 5]
# Batch_display_step            100
# Image_scale                   1
# ...
