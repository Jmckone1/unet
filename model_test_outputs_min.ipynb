# %%
## import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
from skimage.measure import block_reduce

title = "title"
legend_names = ["legend"]

for out_type in ["loss","dice"]:
    for training_phase in ["training", "validation"]:
        
        loss_0 = []
        loss_Nan_0 = []
        
        # using sigmoid
        File_name = "Checkpoints/Checkpoints/Output_Test_21/epoch_0"+training_phase+"_"+out_type+".csv"
        loss_0, loss_Nan_0 = [],[]

        loss_0 = np.genfromtxt(File_name, delimiter=',',invalid_raise = False)
#         #print(loss_0)
#         print("Model 1")
#         print(loss_0[110:140])
        
#         print(len(loss_0))
        if training_phase == "training":
            val = 1
        else:
            val = 1
            
        if out_type == "dice":
            loss_0 = np.ndarray.flatten(loss_0)
            loss_0 = block_reduce(loss_0, block_size=(16,), func=np.mean, cval=np.mean(loss_0[:len(loss_0)-1]))

        plt.plot(range(len(loss_0[0::val])),loss_0[0::val])
        
        loss_0 = []
        loss_Nan_0 = []
        
        File_name = "Checkpoints/Checkpoints/Output_Test_22/epoch_0"+training_phase+"_"+out_type+".csv"
        loss_0, loss_Nan_0 = [],[]

        loss_0 = np.genfromtxt(File_name, delimiter=',',invalid_raise = False)
#         print("Model 2")
#         print(loss_0[110:140])
#         print(len(loss_0))
        if training_phase == "training":
            val = 1
        else:
            val = 1
            
        if out_type == "dice":
            loss_0 = np.ndarray.flatten(loss_0)
            loss_0 = block_reduce(loss_0, block_size=(16,), func=np.mean, cval=np.mean(loss_0[:len(loss_0)-1]))
        
        plt.plot(range(len(loss_0[0::val])),loss_0[0::val])

        plt.title(training_phase + " " + out_type,fontsize=20)
        plt.legend(["model1","model2"], fontsize=16)
        plt.xlabel("Epoch / " + str(val) ,fontsize=18)
        plt.ylabel(ylabel=out_type,fontsize=18)
        plt.grid()
        plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: ConversionWarning: Some errors were detected !
#     Line #553 (got 1 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:42: ConversionWarning: Some errors were detected !
#     Line #553 (got 1 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: ConversionWarning: Some errors were detected !
#     Line #553 (got 6 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:42: ConversionWarning: Some errors were detected !
#     Line #553 (got 6 columns instead of 8)

# %%
## import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
from skimage.measure import block_reduce

title = "title"
legend_names = ["legend"]

for out_type in ["loss","dice"]:
    for training_phase in ["training", "validation"]:
        
        loss_0 = []
        loss_Nan_0 = []
        
        # using sigmoid
        File_name = "Checkpoints/Checkpoints/Output_Test_27/epoch_0"+training_phase+"_"+out_type+".csv"
        loss_0, loss_Nan_0 = [],[]

        loss_0 = np.genfromtxt(File_name, delimiter=',',invalid_raise = False)
        #print(loss_0)
#         print("Model 1")
#         print(loss_0[110:140])
        
        print(len(loss_0))
        if training_phase == "training":
            val = 32
        else:
            val = 32
            
        if out_type == "dice":
            loss_0 = np.ndarray.flatten(loss_0)
            loss_0 = block_reduce(loss_0, block_size=(16,), func=np.mean, cval=np.mean(loss_0[:len(loss_0)-1]))

        plt.plot(range(len(loss_0[0::val])),loss_0[0::val])
        
        loss_0 = []
        loss_Nan_0 = []
        
        File_name = "Checkpoints/Checkpoints/Output_Test_28/epoch_0"+training_phase+"_"+out_type+".csv"
        loss_0, loss_Nan_0 = [],[]

        loss_0 = np.genfromtxt(File_name, delimiter=',',invalid_raise = False)
#         print("Model 2")
#         print(loss_0[110:140])
#         print(len(loss_0))
        if training_phase == "training":
            val = 32
        else:
            val = 32
            
        if out_type == "dice":
            loss_0 = np.ndarray.flatten(loss_0)
            loss_0 = block_reduce(loss_0, block_size=(16,), func=np.mean, cval=np.mean(loss_0[:len(loss_0)-1]))
        
        plt.plot(range(len(loss_0[0::val])),loss_0[0::val])

        plt.title(training_phase + " " + out_type,fontsize=20)
        plt.legend(["model1","model2"], fontsize=16)
        plt.xlabel("Epoch / " + str(val) ,fontsize=18)
        plt.ylabel(ylabel=out_type,fontsize=18)
        plt.grid()
        plt.show()
# Out:
# 553
# 553
# 552
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: ConversionWarning: Some errors were detected !
#     Line #553 (got 1 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:42: ConversionWarning: Some errors were detected !
#     Line #553 (got 1 columns instead of 8)
# 552
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: ConversionWarning: Some errors were detected !
#     Line #553 (got 6 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:42: ConversionWarning: Some errors were detected !
#     Line #553 (got 6 columns instead of 8)

# %%
## import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
from skimage.measure import block_reduce

title = "title"
legend_names = ["legend"]

for out_type in ["loss","dice"]:
    for training_phase in ["training", "validation"]:
        
        loss_0 = []
        loss_Nan_0 = []
        
        # using sigmoid
        File_name = "Checkpoints/Checkpoints/Model_10_percent_input/epoch_0"+training_phase+"_"+out_type+".csv"
        loss_0, loss_Nan_0 = [],[]

        loss_0 = np.genfromtxt(File_name, delimiter=',',invalid_raise = False)
        #print(loss_0)
#         print("Model 1")
#         print(loss_0[110:140])
        
        print(len(loss_0))
        if training_phase == "training":
            val = 1
        else:
            val = 1
            
        if out_type == "dice":
            loss_0 = np.ndarray.flatten(loss_0)
            loss_0 = block_reduce(loss_0, block_size=(16,), func=np.mean, cval=np.mean(loss_0[:len(loss_0)-1]))

        plt.plot(range(len(loss_0[0::val])),loss_0[0::val])
        
        loss_0 = []
        loss_Nan_0 = []
        
        File_name = "Checkpoints/Checkpoints/Model_20_percent_input/epoch_0"+training_phase+"_"+out_type+".csv"
        loss_0, loss_Nan_0 = [],[]

        loss_0 = np.genfromtxt(File_name, delimiter=',',invalid_raise = False)
#         print("Model 2")
#         print(loss_0[110:140])
#         print(len(loss_0))
        if training_phase == "training":
            val = 1
        else:
            val = 1
            
        if out_type == "dice":
            loss_0 = np.ndarray.flatten(loss_0)
            loss_0 = block_reduce(loss_0, block_size=(16,), func=np.mean, cval=np.mean(loss_0[:len(loss_0)-1]))
        
        plt.plot(range(len(loss_0[0::val])),loss_0[0::val])

        plt.title(training_phase + " " + out_type,fontsize=20)
        plt.legend(["model1","model2"], fontsize=16)
        plt.xlabel("Epoch / " + str(val) ,fontsize=18)
        plt.ylabel(ylabel=out_type,fontsize=18)
        plt.grid()
        plt.show()
# Out:
# 553
# 553
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: ConversionWarning: Some errors were detected !
#     Line #553 (got 1 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:42: ConversionWarning: Some errors were detected !
#     Line #1105 (got 2 columns instead of 8)
# 552
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: ConversionWarning: Some errors were detected !
#     Line #553 (got 6 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:42: ConversionWarning: Some errors were detected !
#     Line #553 (got 6 columns instead of 8)
# 552

# %%
# Segmentation outputs for differing training data size amounts

from matplotlib.ticker import MultipleLocator
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import csv  

sns.set(font_scale = 1.35)
sns.set_style("white",{"grid.color": ".5", "grid.linestyle": ":"})

epoch = 0
for show_ones in [False, True]:
    for train_stage in ["training","validation"]:
        percentage_array = [10,20,30,40,50,100]
        inputs,inputs2 = ["","","","","",""],["","","","","",""]
        pred_type = ["predictions_sigmoid","predictions"]

        for percentage in range(len(percentage_array)):
            inputs[percentage] ="Checkpoints/Checkpoints/Model_"+str(percentage_array[percentage])+"_percent_input/epoch_0"+train_stage+"_dice.csv"
            inputs2[percentage] = "Checkpoints/Checkpoints/Brats_"+str(percentage_array[percentage])+"_c_100_pretrained/epoch_0"+train_stage+"_dice.csv"

        title_output_model = ["RI", "PTE"]#, "PTE"]
        col_name = ["10%","20%","30%","40%","50%","100%"]
        train_data_input = pd.DataFrame(data=None, columns=title_output_model)# .astype(int)

        x_array = np.array([])
        y_array = np.array([])
        z_array = np.array([])
        a_array = np.array([])

        index = [0,1,2,3,4,5]
        input_test = [inputs, inputs2]#, inputs3]

        for i in range(len(index)):
            x_array = np.array([])
            y_array = np.array([])
            z_array = np.array([])

            x_array = np.genfromtxt(input_test[0][index[i]], delimiter=',',invalid_raise = False)
            x_array = np.ndarray.flatten(x_array)
#             print(len(x_array[x_array == 1]), "/", len(x_array))
            if show_ones == True:
                x_array[x_array == 1] = np.nan

            y_array = np.genfromtxt(input_test[1][index[i]], delimiter=',',invalid_raise = False)
            y_array = np.ndarray.flatten(y_array)
#             print(len(y_array[y_array == 1]), "/", len(y_array))
            if show_ones == True:
                y_array[y_array == 1] = np.nan

            df1 = pd.DataFrame(data = {"Division":np.full(len(x_array), col_name[index[i]]),
                                       "RI":x_array,"PTE":y_array})#,"PTE":z_array})
            train_data_input = train_data_input.append(df1,ignore_index=True)

        data = train_data_input.melt('Division', var_name='Model Pre-training level', value_name='Mean Dice')
        fig = plt.figure(figsize=(12,5))
        plt.grid()
        ax=sns.boxplot(y='Mean Dice', x='Division', hue='Model Pre-training level', data=data)
        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
        plt.title("Mean Testing Dice score by model pretraining.\n Grouped by percentage of dataset trained on."
                 ,fontsize=20)
        plt.ylim(-0.05,1.05)
        ax.xaxis.set_minor_locator(MultipleLocator(0.5))
        ax.xaxis.grid(True, which='minor', color='black', lw=1)
        plt.xlabel("Dataset division percentages",fontsize=18)
        plt.ylabel("Mean Volume Dice Score",fontsize=18)
        plt.show()

        fig = plt.figure(figsize=(12,5))
        plt.grid()
        ax=sns.boxplot(y='Mean Dice', x='Model Pre-training level', hue='Division', data=data)
        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
        plt.title("Mean Testing Dice score by percentage of dataset trained on.\n Grouped by model pretraining level."
                 ,fontsize=20)
        plt.ylim(-0.05,1.05)
        ax.xaxis.set_minor_locator(MultipleLocator(0.5))
        ax.xaxis.grid(True, which='minor', color='black', lw=1)
        plt.xlabel("Dataset division percentages",fontsize=18)
        plt.ylabel("Mean Volume Dice Score",fontsize=18)
        plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:42: ConversionWarning: Some errors were detected !
#     Line #553 (got 1 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:48: ConversionWarning: Some errors were detected !
#     Line #553 (got 1 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:42: ConversionWarning: Some errors were detected !
#     Line #1105 (got 2 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:48: ConversionWarning: Some errors were detected !
#     Line #1105 (got 2 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:42: ConversionWarning: Some errors were detected !
#     Line #1657 (got 3 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:48: ConversionWarning: Some errors were detected !
#     Line #1657 (got 3 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:42: ConversionWarning: Some errors were detected !
#     Line #2209 (got 4 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:48: ConversionWarning: Some errors were detected !
#     Line #2209 (got 4 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:42: ConversionWarning: Some errors were detected !
#     Line #2761 (got 5 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:48: ConversionWarning: Some errors were detected !
#     Line #2761 (got 5 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:42: ConversionWarning: Some errors were detected !
#     Line #4970 (got 1 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:48: ConversionWarning: Some errors were detected !
#     Line #4970 (got 1 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:42: ConversionWarning: Some errors were detected !
#     Line #553 (got 6 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:48: ConversionWarning: Some errors were detected !
#     Line #553 (got 1 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:42: ConversionWarning: Some errors were detected !
#     Line #553 (got 1 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:48: ConversionWarning: Some errors were detected !
#     Line #553 (got 1 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:42: ConversionWarning: Some errors were detected !
#     Line #1105 (got 2 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:48: ConversionWarning: Some errors were detected !
#     Line #1105 (got 2 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:42: ConversionWarning: Some errors were detected !
#     Line #1657 (got 3 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:48: ConversionWarning: Some errors were detected !
#     Line #1657 (got 3 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:42: ConversionWarning: Some errors were detected !
#     Line #2209 (got 4 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:48: ConversionWarning: Some errors were detected !
#     Line #2209 (got 4 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:42: ConversionWarning: Some errors were detected !
#     Line #2761 (got 5 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:48: ConversionWarning: Some errors were detected !
#     Line #2761 (got 5 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:42: ConversionWarning: Some errors were detected !
#     Line #4970 (got 1 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:48: ConversionWarning: Some errors were detected !
#     Line #4970 (got 1 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:42: ConversionWarning: Some errors were detected !
#     Line #553 (got 6 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:48: ConversionWarning: Some errors were detected !
#     Line #553 (got 1 columns instead of 8)

# %%
import matplotlib.pyplot as plt
import numpy as np

title = "title"
legend_names = ["legend"]

for out_type in ["loss","jaccard_index"]:
    for training_phase in ["training", "validation"]:
        if out_type == "loss" and training_phase == "training":
            filestring = "Training_loss"
        if out_type == "loss" and training_phase == "validation":
            filestring = "Validation_loss"
        if out_type == "jaccard_index" and training_phase == "training":
            filestring = "Training_Jaccard"
        if out_type == "jaccard_index" and training_phase == "validation":
            filestring = "Validation_Jaccard"
        loss_0 = []
        loss_Nan_0 = []
        
        # using sigmoid
        
        File_name = "Checkpoints_RANO/Checkpoints/Prano_test_01/"+filestring +"/epoch_0"+training_phase+"_"+out_type+".csv"
        if out_type == "jaccard_index" and training_phase == "training":
             File_name = "Checkpoints_RANO/Checkpoints/Prano_test_01/"+filestring +"/epoch_0"+out_type+".csv"
        loss_0, loss_Nan_0 = [],[]

        loss_0 = np.genfromtxt(File_name, delimiter=',')
        if training_phase == "training":
            val = 1
        else:
            val = 1
        
        plt.plot(range(len(loss_0[0::val])),loss_0[0::val])
        
        loss_0 = []
        loss_Nan_0 = []
        
        File_name = "Checkpoints_RANO/Checkpoints/Prano_test_02/"+filestring +"/epoch_0"+training_phase+"_"+out_type+".csv"
        if out_type == "jaccard_index" and training_phase == "training":
             File_name = "Checkpoints_RANO/Checkpoints/Prano_test_01/"+filestring +"/epoch_0"+out_type+".csv"
        loss_0, loss_Nan_0 = [],[]

        loss_0 = np.genfromtxt(File_name, delimiter=',')
        if training_phase == "training":
            val = 1
        else:
            val = 1
        
        plt.plot(range(len(loss_0[0::val])),loss_0[0::val])

        plt.title(training_phase + " " + out_type,fontsize=20)
        plt.legend(["model1","model2"], fontsize=16)
        plt.xlabel("Epoch / " + str(val) ,fontsize=18)
        plt.ylabel(ylabel=out_type,fontsize=18)
        plt.grid()
        plt.show()

# %%
# RANO output loss for both training and validation - over differing penalty types

from matplotlib.pyplot import figure
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

Epochs = 50

sns.set(font_scale = 1.35)
sns.set_style("white",{"grid.color": ".5", "grid.linestyle": ":"})

input_names = ["Prano_pretrain_1_C100"]
legend_names = ["Validation", "Training"]

output_type = ["validation_loss","training_loss"]
output_axis = ["MSE loss + cosine loss"]
output_title = ["Loss"]
second_out = ["Validation_loss","Training_loss"]

loss_0 = []
loss_Nan_0 = []
figure(figsize=(14, 6), dpi=80)
ax = plt.subplot()
for c in range(len(output_type)):

    for s in range(len(input_names)):
        for i in range(Epochs):
            
            loss_0 = np.genfromtxt("Checkpoints_RANO/Checkpoints/"+ input_names[s]+ "/" + second_out[c] + "/epoch_"+str(i)+output_type[c] + ".csv",delimiter=',')
            loss_Nan_0 = np.append(loss_Nan_0, np.mean(loss_0[np.logical_not(np.isnan(loss_0))]))
            if c > (len(output_type) - 3):
                loss_Nan_0[i] = loss_Nan_0[i]

        ax.plot(range(len(loss_Nan_0)),loss_Nan_0)
        loss_0 = []
        loss_Nan_0 = []

plt.title("Mean " + output_title[0] + " per Epoch ",fontsize=20)
ax.legend(legend_names, bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0, fontsize=16)
plt.xlabel("Epoch",fontsize=18)
plt.ylabel(ylabel=output_axis[0],fontsize=18)
plt.grid()
plt.show()    
    
# RANO output loss for both training and validation - over differing penalty types

from matplotlib.pyplot import figure
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

sns.set(font_scale = 1.35)
sns.set_style("white",{"grid.color": ".5", "grid.linestyle": ":"})

input_names = ["Prano_pretrain_1_C100"]
legend_names = ["Validation", "Training"]

output_type = ["validation_jaccard_index","jaccard_index"]
output_axis = ["Jaccard score"]
output_title = ["Jaccard"]
second_out = ["Validation_Jaccard","Training_Jaccard"]

loss_0 = []
loss_Nan_0 = []
figure(figsize=(14, 6), dpi=80)
ax = plt.subplot()
for c in range(len(output_type)):

    for s in range(len(input_names)):
        for i in range(Epochs):
            
            loss_0 = np.genfromtxt("Checkpoints_RANO/Checkpoints/"+ input_names[s]+ "/" + second_out[c] + "/epoch_"+str(i)+output_type[c] + ".csv",delimiter=',')
            loss_Nan_0 = np.append(loss_Nan_0, np.mean(loss_0[np.logical_not(np.isnan(loss_0))]))
            if c > (len(output_type) - 3):
                loss_Nan_0[i] = loss_Nan_0[i]

        ax.plot(range(len(loss_Nan_0)),loss_Nan_0)
        loss_0 = []
        loss_Nan_0 = []

plt.title("Mean " + output_title[0] + " per Epoch ",fontsize=20)
ax.legend(legend_names, bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0, fontsize=16)
plt.xlabel("Epoch",fontsize=18)
plt.ylabel(ylabel=output_axis[0],fontsize=18)
plt.grid()
plt.show()

# %%
print("CT DATA")

## import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
from skimage.measure import block_reduce

title = "title"
legend_names = ["legend"]

for out_type in ["loss","dice"]:
    for training_phase in ["training", "validation"]:
        
#         loss_0 = []
#         loss_Nan_0 = []
        
#         # using sigmoid
#         File_name = "Checkpoints/Checkpoints/CT_Test_08_06_2023_3/epoch_0"+training_phase+"_"+out_type+".csv"
#         loss_0, loss_Nan_0 = [],[]

# #         loss_0 = np.genfromtxt(File_name, delimiter=',',invalid_raise = False)
#         print(loss_0)
#         #print(loss_0)
# #         print("Model 1")
# #         print(loss_0[110:140])
        
#         print(len(loss_0))
#         if training_phase == "training":
#             val = 1
#         else:
#             val = 1
            
#         if out_type == "dice":
#             loss_0 = np.ndarray.flatten(loss_0)
#             loss_0 = block_reduce(loss_0, block_size=(16,), func=np.mean, cval=np.mean(loss_0[:len(loss_0)-1]))

#         plt.plot(range(len(loss_0[0::val])),loss_0[0::val])
#         plt.ylim(-0.01, 0.1)
        loss_0 = []
        loss_Nan_0 = []
        
        File_name = "Checkpoints/Checkpoints/CT_Test_08_06_2023_4/epoch_0"+training_phase+"_"+out_type+".csv"
        loss_0, loss_Nan_0 = [],[]

        loss_0 = np.genfromtxt(File_name, delimiter=',',invalid_raise = False)
#         print(loss_0)
#         print("Model 2")
#         print(loss_0[110:140])
#         print(len(loss_0))
        if training_phase == "training":
            val = 1
        else:
            val = 1
            
        if out_type == "dice":
            loss_0 = np.ndarray.flatten(loss_0)
            loss_0 = block_reduce(loss_0, block_size=(16,), func=np.mean, cval=np.mean(loss_0[:len(loss_0)-1]))
        
        plt.plot(range(len(loss_0[0::val])),loss_0[0::val])

        plt.title(training_phase + " " + out_type,fontsize=20)
        plt.legend(["model1","model2"], fontsize=16)
        plt.xlabel("Epoch / " + str(val) ,fontsize=18)
        plt.ylabel(ylabel=out_type,fontsize=18)
        plt.grid()
        plt.show()
        
#         brats_Test_08_06_2023_4
# Out:
# CT DATA
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:45: ConversionWarning: Some errors were detected !
#     Line #221 (got 5 columns instead of 8)

# %%
print("CT DATA")

## import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
from skimage.measure import block_reduce

title = "title"
legend_names = ["legend"]

for out_type in ["loss","dice"]:
    for training_phase in ["training", "validation"]:
        
#         loss_0 = []
#         loss_Nan_0 = []
        
#         # using sigmoid
#         File_name = "Checkpoints/Checkpoints/CT_Test_08_06_2023_2/epoch_0"+training_phase+"_"+out_type+".csv"
#         loss_0, loss_Nan_0 = [],[]

#         loss_0 = np.genfromtxt(File_name, delimiter=',',invalid_raise = False)
# #         print(loss_0)
#         #print(loss_0)
# #         print("Model 1")
# #         print(loss_0[110:140])
        
# #         print(len(loss_0))
#         if training_phase == "training":
#             val = 1
#         else:
#             val = 1
            
#         if out_type == "dice":
#             loss_0 = np.ndarray.flatten(loss_0)
#             loss_0 = block_reduce(loss_0, block_size=(16,), func=np.mean, cval=np.mean(loss_0[:len(loss_0)-1]))

#         plt.plot(range(len(loss_0[0::val])),loss_0[0::val])
#         plt.ylim(-0.01, 0.1)
        loss_0 = []
        loss_Nan_0 = []
        
        File_name = "Checkpoints/Checkpoints/CT_Test_08_06_2023_2/epoch_0"+training_phase+"_"+out_type+".csv"
        loss_0, loss_Nan_0 = [],[]

        loss_0 = np.genfromtxt(File_name, delimiter=',',invalid_raise = False)
#         print(loss_0)
#         print("Model 2")
#         print(loss_0[110:140])
#         print(len(loss_0))
        if training_phase == "training":
            val = 1
        else:
            val = 1
            
        if out_type == "dice":
            loss_0 = np.ndarray.flatten(loss_0)
            loss_0 = block_reduce(loss_0, block_size=(16,), func=np.mean, cval=np.mean(loss_0[:len(loss_0)-1]))
        
        plt.plot(range(len(loss_0[0::val])),loss_0[0::val])

        plt.title(training_phase + " " + out_type,fontsize=20)
        plt.legend(["model1","model2"], fontsize=16)
        plt.xlabel("Epoch / " + str(val) ,fontsize=18)
        plt.ylabel(ylabel=out_type,fontsize=18)
        plt.grid()
        plt.show()
        
#         brats_Test_08_06_2023_4
# Out:
# CT DATA
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:45: ConversionWarning: Some errors were detected !
#     Line #221 (got 5 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:45: ConversionWarning: Some errors were detected !
#     Line #221 (got 5 columns instead of 8)

# %%
print("CT vs MRI")

## import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
from skimage.measure import block_reduce

title = "title"
legend_names = ["legend"]

for out_type in ["loss","dice"]:
    length = 0
    for training_phase in ["training", "validation"]:
        
        loss_0 = []
        loss_Nan_0 = []
        
        # using sigmoid
        File_name = "Checkpoints/Checkpoints/brats_Test_08_06_2023_4/epoch_0"+training_phase+"_"+out_type+".csv"
        loss_0, loss_Nan_0 = [],[]
        
        
        if training_phase == "training":
            val = 4
            length = 500
        else:
            val = 4
            length = 200

        loss_0 = np.genfromtxt(File_name, delimiter=',',invalid_raise = False)
        loss_0 = loss_0[:length]
#         print(len(loss_0))
#         input("")
#         print(loss_0)

        if out_type == "dice":
            loss_0 = np.ndarray.flatten(loss_0)
            loss_0 = block_reduce(loss_0, block_size=(16,), func=np.mean, cval=np.mean(loss_0[:len(loss_0)-1]))

        plt.plot(range(len(loss_0[0::val])),loss_0[0::val])
#         plt.ylim(-0.01, 0.1)
        loss_1 = []
        loss_Nan_1 = []
        
        File_name = "Checkpoints/Checkpoints/CT_Test_08_06_2023_3/epoch_0"+training_phase+"_"+out_type+".csv"
        
        if training_phase == "training":
            val = 4
            length = 500
        else:
            val = 4
            length = 200
            
        loss_1, loss_Nan_1 = [],[]

        loss_1 = np.genfromtxt(File_name, delimiter=',',invalid_raise = False)
        loss_1 = loss_1[:length]
#         print(len(loss_1))
#         print(loss_1)

            
        if out_type == "dice":
            loss_1 = np.ndarray.flatten(loss_1)
            loss_1 = block_reduce(loss_1, block_size=(16,), func=np.mean, cval=np.mean(loss_1[:len(loss_1)-1]))
        
        plt.plot(range(len(loss_1[0::val])),loss_1[0::val])

        plt.title(training_phase + " " + out_type,fontsize=20)
        plt.legend(["MRI","CT"], fontsize=16)
        plt.xlabel("Epoch / " + str(val) ,fontsize=18)
        plt.ylabel(ylabel=out_type,fontsize=18)
        plt.grid()
        plt.show()
# Out:
# CT vs MRI
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:30: ConversionWarning: Some errors were detected !
#     Line #553 (got 1 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:30: ConversionWarning: Some errors were detected !
#     Line #553 (got 1 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:56: ConversionWarning: Some errors were detected !
#     Line #221 (got 5 columns instead of 8)

# %%
print("10% of the dataset")

## import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
from skimage.measure import block_reduce

title = "title"
legend_names = ["legend"]



for out_type in ["loss","dice"]:
    for training_phase in ["training", "validation"]:
        
        loss_0 = []
        loss_Nan_0 = []
        
        # using sigmoid
        File_name = "Checkpoints/Checkpoints/Model_10_percent_input/epoch_0"+training_phase+"_"+out_type+".csv"
        loss_0, loss_Nan_0 = [],[]

        loss_0 = np.genfromtxt(File_name, delimiter=',',invalid_raise = False)
#         print(loss_0)
        #print(loss_0)
#         print("Model 1")
#         print(loss_0[110:140])
        
#         print(len(loss_0))
        if training_phase == "training":
            val = 8
        else:
            val = 8
            
        if out_type == "dice":
            loss_0 = np.ndarray.flatten(loss_0)
            loss_0 = block_reduce(loss_0, block_size=(16,), func=np.mean, cval=np.mean(loss_0[:len(loss_0)-1]))

        plt.plot(range(len(loss_0[0::val])),loss_0[0::val])
#         plt.ylim(-0.01, 0.1)
        loss_0 = []
        loss_Nan_0 = []
        
        File_name = "Checkpoints/Checkpoints/Brats_10_c_100_pretrained/epoch_0"+training_phase+"_"+out_type+".csv"
        loss_0, loss_Nan_0 = [],[]

        loss_0 = np.genfromtxt(File_name, delimiter=',',invalid_raise = False)
#         print(loss_0)
#         print("Model 2")
#         print(loss_0[110:140])
#         print(len(loss_0))
        if training_phase == "training":
            val = 8
        else:
            val = 8
            
        if out_type == "dice":
            loss_0 = np.ndarray.flatten(loss_0)
            loss_0 = block_reduce(loss_0, block_size=(16,), func=np.mean, cval=np.mean(loss_0[:len(loss_0)-1]))
        
        plt.plot(range(len(loss_0[0::val])),loss_0[0::val])

        plt.title(training_phase + " " + out_type,fontsize=20)
        plt.legend(["model1","model2"], fontsize=16)
        plt.xlabel("Epoch / " + str(val) ,fontsize=18)
        plt.ylabel(ylabel=out_type,fontsize=18)
        plt.grid()
        plt.show()
        
#         brats_Test_08_06_2023_4
# Brats_10_c_100_pretrained_5_epochs
# Out:
# 10% of the dataset
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: ConversionWarning: Some errors were detected !
#     Line #553 (got 1 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:47: ConversionWarning: Some errors were detected !
#     Line #553 (got 1 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: ConversionWarning: Some errors were detected !
#     Line #553 (got 6 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:47: ConversionWarning: Some errors were detected !
#     Line #553 (got 1 columns instead of 8)

# %%
print("10% of the dataset ")

## import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
from skimage.measure import block_reduce

title = "title"
legend_names = ["legend"]



for out_type in ["loss","dice"]:
    for training_phase in ["training", "validation"]:
        
        loss_0 = []
        loss_Nan_0 = []
        
        # using sigmoid
        File_name = "Checkpoints/Checkpoints/Model_10_percent_input/epoch_0"+training_phase+"_"+out_type+".csv"
        loss_0, loss_Nan_0 = [],[]

        loss_0 = np.genfromtxt(File_name, delimiter=',',invalid_raise = False)
#         print(loss_0)
        #print(loss_0)
#         print("Model 1")
#         print(loss_0[110:140])
        
#         print(len(loss_0))
        if training_phase == "training":
            val = 8
        else:
            val = 8
            
        if out_type == "dice":
            loss_0 = np.ndarray.flatten(loss_0)
            loss_0 = block_reduce(loss_0, block_size=(16,), func=np.mean, cval=np.mean(loss_0[:len(loss_0)-1]))

        plt.plot(range(len(loss_0[0::val])),loss_0[0::val])
#         plt.ylim(-0.01, 0.1)
        loss_0 = []
        loss_Nan_0 = []
        
        File_name = "Checkpoints/Checkpoints/Brats_10_c_100_pretrained_5_epochs/epoch_0"+training_phase+"_"+out_type+".csv"
        loss_0, loss_Nan_0 = [],[]

        loss_0 = np.genfromtxt(File_name, delimiter=',',invalid_raise = False)
#         print(loss_0)
#         print("Model 2")
#         print(loss_0[110:140])
#         print(len(loss_0))
        if training_phase == "training":
            val = 8
        else:
            val = 8
            
        if out_type == "dice":
            loss_0 = np.ndarray.flatten(loss_0)
            loss_0 = block_reduce(loss_0, block_size=(16,), func=np.mean, cval=np.mean(loss_0[:len(loss_0)-1]))
        
        plt.plot(range(len(loss_0[0::val])),loss_0[0::val])

        plt.title(training_phase + " " + out_type,fontsize=20)
        plt.legend(["RI","PTE"], fontsize=16)
        plt.xlabel("Epoch / " + str(val) ,fontsize=18)
        plt.ylabel(ylabel=out_type,fontsize=18)
        plt.grid()
        plt.show()
        
#         brats_Test_08_06_2023_4
# Brats_10_c_100_pretrained_5_epochs
# Brats_10_c_100_pretrained_5_epochs
# Out:
# 10% of the dataset
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: ConversionWarning: Some errors were detected !
#     Line #553 (got 1 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:47: ConversionWarning: Some errors were detected !
#     Line #553 (got 1 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: ConversionWarning: Some errors were detected !
#     Line #553 (got 6 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:47: ConversionWarning: Some errors were detected !
#     Line #553 (got 1 columns instead of 8)

# %%
print("10% of the dataset - Random init vs pretrained")

## import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
from skimage.measure import block_reduce

title = "title"
legend_names = ["legend"]



for out_type in ["loss","dice"]:
    for training_phase in ["training", "validation"]:
        
        loss_0 = []
        loss_Nan_0 = []
        
        # using sigmoid
        File_name = "Checkpoints/Checkpoints/Brats_10_c_100_randomInit_5_epochs/epoch_4"+training_phase+"_"+out_type+".csv"
        loss_0, loss_Nan_0 = [],[]

        loss_0 = np.genfromtxt(File_name, delimiter=',',invalid_raise = False)
#         print(loss_0)
        #print(loss_0)
#         print("Model 1")
#         print(loss_0[110:140])
        
#         print(len(loss_0))
        if training_phase == "training":
            val = 8
        else:
            val = 8
            
        if out_type == "dice":
            loss_0 = np.ndarray.flatten(loss_0)
            loss_0 = block_reduce(loss_0, block_size=(16,), func=np.mean, cval=np.mean(loss_0[:len(loss_0)-1]))

        plt.plot(range(len(loss_0[0::val])),loss_0[0::val])
#         plt.ylim(-0.01, 0.1)
        loss_0 = []
        loss_Nan_0 = []
        
        File_name = "Checkpoints/Checkpoints/Brats_10_c_100_pretrained_5_epochs/epoch_4"+training_phase+"_"+out_type+".csv"
        loss_0, loss_Nan_0 = [],[]

        loss_0 = np.genfromtxt(File_name, delimiter=',',invalid_raise = False)
#         print(loss_0)
#         print("Model 2")
#         print(loss_0[110:140])
#         print(len(loss_0))
        if training_phase == "training":
            val = 8
        else:
            val = 8
            
        if out_type == "dice":
            loss_0 = np.ndarray.flatten(loss_0)
            loss_0 = block_reduce(loss_0, block_size=(16,), func=np.mean, cval=np.mean(loss_0[:len(loss_0)-1]))
        
        plt.plot(range(len(loss_0[0::val])),loss_0[0::val])

        plt.title(training_phase + " " + out_type,fontsize=20)
        plt.legend(["RI (random init)","PTE (Pretrained)"], fontsize=16)
        plt.xlabel("Epoch / " + str(val) ,fontsize=18)
        plt.ylabel(ylabel=out_type,fontsize=18)
        plt.grid()
        plt.show()
        
#         brats_Test_08_06_2023_4
# Brats_10_c_100_pretrained_5_epochs
# Brats_10_c_100_pretrained_5_epochs
# Out:
# 10% of the dataset - Random init vs pretrained
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: ConversionWarning: Some errors were detected !
#     Line #553 (got 1 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:47: ConversionWarning: Some errors were detected !
#     Line #553 (got 1 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: ConversionWarning: Some errors were detected !
#     Line #553 (got 1 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:47: ConversionWarning: Some errors were detected !
#     Line #553 (got 1 columns instead of 8)

# %%
# Segmentation outputs for differing training data size amounts

from matplotlib.ticker import MultipleLocator
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import csv  

sns.set(font_scale = 1.35)
sns.set_style("white",{"grid.color": ".5", "grid.linestyle": ":"})

epoch = 0
for show_ones in [False, True]:
    for train_stage in ["training","validation"]:
        percentage_array = [0,1,2,3,4,0]
        inputs,inputs2 = ["","","","","",""],["","","","","",""]
        pred_type = ["predictions_sigmoid","predictions"]

        for percentage in range(len(percentage_array)):
            inputs[percentage] ="Checkpoints/Checkpoints/Brats_10_c_100_randomInit_5_epochs/epoch_" + str(percentage_array[percentage]) + train_stage+"_dice.csv"
            inputs2[percentage] = "Checkpoints/Checkpoints/Brats_10_c_100_pretrained_5_epochs/epoch_" + str(percentage_array[percentage]) + train_stage+"_dice.csv"

        title_output_model = ["RI", "PTE"]#, "PTE"]
        col_name = ["Epoch 1","Epoch 2","Epoch 3","Epoch 4","Epoch 5","100%"]
        train_data_input = pd.DataFrame(data=None, columns=title_output_model)# .astype(int)

        x_array = np.array([])
        y_array = np.array([])
        z_array = np.array([])
        a_array = np.array([])

        index = [0,1,2,3,4]#,5]
        input_test = [inputs, inputs2]#, inputs3]

        for i in range(len(index)):
            x_array = np.array([])
            y_array = np.array([])
            z_array = np.array([])

            x_array = np.genfromtxt(input_test[0][index[i]], delimiter=',',invalid_raise = False)
            x_array = np.ndarray.flatten(x_array)
#             print(len(x_array[x_array == 1]), "/", len(x_array))
            if show_ones == True:
                x_array[x_array == 1] = np.nan

            y_array = np.genfromtxt(input_test[1][index[i]], delimiter=',',invalid_raise = False)
            y_array = np.ndarray.flatten(y_array)
#             print(len(y_array[y_array == 1]), "/", len(y_array))
            if show_ones == True:
                y_array[y_array == 1] = np.nan

            df1 = pd.DataFrame(data = {"Division":np.full(len(x_array), col_name[index[i]]),
                                       "RI":x_array,"PTE":y_array})#,"PTE":z_array})
            train_data_input = train_data_input.append(df1,ignore_index=True)

        data = train_data_input.melt('Division', var_name='Model Pre-training level', value_name='Mean Dice')
        fig = plt.figure(figsize=(12,5))
        plt.grid()
        ax=sns.boxplot(y='Mean Dice', x='Division', hue='Model Pre-training level', data=data)
        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
        plt.title("Mean "+train_stage+" Dice score by model pretraining.\n Grouped by epoch at 10% dataset trained."
                 ,fontsize=20)
        plt.ylim(-0.05,1.05)
        ax.xaxis.set_minor_locator(MultipleLocator(0.5))
        ax.xaxis.grid(True, which='minor', color='black', lw=1)
        plt.xlabel("Dataset division percentages",fontsize=18)
        plt.ylabel("Mean Volume Dice Score",fontsize=18)
        plt.show()

        fig = plt.figure(figsize=(12,5))
        plt.grid()
        ax=sns.boxplot(y='Mean Dice', x='Model Pre-training level', hue='Division', data=data)
        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
        plt.title("Mean "+train_stage+" Dice score per epoch.\n Grouped by model pretraining level at 10% dataset trained."
                 ,fontsize=20)
        plt.ylim(-0.05,1.05)
        ax.xaxis.set_minor_locator(MultipleLocator(0.5))
        ax.xaxis.grid(True, which='minor', color='black', lw=1)
        plt.xlabel("Dataset division percentages",fontsize=18)
        plt.ylabel("Mean Volume Dice Score",fontsize=18)
        plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:42: ConversionWarning: Some errors were detected !
#     Line #553 (got 1 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:48: ConversionWarning: Some errors were detected !
#     Line #553 (got 1 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:42: ConversionWarning: Some errors were detected !
#     Line #553 (got 1 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:48: ConversionWarning: Some errors were detected !
#     Line #553 (got 1 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:42: ConversionWarning: Some errors were detected !
#     Line #553 (got 1 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:48: ConversionWarning: Some errors were detected !
#     Line #553 (got 1 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:42: ConversionWarning: Some errors were detected !
#     Line #553 (got 1 columns instead of 8)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:48: ConversionWarning: Some errors were detected !
#     Line #553 (got 1 columns instead of 8)

# %%
print("TESTING DATA")
# Segmentation outputs for differing training data size amounts

from matplotlib.ticker import MultipleLocator
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import csv  

sns.set(font_scale = 1.35)
sns.set_style("white",{"grid.color": ".5", "grid.linestyle": ":"})

epoch = 0
show_ones = False
for train_stage in ["Testing"]:
    percentage_array = [0,1,2,3,4,0]
    inputs,inputs2 = ["","","","","",""],["","","","","",""]
    pred_type = ["predictions_sigmoid","predictions"]

    for percentage in range(len(percentage_array)):
        inputs[percentage] = "Test_outputs/Prano_randomInit_10_C100_Output_test/Epoch_" + str(percentage_array[percentage]) + "_Dice_predictions.csv"
        inputs2[percentage] = "Test_outputs/Prano_pretrain_10_C100_Output_test_2/Epoch_" + str(percentage_array[percentage]) + "_Dice_predictions.csv"


#             inputs[percentage] ="Checkpoints/Checkpoints/Brats_10_c_100_randomInit_5_epochs/epoch_" + str(percentage_array[percentage]) + train_stage+"_dice.csv"
#             inputs2[percentage] = "Checkpoints/Checkpoints/Brats_10_c_100_pretrained_5_epochs/epoch_" + str(percentage_array[percentage]) + train_stage+"_dice.csv"

    title_output_model = ["RI", "PTE"]#, "PTE"]
    col_name = ["Epoch 1","Epoch 2","Epoch 3","Epoch 4","Epoch 5","100%"]
    train_data_input = pd.DataFrame(data=None, columns=title_output_model)# .astype(int)

    x_array = np.array([])
    y_array = np.array([])
    z_array = np.array([])
    a_array = np.array([])

    index = [0,1,2,3,4]#,5]
    input_test = [inputs, inputs2]#, inputs3]

    for i in range(len(index)):
        x_array = np.array([])
        y_array = np.array([])
        z_array = np.array([])

        x_array = np.genfromtxt(input_test[0][index[i]], delimiter=',',invalid_raise = False)
        x_array = np.ndarray.flatten(x_array)
#             print(len(x_array[x_array == 1]), "/", len(x_array))
        if show_ones == True:
            x_array[x_array == 1] = np.nan

        y_array = np.genfromtxt(input_test[1][index[i]], delimiter=',',invalid_raise = False)
        y_array = np.ndarray.flatten(y_array)
#             print(len(y_array[y_array == 1]), "/", len(y_array))
        if show_ones == True:
            y_array[y_array == 1] = np.nan

        df1 = pd.DataFrame(data = {"Division":np.full(len(x_array), col_name[index[i]]),
                                   "RI":x_array,"PTE":y_array})#,"PTE":z_array})
        train_data_input = train_data_input.append(df1,ignore_index=True)

    data = train_data_input.melt('Division', var_name='Model Pre-training level', value_name='Mean Dice')
    fig = plt.figure(figsize=(12,5))
    plt.grid()
    ax=sns.boxplot(y='Mean Dice', x='Division', hue='Model Pre-training level', data=data)
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
    plt.title("Mean "+train_stage+" Dice score by model pretraining.\n Grouped by epoch at 10% dataset trained."
             ,fontsize=20)
    plt.ylim(-0.05,1.05)
    ax.xaxis.set_minor_locator(MultipleLocator(0.5))
    ax.xaxis.grid(True, which='minor', color='black', lw=1)
    plt.xlabel("Dataset division percentages",fontsize=18)
    plt.ylabel("Mean Volume Dice Score",fontsize=18)
    plt.show()

    fig = plt.figure(figsize=(12,5))
    plt.grid()
    ax=sns.boxplot(y='Mean Dice', x='Model Pre-training level', hue='Division', data=data)
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
    plt.title("Mean "+train_stage+" Dice score per epoch.\n Grouped by model pretraining level at 10% dataset trained."
             ,fontsize=20)
    plt.ylim(-0.05,1.05)
    ax.xaxis.set_minor_locator(MultipleLocator(0.5))
    ax.xaxis.grid(True, which='minor', color='black', lw=1)
    plt.xlabel("Dataset division percentages",fontsize=18)
    plt.ylabel("Mean Volume Dice Score",fontsize=18)
    plt.show()
# Out:
# TESTING DATA

# %%
# Paired T test between epoch 1 of each setting


print("TESTING DATA")
# Segmentation outputs for differing training data size amounts

from matplotlib.ticker import MultipleLocator
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import csv  

sns.set(font_scale = 1.35)
sns.set_style("white",{"grid.color": ".5", "grid.linestyle": ":"})

epoch = 0
show_ones = False
for train_stage in ["Testing"]:
    percentage_array = [0,1,2,3,4,0]
    inputs,inputs2 = ["","","","","",""],["","","","","",""]
    pred_type = ["predictions_sigmoid","predictions"]

    for percentage in range(len(percentage_array)):
        inputs[percentage] = "Test_outputs/Prano_pretrained_10_C100_Output_test_5/Epoch_" + str(percentage_array[percentage]) + "_Dice_predictions.csv"
        inputs2[percentage] = "Test_outputs/Prano_pretrained_50_C100_Output_test_5/Epoch_" + str(percentage_array[percentage]) + "_Dice_predictions.csv"

    title_output_model = ["10%", "50%"]#, "PTE"]
    col_name = ["Epoch 1","Epoch 2","Epoch 3","Epoch 4","Epoch 5","100%"]
    train_data_input = pd.DataFrame(data=None, columns=title_output_model)# .astype(int)

    x_array = np.array([])
    y_array = np.array([])
    z_array = np.array([])
    a_array = np.array([])

    index = [0,1,2,3,4]#,5]
    input_test = [inputs, inputs2]#, inputs3]

    for i in range(len(index)):
        x_array = np.array([])
        y_array = np.array([])
        z_array = np.array([])

        x_array = np.genfromtxt(input_test[0][index[i]], delimiter=',',invalid_raise = False)
        x_array = np.ndarray.flatten(x_array)
        if show_ones == True:
            x_array[x_array == 1] = np.nan

        y_array = np.genfromtxt(input_test[1][index[i]], delimiter=',',invalid_raise = False)
        y_array = np.ndarray.flatten(y_array)
        if show_ones == True:
            y_array[y_array == 1] = np.nan

        df1 = pd.DataFrame(data = {"Division":np.full(len(x_array), col_name[index[i]]),
                                   "10%":x_array,"50%":y_array})#,"PTE":z_array})
        train_data_input = train_data_input.append(df1,ignore_index=True)

    data = train_data_input.melt('Division', var_name='Model Pre-training level', value_name='Mean Dice')
    fig = plt.figure(figsize=(10,5))
    plt.grid()
    ax=sns.boxplot(y='Mean Dice', x='Division', hue='Model Pre-training level', data=data)
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
    plt.title("Mean "+train_stage+" Dice score with pretraining. Grouped by epoch \nfor 10% vs 50% dataset used for training."
             ,fontsize=20)
    plt.ylim(-0.05,1.05)
    ax.xaxis.set_minor_locator(MultipleLocator(0.5))
    ax.xaxis.grid(True, which='minor', color='black', lw=1)
    plt.xlabel("",fontsize=18)
    plt.ylabel("Mean Volume Dice Score",fontsize=18)
    plt.show()
# Out:
# TESTING DATA

# %%
# Paired T test between epoch 1 of each setting


print("TESTING DATA")
# Segmentation outputs for differing training data size amounts

from matplotlib.ticker import MultipleLocator
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import csv  

sns.set(font_scale = 1.35)
sns.set_style("white",{"grid.color": ".5", "grid.linestyle": ":"})

epoch = 0
show_ones = False
for train_stage in ["Testing"]:
    percentage_array = [0,1,2,3,4,0]
    inputs,inputs2 = ["","","","","",""],["","","","","",""]
    pred_type = ["predictions_sigmoid","predictions"]

    for percentage in range(len(percentage_array)):
        inputs[percentage] = "Test_outputs/Prano_randomInit_10_C100_Output_test_5/Epoch_" + str(percentage_array[percentage]) + "_Dice_predictions.csv"
        inputs2[percentage] = "Test_outputs/Prano_randomInit_50_C100_Output_test_5/Epoch_" + str(percentage_array[percentage]) + "_Dice_predictions.csv"

    title_output_model = ["10%", "50%"]#, "PTE"]
    col_name = ["Epoch 1","Epoch 2","Epoch 3","Epoch 4","Epoch 5","100%"]
    train_data_input = pd.DataFrame(data=None, columns=title_output_model)# .astype(int)

    x_array = np.array([])
    y_array = np.array([])
    z_array = np.array([])
    a_array = np.array([])

    index = [0,1,2,3,4]#,5]
    input_test = [inputs, inputs2]#, inputs3]

    for i in range(len(index)):
        x_array = np.array([])
        y_array = np.array([])
        z_array = np.array([])

        x_array = np.genfromtxt(input_test[0][index[i]], delimiter=',',invalid_raise = False)
        x_array = np.ndarray.flatten(x_array)
        if show_ones == True:
            x_array[x_array == 1] = np.nan

        y_array = np.genfromtxt(input_test[1][index[i]], delimiter=',',invalid_raise = False)
        y_array = np.ndarray.flatten(y_array)
        if show_ones == True:
            y_array[y_array == 1] = np.nan

        df1 = pd.DataFrame(data = {"Division":np.full(len(x_array), col_name[index[i]]),
                                   "10%":x_array,"50%":y_array})#,"PTE":z_array})
        train_data_input = train_data_input.append(df1,ignore_index=True)

    data = train_data_input.melt('Division', var_name='Model Pre-training level', value_name='Mean Dice')
    fig = plt.figure(figsize=(10,5))
    plt.grid()
    ax=sns.boxplot(y='Mean Dice', x='Division', hue='Model Pre-training level', data=data)
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
    plt.title("Mean "+train_stage+" Dice score with pretraining. Grouped by epoch \nfor 10% vs 50% dataset used for training."
             ,fontsize=20)
    plt.ylim(-0.05,1.05)
    ax.xaxis.set_minor_locator(MultipleLocator(0.5))
    ax.xaxis.grid(True, which='minor', color='black', lw=1)
    plt.xlabel("",fontsize=18)
    plt.ylabel("Mean Volume Dice Score",fontsize=18)
    plt.show()
# Out:
# TESTING DATA

# %%
# Paired T test between epoch 1 of each setting


print("TESTING DATA")
# Segmentation outputs for differing training data size amounts

from matplotlib.ticker import MultipleLocator
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import csv  

sns.set(font_scale = 1.35)
sns.set_style("white",{"grid.color": ".5", "grid.linestyle": ":"})

epoch = 0
show_ones = False
for train_stage in ["Testing"]:
    percentage_array = [0,1,2,3,4,0]
    inputs,inputs2 = ["","","","","",""],["","","","","",""]
    pred_type = ["predictions_sigmoid","predictions"]

    for percentage in range(len(percentage_array)):
        inputs[percentage] = "Test_outputs/Prano_randomInit_10_C100_Output_test_5/Epoch_" + str(percentage_array[percentage]) + "_Dice_predictions.csv"
        inputs2[percentage] = "Test_outputs/Prano_pretrained_10_C100_Output_test_5/Epoch_" + str(percentage_array[percentage]) + "_Dice_predictions.csv"

    title_output_model = ["RI", "PTE"]#, "PTE"]
    col_name = ["Epoch 1","Epoch 2","Epoch 3","Epoch 4","Epoch 5","100%"]
    train_data_input = pd.DataFrame(data=None, columns=title_output_model)# .astype(int)

    x_array = np.array([])
    y_array = np.array([])
    z_array = np.array([])
    a_array = np.array([])

    index = [0,1,2,3,4]#,5]
    input_test = [inputs, inputs2]#, inputs3]

    for i in range(len(index)):
        x_array = np.array([])
        y_array = np.array([])
        z_array = np.array([])

        x_array = np.genfromtxt(input_test[0][index[i]], delimiter=',',invalid_raise = False)
        x_array = np.ndarray.flatten(x_array)
        if show_ones == True:
            x_array[x_array == 1] = np.nan

        y_array = np.genfromtxt(input_test[1][index[i]], delimiter=',',invalid_raise = False)
        y_array = np.ndarray.flatten(y_array)
        if show_ones == True:
            y_array[y_array == 1] = np.nan

        df1 = pd.DataFrame(data = {"Division":np.full(len(x_array), col_name[index[i]]),
                                   "RI":x_array,"PTE":y_array})#,"PTE":z_array})
        train_data_input = train_data_input.append(df1,ignore_index=True)

    data = train_data_input.melt('Division', var_name='Model Pre-training level', value_name='Mean Dice')
    fig = plt.figure(figsize=(10,5))
    plt.grid()
    ax=sns.boxplot(y='Mean Dice', x='Division', hue='Model Pre-training level', data=data)
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
    plt.title("Mean "+train_stage+" Dice score with pretraining. Grouped by epoch \nfor 10% dataset used for training."
             ,fontsize=20)
    plt.ylim(-0.05,1.05)
    ax.xaxis.set_minor_locator(MultipleLocator(0.5))
    ax.xaxis.grid(True, which='minor', color='black', lw=1)
    plt.xlabel("",fontsize=18)
    plt.ylabel("Mean Volume Dice Score",fontsize=18)
    plt.show()
# Out:
# TESTING DATA

# %%
# Paired T test between epoch 1 of each setting


print("TESTING DATA")
# Segmentation outputs for differing training data size amounts

from matplotlib.ticker import MultipleLocator
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import csv  

sns.set(font_scale = 1.35)
sns.set_style("white",{"grid.color": ".5", "grid.linestyle": ":"})

epoch = 0
show_ones = False
for train_stage in ["Testing"]:
    percentage_array = [0,1,2,3,4,0]
    inputs,inputs2 = ["","","","","",""],["","","","","",""]
    pred_type = ["predictions_sigmoid","predictions"]

    for percentage in range(len(percentage_array)):
        inputs[percentage] = "Test_outputs/Prano_randomInit_50_C100_Output_test_5/Epoch_" + str(percentage_array[percentage]) + "_Dice_predictions.csv"
        inputs2[percentage] = "Test_outputs/Prano_pretrained_50_C100_Output_test_5/Epoch_" + str(percentage_array[percentage]) + "_Dice_predictions.csv"

    title_output_model = ["RI", "PTE"]#, "PTE"]
    col_name = ["Epoch 1","Epoch 2","Epoch 3","Epoch 4","Epoch 5","100%"]
    train_data_input = pd.DataFrame(data=None, columns=title_output_model)# .astype(int)

    x_array = np.array([])
    y_array = np.array([])
    z_array = np.array([])
    a_array = np.array([])

    index = [0,1,2,3,4]#,5]
    input_test = [inputs, inputs2]#, inputs3]

    for i in range(len(index)):
        x_array = np.array([])
        y_array = np.array([])
        z_array = np.array([])

        x_array = np.genfromtxt(input_test[0][index[i]], delimiter=',',invalid_raise = False)
        x_array = np.ndarray.flatten(x_array)
        if show_ones == True:
            x_array[x_array == 1] = np.nan

        y_array = np.genfromtxt(input_test[1][index[i]], delimiter=',',invalid_raise = False)
        y_array = np.ndarray.flatten(y_array)
        if show_ones == True:
            y_array[y_array == 1] = np.nan

        df1 = pd.DataFrame(data = {"Division":np.full(len(x_array), col_name[index[i]]),
                                   "RI":x_array,"PTE":y_array})#,"PTE":z_array})
        train_data_input = train_data_input.append(df1,ignore_index=True)

    data = train_data_input.melt('Division', var_name='Model Pre-training level', value_name='Mean Dice')
    fig = plt.figure(figsize=(10,5))
    plt.grid()
    ax=sns.boxplot(y='Mean Dice', x='Division', hue='Model Pre-training level', data=data)
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
    plt.title("Mean "+train_stage+" Dice score with pretraining. Grouped by epoch \nfor 50% dataset used for training."
             ,fontsize=20)
    plt.ylim(-0.05,1.05)
    ax.xaxis.set_minor_locator(MultipleLocator(0.5))
    ax.xaxis.grid(True, which='minor', color='black', lw=1)
    plt.xlabel("",fontsize=18)
    plt.ylabel("Mean Volume Dice Score",fontsize=18)
    plt.show()
# Out:
# TESTING DATA

# %%
# RANO output loss for both training and validation - over differing penalty types

from matplotlib.pyplot import figure
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

Epochs = 50

sns.set(font_scale = 1.35)
sns.set_style("white",{"grid.color": ".5", "grid.linestyle": ":"})

input_names = ["Prano_pretrain_1_C100"]
legend_names = ["Validation", "Training"]

output_type = ["validation_loss","training_loss"]
output_axis = ["MSE loss + cosine loss"]
output_title = ["Loss"]
second_out = ["Validation_loss","Training_loss"]

loss_0 = []
loss_Nan_0 = []
figure(figsize=(14, 6), dpi=80)
ax = plt.subplot()
for c in range(len(output_type)):

    for s in range(len(input_names)):
        for i in range(Epochs):
            
            loss_0 = np.genfromtxt("Checkpoints_RANO/Checkpoints/"+ input_names[s]+ "/" + second_out[c] + "/epoch_"+str(i)+output_type[c] + ".csv",delimiter=',')
            loss_Nan_0 = np.append(loss_Nan_0, np.mean(loss_0[np.logical_not(np.isnan(loss_0))]))
            if c > (len(output_type) - 3):
                loss_Nan_0[i] = loss_Nan_0[i]

        ax.plot(range(len(loss_Nan_0)),loss_Nan_0)
        loss_0 = []
        loss_Nan_0 = []

plt.title("Mean " + output_title[0] + " per Epoch ",fontsize=20)
ax.legend(legend_names, bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0, fontsize=16)
plt.xlabel("Epoch",fontsize=18)
plt.ylabel(ylabel=output_axis[0],fontsize=18)
plt.grid()
plt.show()    
    
# RANO output loss for both training and validation - over differing penalty types

from matplotlib.pyplot import figure
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

sns.set(font_scale = 1.35)
sns.set_style("white",{"grid.color": ".5", "grid.linestyle": ":"})

input_names = ["CT_50_c_100_Prano_50_epochs"]
legend_names = ["Validation", "Training"]

output_type = ["validation_jaccard_index","jaccard_index"]
output_axis = ["Jaccard score"]
output_title = ["Jaccard"]
second_out = ["Validation_Jaccard","Training_Jaccard"]

loss_0 = []
loss_Nan_0 = []
figure(figsize=(14, 6), dpi=80)
ax = plt.subplot()
for c in range(len(output_type)):

    #CT_50_c_100_Prano_50_epochs
    
    for s in range(len(input_names)):
        for i in range(Epochs):
            
            loss_0 = np.genfromtxt("Checkpoints_RANO/Checkpoints/"+ input_names[s]+ "/" + second_out[c] + "/epoch_"+str(i)+output_type[c] + ".csv",delimiter=',')
            loss_Nan_0 = np.append(loss_Nan_0, np.mean(loss_0[np.logical_not(np.isnan(loss_0))]))
            if c > (len(output_type) - 3):
                loss_Nan_0[i] = loss_Nan_0[i]

        ax.plot(range(len(loss_Nan_0)),loss_Nan_0)
        loss_0 = []
        loss_Nan_0 = []

plt.title("Mean " + output_title[0] + " per Epoch ",fontsize=20)
ax.legend(legend_names, bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0, fontsize=16)
plt.xlabel("Epoch",fontsize=18)
plt.ylabel(ylabel=output_axis[0],fontsize=18)
plt.grid()
plt.show()
