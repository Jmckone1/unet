# %%
print("The plan for this file is to incrementally make changes to the code")
print("that were all made previously to see what is impacting the results")
print("causing them not to work in the most recent version")
print("")
print("Lets make sure to only make one change at a time")
print("the changes are as follows")
print("None")
print("dataloader")
print("dice score")
print("network combination")
print("splitting validation and training codebases amongst files")

# %run "Code_UNet_2/Code_UNet_Re/UNet_Main_2.py"
# Out:
# The plan for this file is to incrementally make changes to the code
# that were all made previously to see what is impacting the results
# causing them not to work in the most recent version
#
# Lets make sure to only make one change at a time
# the changes are as follows
# None
# dataloader
# dice score
# network combination
# splitting validation and training codebases amongst files
# ###################################################
# Parameter file values
# ###################################################
# __module__ Net_modules.Parameters_seg
# Seed 0
# GPU 2
#
# __module__ Net_modules.Parameters_seg
# image_in whimg_norm
# rano_in RANO_2
# index_file /inedx_max_2.npy
# refresh_index False
#
# __module__ Net_modules.Parameters_seg
# dataset_path Brats_2018_data/Brats_2018_data
# c_file Checkpoints/Old_model_dataloaderOld_noAugment_print/
# checkpoint_name Checkpoints_RANO/Unet_H16_M14_CO100_R3_main_data_input_4/checkpoint_49.pth
# n_epochs 1
# input_dim 4
# label_dim 1
# hidden_dim 16
# lr 0.0003
# size 1
# display_step 50
# batch_size 16
# device cuda
# train_split 0.7
# validation_split 0.1
# test_split 0.2
# custom_split_amount 1
# weight_decay 1e-08
# extensions ['/HGG', '/LGG']
# useWeights False
# allow_update True
# checkpoint_eval False
#
# Press Enter to continue . . .
# starting model
# Init dataloader
# 90
# /HGG/Brats18_CBICA_ATF_1/Brats18_CBICA_ATF_1_whimg_norm.nii.gz
# 90
# -2.8176591396331787 5.663393974304199
# 0.0 1.0
# float64
# float64
# /HGG/Brats18_CBICA_ATF_1/Brats18_CBICA_ATF_1_whimg_norm.nii.gz
# 100
# -2.7543270587921143 6.270469665527344
# 0.0 0.0
# float64
# float64
# /HGG/Brats18_CBICA_ATF_1/Brats18_CBICA_ATF_1_whimg_norm.nii.gz
# 110
# -3.1373918056488037 6.460465431213379
# 0.0 0.0
# float64
# float64
# 190
# /HGG/Brats18_CBICA_AXL_1/Brats18_CBICA_AXL_1_whimg_norm.nii.gz
# 190
# -3.300100803375244 7.4258341789245605
# 0.0 0.0
# float64
# float64
# /HGG/Brats18_CBICA_AXL_1/Brats18_CBICA_AXL_1_whimg_norm.nii.gz
# 200
# -3.3477284908294678 9.289610862731934
# 0.0 1.0
# float64
# float64
# /HGG/Brats18_CBICA_AXL_1/Brats18_CBICA_AXL_1_whimg_norm.nii.gz
# 210
# -3.5368287563323975 10.655854225158691
# 0.0 1.0
# float64
# float64
# 290
# /HGG/Brats18_CBICA_AXL_1/Brats18_CBICA_AXL_1_whimg_norm.nii.gz
# 290
# -3.5368287563323975 3.958893060684204
# 0.0 0.0
# float64
# float64
# /HGG/Brats18_CBICA_AXL_1/Brats18_CBICA_AXL_1_whimg_norm.nii.gz
# 300
# 0.0 0.0
# 0.0 0.0
# float64
# float64
# /HGG/Brats18_TCIA01_411_1/Brats18_TCIA01_411_1_whimg_norm.nii.gz
# 310
# 0.0 0.0
# 0.0 0.0
# float64
# float64
# 390
# /HGG/Brats18_TCIA01_411_1/Brats18_TCIA01_411_1_whimg_norm.nii.gz
# 390
# -5.495569705963135 6.717061996459961
# 0.0 0.0
# float64
# float64
# /HGG/Brats18_TCIA01_411_1/Brats18_TCIA01_411_1_whimg_norm.nii.gz
# 400
# -5.519100666046143 4.924354076385498
# 0.0 0.0
# float64
# float64
# /HGG/Brats18_TCIA01_411_1/Brats18_TCIA01_411_1_whimg_norm.nii.gz
# 410
# -5.683818340301514 7.96420955657959
# 0.0 0.0
# float64
# float64
# 490
# /HGG/Brats18_CBICA_ALU_1/Brats18_CBICA_ALU_1_whimg_norm.nii.gz
# 490
# -2.999985933303833 11.809277534484863
# 0.0 0.0
# float64
# float64
# /HGG/Brats18_CBICA_ALU_1/Brats18_CBICA_ALU_1_whimg_norm.nii.gz
# 500
# -3.185966968536377 8.249100685119629
# 0.0 0.0
# float64
# float64
# /HGG/Brats18_CBICA_ALU_1/Brats18_CBICA_ALU_1_whimg_norm.nii.gz
# 510
# -2.77559494972229 7.760364532470703
# 0.0 1.0
# float64
# float64
# 590
# /HGG/Brats18_CBICA_ALU_1/Brats18_CBICA_ALU_1_whimg_norm.nii.gz
# 590
# -2.7243428230285645 8.346102714538574
# 0.0 0.0
# float64
# float64
# /HGG/Brats18_CBICA_ALU_1/Brats18_CBICA_ALU_1_whimg_norm.nii.gz
# 600
# -3.009890079498291 9.65669059753418
# 0.0 0.0
# float64
# float64
# /HGG/Brats18_CBICA_ALU_1/Brats18_CBICA_ALU_1_whimg_norm.nii.gz
# 610
# 0.0 0.0
# 0.0 0.0
# float64
# float64
# 690
# /HGG/Brats18_CBICA_BHB_1/Brats18_CBICA_BHB_1_whimg_norm.nii.gz
# 690
# -3.353137493133545 8.780383110046387
# 0.0 1.0
# float64
# float64
# /HGG/Brats18_CBICA_BHB_1/Brats18_CBICA_BHB_1_whimg_norm.nii.gz
# 700
# -3.5768823623657227 6.427611351013184
# 0.0 0.0
# float64
# float64
# /HGG/Brats18_CBICA_BHB_1/Brats18_CBICA_BHB_1_whimg_norm.nii.gz
# 710
# -3.5236096382141113 9.652251243591309
# 0.0 0.0
# float64
# float64
# 790
# /HGG/Brats18_CBICA_AUN_1/Brats18_CBICA_AUN_1_whimg_norm.nii.gz
# 790
# -3.609121322631836 5.360806941986084
# 0.0 0.0
# float64
# float64
# /HGG/Brats18_CBICA_AUN_1/Brats18_CBICA_AUN_1_whimg_norm.nii.gz
# 800
# -3.8605527877807617 4.752225399017334
# 0.0 0.0
# float64
# float64
# /HGG/Brats18_CBICA_AUN_1/Brats18_CBICA_AUN_1_whimg_norm.nii.gz
# 810
# -3.653491497039795 7.727622985839844
# 0.0 0.0
# float64
# float64
# 890
# /HGG/Brats18_CBICA_AUN_1/Brats18_CBICA_AUN_1_whimg_norm.nii.gz
# 890
# -4.052824020385742 8.516561508178711
# 0.0 1.0
# float64
# float64
# /HGG/Brats18_CBICA_AUN_1/Brats18_CBICA_AUN_1_whimg_norm.nii.gz
# 900
# -3.2837390899658203 8.057876586914062
# 0.0 1.0
# float64
# float64
# /HGG/Brats18_CBICA_AUN_1/Brats18_CBICA_AUN_1_whimg_norm.nii.gz
# 910
# -2.6431961059570312 7.9936604499816895
# 0.0 1.0
# float64
# float64
# 990
# /HGG/Brats18_CBICA_AQG_1/Brats18_CBICA_AQG_1_whimg_norm.nii.gz
# 990
# -3.418645143508911 7.868503570556641
# 0.0 1.0
# float64
# float64
# /HGG/Brats18_CBICA_AQG_1/Brats18_CBICA_AQG_1_whimg_norm.nii.gz
# 1000
# -3.913860321044922 7.925185680389404
# 0.0 1.0
# float64
# float64
# /HGG/Brats18_CBICA_AQG_1/Brats18_CBICA_AQG_1_whimg_norm.nii.gz
# 1010
# -3.418645143508911 5.583375453948975
# 0.0 1.0
# float64
# float64
# initialised dataset
# loaded index file
# length start
# range start
# 31000
# 4495
# 44175
# Custom_split length 44175
# produced dataset split amounts
# Full_dataset:  44175
# Training:  31000
# validation:  4495
# Epochs:  1
# Actual train length 44175
# actual validation length 4495

# %%
print("The plan for this file is to incrementally make changes to the code")
print("that were all made previously to see what is impacting the results")
print("causing them not to work in the most recent version")
print("")
print("Lets make sure to only make one change at a time")
print("the changes are as follows")
print("None")
print("dataloader")
print("dice score")
print("network combination")
print("splitting validation and training codebases amongst files")

# %run "Code_UNet_2/Code_UNet_Re/UNet_Main_2.py"
# Out:
# The plan for this file is to incrementally make changes to the code
# that were all made previously to see what is impacting the results
# causing them not to work in the most recent version
#
# Lets make sure to only make one change at a time
# the changes are as follows
# None
# dataloader
# dice score
# network combination
# splitting validation and training codebases amongst files
# ###################################################
# Parameter file values
# ###################################################
# __module__ Net_modules.Parameters_seg
# Seed 0
# GPU 2
#
# __module__ Net_modules.Parameters_seg
# image_in whimg_norm
# rano_in RANO_2
# index_file /inedx_max_2.npy
# refresh_index False
#
# __module__ Net_modules.Parameters_seg
# dataset_path Brats_2018_data/Brats_2018_data
# c_file Checkpoints/Old_model_dataloaderOld_noAugment_print/
# checkpoint_name Checkpoints_RANO/Unet_H16_M14_CO100_R3_main_data_input_4/checkpoint_49.pth
# n_epochs 1
# input_dim 4
# label_dim 1
# hidden_dim 16
# lr 0.0003
# size 1
# display_step 50
# batch_size 16
# device cuda
# train_split 0.7
# validation_split 0.1
# test_split 0.2
# custom_split_amount 1
# weight_decay 1e-08
# extensions ['/HGG', '/LGG']
# useWeights False
# allow_update True
# checkpoint_eval False
#
# Press Enter to continue . . .
#
# ######################## new dataloader ###############
#
# Loading Dataset
# Image /data/Brats_2018_4/imagesTr/Brats18_CBICA_ATF_1_whimg_norm_90.nii.gz
# Mask /data/Brats_2018_4/labelsTr/Brats18_CBICA_ATF_1_whseg_norm_90.nii.gz
# -2.532665491104126 4.749337673187256
# 0.0 1.0
# float64
# float64
# Image /data/Brats_2018_4/imagesTr/Brats18_CBICA_ATF_1_whimg_norm_100.nii.gz
# Mask /data/Brats_2018_4/labelsTr/Brats18_CBICA_ATF_1_whseg_norm_100.nii.gz
# -2.761702537536621 5.80603551864624
# 0.0 0.0
# float64
# float64
# Image /data/Brats_2018_4/imagesTr/Brats18_CBICA_ATF_1_whimg_norm_110.nii.gz
# Mask /data/Brats_2018_4/labelsTr/Brats18_CBICA_ATF_1_whseg_norm_110.nii.gz
# -3.162437677383423 5.869367599487305
# 0.0 0.0
# float64
# float64
# Image /data/Brats_2018_4/imagesTr/Brats18_CBICA_AXL_1_whimg_norm_35.nii.gz
# Mask /data/Brats_2018_4/labelsTr/Brats18_CBICA_AXL_1_whseg_norm_35.nii.gz
# -3.300100803375244 8.081315040588379
# 0.0 0.0
# float64
# float64
# Image /data/Brats_2018_4/imagesTr/Brats18_CBICA_AXL_1_whimg_norm_45.nii.gz
# Mask /data/Brats_2018_4/labelsTr/Brats18_CBICA_AXL_1_whseg_norm_45.nii.gz
# -3.2355806827545166 9.060587882995605
# 0.0 1.0
# float64
# float64
# Image /data/Brats_2018_4/imagesTr/Brats18_CBICA_AXL_1_whimg_norm_55.nii.gz
# Mask /data/Brats_2018_4/labelsTr/Brats18_CBICA_AXL_1_whseg_norm_55.nii.gz
# -3.5368287563323975 10.403139114379883
# 0.0 1.0
# float64
# float64
# Image /data/Brats_2018_4/imagesTr/Brats18_CBICA_AXL_1_whimg_norm_135.nii.gz
# Mask /data/Brats_2018_4/labelsTr/Brats18_CBICA_AXL_1_whseg_norm_135.nii.gz
# -3.2596805095672607 3.7061774730682373
# 0.0 0.0
# float64
# float64
# Image /data/Brats_2018_4/imagesTr/Brats18_CBICA_AXL_1_whimg_norm_145.nii.gz
# Mask /data/Brats_2018_4/labelsTr/Brats18_CBICA_AXL_1_whseg_norm_145.nii.gz
# 0.0 0.0
# 0.0 0.0
# float64
# float64
# Image /data/Brats_2018_4/imagesTr/Brats18_TCIA01_411_1_whimg_norm_0.nii.gz
# Mask /data/Brats_2018_4/labelsTr/Brats18_TCIA01_411_1_whseg_norm_0.nii.gz
# -4.624919414520264 9.791290283203125
# 0.0 0.0
# float64
# float64
# Image /data/Brats_2018_4/imagesTr/Brats18_TCIA01_411_1_whimg_norm_80.nii.gz
# Mask /data/Brats_2018_4/labelsTr/Brats18_TCIA01_411_1_whseg_norm_80.nii.gz
# -5.566162586212158 6.858248710632324
# 0.0 0.0
# float64
# float64
# Image /data/Brats_2018_4/imagesTr/Brats18_TCIA01_411_1_whimg_norm_90.nii.gz
# Mask /data/Brats_2018_4/labelsTr/Brats18_TCIA01_411_1_whseg_norm_90.nii.gz
# -5.472038269042969 4.827856063842773
# 0.0 0.0
# float64
# float64
# Image /data/Brats_2018_4/imagesTr/Brats18_TCIA01_411_1_whimg_norm_100.nii.gz
# Mask /data/Brats_2018_4/labelsTr/Brats18_TCIA01_411_1_whseg_norm_100.nii.gz
# -4.860230445861816 9.329011917114258
# 0.0 0.0
# float64
# float64
# Image /data/Brats_2018_4/imagesTr/Brats18_CBICA_ALU_1_whimg_norm_25.nii.gz
# Mask /data/Brats_2018_4/labelsTr/Brats18_CBICA_ALU_1_whseg_norm_25.nii.gz
# -2.9645609855651855 10.139925003051758
# 0.0 0.0
# float64
# float64
# Image /data/Brats_2018_4/imagesTr/Brats18_CBICA_ALU_1_whimg_norm_35.nii.gz
# Mask /data/Brats_2018_4/labelsTr/Brats18_CBICA_ALU_1_whseg_norm_35.nii.gz
# -3.097404718399048 9.43830394744873
# 0.0 0.0
# float64
# float64
# Image /data/Brats_2018_4/imagesTr/Brats18_CBICA_ALU_1_whimg_norm_45.nii.gz
# Mask /data/Brats_2018_4/labelsTr/Brats18_CBICA_ALU_1_whseg_norm_45.nii.gz
# -2.6291604042053223 7.855546951293945
# 0.0 1.0
# float64
# float64
# Image /data/Brats_2018_4/imagesTr/Brats18_CBICA_ALU_1_whimg_norm_125.nii.gz
# Mask /data/Brats_2018_4/labelsTr/Brats18_CBICA_ALU_1_whseg_norm_125.nii.gz
# -2.797559976577759 8.419320106506348
# 0.0 0.0
# float64
# float64
# Image /data/Brats_2018_4/imagesTr/Brats18_CBICA_ALU_1_whimg_norm_135.nii.gz
# Mask /data/Brats_2018_4/labelsTr/Brats18_CBICA_ALU_1_whseg_norm_135.nii.gz
# -2.892742395401001 8.250920295715332
# 0.0 0.0
# float64
# float64
# Image /data/Brats_2018_4/imagesTr/Brats18_CBICA_ALU_1_whimg_norm_145.nii.gz
# Mask /data/Brats_2018_4/labelsTr/Brats18_CBICA_ALU_1_whseg_norm_145.nii.gz
# 0.0 0.0
# 0.0 0.0
# float64
# float64
# Image /data/Brats_2018_4/imagesTr/Brats18_CBICA_BHB_1_whimg_norm_70.nii.gz
# Mask /data/Brats_2018_4/labelsTr/Brats18_CBICA_BHB_1_whseg_norm_70.nii.gz
# -3.438373565673828 8.318344116210938
# 0.0 1.0
# float64
# float64
# Image /data/Brats_2018_4/imagesTr/Brats18_CBICA_BHB_1_whimg_norm_80.nii.gz
# Mask /data/Brats_2018_4/labelsTr/Brats18_CBICA_BHB_1_whseg_norm_80.nii.gz
# -3.651463747024536 7.057101726531982
# 0.0 0.0
# float64
# float64
# Image /data/Brats_2018_4/imagesTr/Brats18_CBICA_BHB_1_whimg_norm_90.nii.gz
# Mask /data/Brats_2018_4/labelsTr/Brats18_CBICA_BHB_1_whseg_norm_90.nii.gz
# -3.438373565673828 10.062935829162598
# 0.0 0.0
# float64
# float64
# Image /data/Brats_2018_4/imagesTr/Brats18_CBICA_AUN_1_whimg_norm_15.nii.gz
# Mask /data/Brats_2018_4/labelsTr/Brats18_CBICA_AUN_1_whseg_norm_15.nii.gz
# -3.609121322631836 4.828732013702393
# 0.0 0.0
# float64
# float64
# Image /data/Brats_2018_4/imagesTr/Brats18_CBICA_AUN_1_whimg_norm_25.nii.gz
# Mask /data/Brats_2018_4/labelsTr/Brats18_CBICA_AUN_1_whseg_norm_25.nii.gz
# -3.4168500900268555 6.259829998016357
# 0.0 0.0
# float64
# float64
# Image /data/Brats_2018_4/imagesTr/Brats18_CBICA_AUN_1_whimg_norm_35.nii.gz
# Mask /data/Brats_2018_4/labelsTr/Brats18_CBICA_AUN_1_whseg_norm_35.nii.gz
# -3.8013925552368164 7.296458721160889
# 0.0 0.0
# float64
# float64
# Image /data/Brats_2018_4/imagesTr/Brats18_CBICA_AUN_1_whimg_norm_115.nii.gz
# Mask /data/Brats_2018_4/labelsTr/Brats18_CBICA_AUN_1_whseg_norm_115.nii.gz
# -3.520380735397339 8.791772842407227
# 0.0 1.0
# float64
# float64
# Image /data/Brats_2018_4/imagesTr/Brats18_CBICA_AUN_1_whimg_norm_125.nii.gz
# Mask /data/Brats_2018_4/labelsTr/Brats18_CBICA_AUN_1_whseg_norm_125.nii.gz
# -2.8548264503479004 9.699969291687012
# 0.0 1.0
# float64
# float64
# Image /data/Brats_2018_4/imagesTr/Brats18_CBICA_AUN_1_whimg_norm_135.nii.gz
# Mask /data/Brats_2018_4/labelsTr/Brats18_CBICA_AUN_1_whseg_norm_135.nii.gz
# -2.9435670375823975 7.415717124938965
# 0.0 1.0
# float64
# float64
# Image /data/Brats_2018_4/imagesTr/Brats18_CBICA_AQG_1_whimg_norm_60.nii.gz
# Mask /data/Brats_2018_4/labelsTr/Brats18_CBICA_AQG_1_whseg_norm_60.nii.gz
# -3.418645143508911 7.925185680389404
# 0.0 1.0
# float64
# float64
# Image /data/Brats_2018_4/imagesTr/Brats18_CBICA_AQG_1_whimg_norm_70.nii.gz
# Mask /data/Brats_2018_4/labelsTr/Brats18_CBICA_AQG_1_whseg_norm_70.nii.gz
# -3.635648488998413 9.191086769104004
# 0.0 1.0
# float64
# float64
# Image /data/Brats_2018_4/imagesTr/Brats18_CBICA_AQG_1_whimg_norm_80.nii.gz
# Mask /data/Brats_2018_4/labelsTr/Brats18_CBICA_AQG_1_whseg_norm_80.nii.gz
# -3.418645143508911 6.035780906677246
# 0.0 1.0
# float64
# float64
# Dataset size:  44175
# Full_dataset:  44175
# 26507
# 8834
#
# ########################################################
# second dataloader
#
# Actual train length 26507
# actual validation length 8834

# %%
####################################################
print("Model 1 baseline with original code. " + 
      "\nBefore any changing of the code to make it more stable and faster")
print("This model is segmentation")
##################################################

import matplotlib.pyplot as plt
import numpy as np

title = "title"
legend_names = ["legend"]

for out_type in ["loss","dice"]:
    for training_phase in ["training", "validation"]:
        
        loss_0 = []
        loss_Nan_0 = []
        
        File_name = "Checkpoints/Checkpoints/Old_model/epoch_0"+training_phase+"_"+out_type+".csv"
        loss_0, loss_Nan_0 = [],[]

        loss_0 = np.genfromtxt(File_name, delimiter=',')
        if training_phase == "training":
            val = 64
        else:
            val = 8
        
        plt.plot(range(len(loss_0[0::val])),loss_0[0::val])

        plt.title(training_phase + " " + out_type,fontsize=20)
        plt.legend([training_phase], fontsize=16)
        plt.xlabel("Epoch / " + str(val) ,fontsize=18)
        plt.ylabel(ylabel=out_type,fontsize=18)
        plt.grid()
        plt.show()
# Out:
# Model 1 baseline with original code.
# Before any changing of the code to make it more stable and faster
# This model is segmentation

# %%
####################################################
print("Model 2 new dataloader with original code. ")
print("This model is segmentation")
##################################################

import matplotlib.pyplot as plt
import numpy as np

title = "title"
legend_names = ["legend"]

for out_type in ["loss","dice"]:
    for training_phase in ["training", "validation"]:
        
        loss_0 = []
        loss_Nan_0 = []
        
        File_name = "Checkpoints/Checkpoints/Old_model_dataloader/epoch_0"+training_phase+"_"+out_type+".csv"
        loss_0, loss_Nan_0 = [],[]

        loss_0 = np.genfromtxt(File_name, delimiter=',')
        if training_phase == "training":
            val = 64
        else:
            val = 8
        
        plt.plot(range(len(loss_0[0::val])),loss_0[0::val])

        plt.title(training_phase + " " + out_type,fontsize=20)
        plt.legend([training_phase], fontsize=16)
        plt.xlabel("Epoch / " + str(val) ,fontsize=18)
        plt.ylabel(ylabel=out_type,fontsize=18)
        plt.grid()
        plt.show()
# Out:
# Model 2 new dataloader with original code.
# This model is segmentation

# %%
####################################################
print("Model 2 new dataloader with original code. ")
print("This model is segmentation")
##################################################

import matplotlib.pyplot as plt
import numpy as np

title = "title"
legend_names = ["legend"]

for out_type in ["loss","dice"]:
    for training_phase in ["training", "validation"]:
        
        loss_0 = []
        loss_Nan_0 = []
        
        File_name = "Checkpoints/Checkpoints/Old_model_dataloaderNew_noAugment/epoch_0"+training_phase+"_"+out_type+".csv"
        loss_0, loss_Nan_0 = [],[]

        loss_0 = np.genfromtxt(File_name, delimiter=',')
        if training_phase == "training":
            val = 64
        else:
            val = 8
        
        plt.plot(range(len(loss_0[0::val])),loss_0[0::val])

        plt.title(training_phase + " " + out_type,fontsize=20)
        plt.legend([training_phase], fontsize=16)
        plt.xlabel("Epoch / " + str(val) ,fontsize=18)
        plt.ylabel(ylabel=out_type,fontsize=18)
        plt.grid()
        plt.show()
# Out:
# Model 2 new dataloader with original code.
# This model is segmentation

# %%
####################################################
print("Model 2 new dataloader with original code. ")
print("This model is segmentation")
##################################################

import matplotlib.pyplot as plt
import numpy as np

title = "title"
legend_names = ["legend"]

for out_type in ["loss","dice"]:
    for training_phase in ["training", "validation"]:
        
        loss_0 = []
        loss_Nan_0 = []
        
        File_name = "Checkpoints/Checkpoints/Old_model_dataloaderNew_noAugment_print/epoch_0"+training_phase+"_"+out_type+".csv"
        loss_0, loss_Nan_0 = [],[]

        loss_0 = np.genfromtxt(File_name, delimiter=',')
        if training_phase == "training":
            val = 64
        else:
            val = 8
        
        plt.plot(range(len(loss_0[0::val])),loss_0[0::val])

        plt.title(training_phase + " " + out_type,fontsize=20)
        plt.legend([training_phase], fontsize=16)
        plt.xlabel("Epoch / " + str(val) ,fontsize=18)
        plt.ylabel(ylabel=out_type,fontsize=18)
        plt.grid()
        plt.show()
# Out:
# Model 2 new dataloader with original code.
# This model is segmentation

# %%
####################################################
print("Model 2 new dataloader with original code. ")
print("This model is segmentation")
##################################################

import matplotlib.pyplot as plt
import numpy as np

title = "title"
legend_names = ["legend"]

for out_type in ["loss","dice"]:
    for training_phase in ["training", "validation"]:
        
        loss_0 = []
        loss_Nan_0 = []
        
        File_name = "Checkpoints/Checkpoints/Old_model_dataloaderOld_noAugment_print_2/epoch_0"+training_phase+"_"+out_type+".csv"
        loss_0, loss_Nan_0 = [],[]

        loss_0 = np.genfromtxt(File_name, delimiter=',')
        if training_phase == "training":
            val = 32
        else:
            val = 4
        
        plt.plot(range(len(loss_0[0::val])),loss_0[0::val])

        plt.title(training_phase + " " + out_type,fontsize=20)
        plt.legend([training_phase], fontsize=16)
        plt.xlabel("Epoch / " + str(val) ,fontsize=18)
        plt.ylabel(ylabel=out_type,fontsize=18)
        plt.grid()
        plt.show()
# Out:
# Model 2 new dataloader with original code.
# This model is segmentation

# %%
####################################################
print("Model 2 new dataloader with original code. ")
print("This model is segmentation")
##################################################

import matplotlib.pyplot as plt
import numpy as np

title = "title"
legend_names = ["legend"]

for out_type in ["loss","dice"]:
    for training_phase in ["training", "validation"]:
        
        loss_0 = []
        loss_Nan_0 = []
        
        File_name = "Checkpoints/Checkpoints/Old_model_dataloaderNew_Augment_False/epoch_1"+training_phase+"_"+out_type+".csv"
        loss_0, loss_Nan_0 = [],[]

        loss_0 = np.genfromtxt(File_name, delimiter=',')
        if training_phase == "training":
            val = 32
        else:
            val = 4
        
        plt.plot(range(len(loss_0[0::val])),loss_0[0::val])

        plt.title(training_phase + " " + out_type,fontsize=20)
        plt.legend([training_phase], fontsize=16)
        plt.xlabel("Epoch / " + str(val) ,fontsize=18)
        plt.ylabel(ylabel=out_type,fontsize=18)
        plt.grid()
        plt.show()
# Out:
# Model 2 new dataloader with original code.
# This model is segmentation

# %%
####################################################
print("Model 2 new dataloader with original code. ")
print("This model is segmentation")
##################################################

import matplotlib.pyplot as plt
import numpy as np

title = "title"
legend_names = []

for out_type in ["loss","dice"]:
    for training_phase in ["training", "validation"]:
        
        # No augmentation #
        ###################
        
        loss_0 = []
        loss_Nan_0 = []
        
        File_name = "Checkpoints/Checkpoints/Old_model_dataloaderNew_Augment_fliponly/epoch_0"+training_phase+"_"+out_type+".csv"
        loss_0, loss_Nan_0 = [],[]

        loss_0 = np.genfromtxt(File_name, delimiter=',')
        if training_phase == "training":
            val = 32
        else:
            val = 4
        
        plt.plot(range(len(loss_0[0::val])),loss_0[0::val])
        legend_names.append("No augment")
        
        # H Flip only # 
        #############
        loss_0 = []
        loss_Nan_0 = []
        
        File_name = "Checkpoints/Checkpoints/Old_model_dataloaderOld_noAugment_print_2/epoch_0"+training_phase+"_"+out_type+".csv"
        loss_0, loss_Nan_0 = [],[]

        loss_0 = np.genfromtxt(File_name, delimiter=',')
        if training_phase == "training":
            val = 32
        else:
            val = 4
        
        plt.plot(range(len(loss_0[0::val])),loss_0[0::val])
        legend_names.append("H flip")
        
#         # V Flip only # 
#         #############
#         loss_0 = []
#         loss_Nan_0 = []
        
#         File_name = "Checkpoints/Checkpoints/Old_model_dataloaderNew_Augment_fliponly_v/epoch_0"+training_phase+"_"+out_type+".csv"
#         loss_0, loss_Nan_0 = [],[]

#         loss_0 = np.genfromtxt(File_name, delimiter=',')
#         if training_phase == "training":
#             val = 32
#         else:
#             val = 4
        
#         plt.plot(range(len(loss_0[0::val])),loss_0[0::val])
#         legend_names.append("V flip")
        
#         #################
        
#         # crop only # 
#         #############
#         loss_0 = []
#         loss_Nan_0 = []
        
#         File_name = "Checkpoints/Checkpoints/Old_model_dataloaderNew_Augment_croponly/epoch_0"+training_phase+"_"+out_type+".csv"
#         loss_0, loss_Nan_0 = [],[]

#         loss_0 = np.genfromtxt(File_name, delimiter=',')
#         if training_phase == "training":
#             val = 32
#         else:
#             val = 4
        
#         plt.plot(range(len(loss_0[0::val])),loss_0[0::val])
#         legend_names.append("Crop")
        
        
        ####################
        # rotate only # 
        #############
        loss_0 = []
        loss_Nan_0 = []
        
        File_name = "Checkpoints/Checkpoints/Old_model_dataloaderNew_Augment_rotateonly/epoch_0"+training_phase+"_"+out_type+".csv"
        loss_0, loss_Nan_0 = [],[]

        loss_0 = np.genfromtxt(File_name, delimiter=',')
        if training_phase == "training":
            val = 32
        else:
            val = 4
        
        plt.plot(range(len(loss_0[0::val])),loss_0[0::val])
        legend_names.append("Rotate")
        
#         # all # 
#         #############
#         loss_0 = []
#         loss_Nan_0 = []
        
#         File_name = "Checkpoints/Checkpoints/Old_model_dataloaderNew_Augment_allnotv/epoch_0"+training_phase+"_"+out_type+".csv"
#         loss_0, loss_Nan_0 = [],[]

#         loss_0 = np.genfromtxt(File_name, delimiter=',')
#         if training_phase == "training":
#             val = 32
#         else:
#             val = 4
        
#         plt.plot(range(len(loss_0[0::val])),loss_0[0::val])
#         legend_names.append("All")
        
    
#                 ####################
#         # hflip and rotate # 
#         #############
#         loss_0 = []
#         loss_Nan_0 = []
        
#         File_name = "Checkpoints/Checkpoints/Old_model_dataloaderNew_Augment_hflip_rotate/epoch_0"+training_phase+"_"+out_type+".csv"
#         loss_0, loss_Nan_0 = [],[]

#         loss_0 = np.genfromtxt(File_name, delimiter=',')
#         if training_phase == "training":
#             val = 32
#         else:
#             val = 4
        
#         plt.plot(range(len(loss_0[0::val])),loss_0[0::val])
#         legend_names.append("Rotate and H flip")
        
                        ####################
        # crop and rotate # 
        #############
        loss_0 = []
        loss_Nan_0 = []
        
        File_name = "Checkpoints/Checkpoints/Old_model_dataloaderNew_Augment_crop_rotate/epoch_0"+training_phase+"_"+out_type+".csv"
        loss_0, loss_Nan_0 = [],[]

        loss_0 = np.genfromtxt(File_name, delimiter=',')
        if training_phase == "training":
            val = 32
        else:
            val = 4
        
        plt.plot(range(len(loss_0[0::val])),loss_0[0::val])
        legend_names.append("Rotate and crop")
        
        plt.title(training_phase + " " + out_type,fontsize=20)
        plt.legend(legend_names, fontsize=16)
        plt.xlabel("Epoch / " + str(val) ,fontsize=18)
        plt.ylabel(ylabel=out_type,fontsize=18)
        plt.grid()
        plt.show()
# Out:
# Model 2 new dataloader with original code.
# This model is segmentation
